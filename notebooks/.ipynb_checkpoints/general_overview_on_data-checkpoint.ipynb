# %%
import scanpy as sc
import pandas as pd
import numpy as np
# Out:
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
adata=sc.read_h5ad("/scratch200/reutj/data/human_dev_GRCh38-3.0.0_all_layers.h5ad")

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.obs.Tissue.unique().tolist()
#many overlapping tissues we would need to join
# Out:
# ["b'Cortex'",
#  "b'Hypothalamus'",
#  "b'Thalamus'",
#  "b'Ventral midbrain'",
#  "b'Forebrain cortex'",
#  "b'Subcortical forebrain'",
#  "b'Forebrain'",
#  "b'Cerebellum'",
#  "b'Dorsal midbrain'",
#  "b'Medulla'",
#  "b'Mesencephalon'",
#  "b'Pons/Cereb'",
#  "b'Tel/diencephalon'",
#  "b'Diencephalon'",
#  "b'Pons'",
#  "b'Striatum'",
#  "b'Telencephalon'",
#  "b'Hindbrain'",
#  "b'Head'",
#  "b'Pons/Medulla'",
#  "b'Subcortex'",
#  "b'Enthorinal cortex'",
#  "b'Hippocampus'",
#  "b'Cortical hem'",
#  "b'Frontotemporal cortex'",
#  "b'Lower cortex'",
#  "b'Occipital cortex'",
#  "b'Upper cortex'",
#  "b'Caudate-Putamen'",
#  "b'Brain'",
#  "b'Midbrain'"]

# %%
adata.obs.CellClass.unique().tolist()
# Out:
# ["b'Erythrocyte'",
#  "b'Fibroblast'",
#  "b'Glioblast'",
#  "b'Immune'",
#  "b'Neuroblast'",
#  "b'Neural crest'",
#  "b'Neuron'",
#  "b'Neuronal IPC'",
#  "b'Oligo'",
#  "b'Radial glia'",
#  "b'Placodes'",
#  "b'Vascular'"]

# %%
adata.var
# Out:
#                 Chromosome       End        Gene     Start Strand  n_cells
# Accession
# ENSG00000238009          1    133723  AL627309.1     89295      -     1325
# ENSG00000239945          1     91105  AL627309.3     89551      -      339
# ENSG00000225880          1    827522   LINC00115    826206      -    18445
# ENSG00000230368          1    876903      FAM41C    868071      -     1581
# ENSG00000223764          1    921016  AL645608.1    916865      -     3872
# ...                    ...       ...         ...       ...    ...      ...
# ENSG00000198692          Y  20593154      EIF1AY  20575725      +   215422
# ENSG00000280969          Y  20781032      RPS4Y2  20756164      +      120
# ENSG00000235059          Y  22485592  AC008175.1  22438940      +       11
# ENSG00000205944          Y  23291356        DAZ2  23219434      +       58
# ENSG00000205916          Y  24907040        DAZ4  24833843      +        8
#
# [32020 rows x 6 columns]

# %% [markdown]
# #### upload gene lists

# %%
hsg=pd.read_csv("/scratch200/reutj/data/hsg_gene_lists/updated_human_specific_genes3.csv")

# %%
har_genes=pd.read_excel("/scratch200/reutj/data/hsg_gene_lists/har_associated_genes.xlsx",header=1)

# %% [markdown]
# #### check genes in adata

# %%
ens_adata=adata.var_names.to_list()
gene_sym_adata=adata.var["Gene"].to_list()

# %%
#eveb less genes here, i will try witout the filtering

# %%
print(len([i for i in hsg["gene"] if i in gene_sym_adata])) #check gene symbols
print(len([i for i in hsg["ens"] if i in ens_adata])) #check gene ensemble
# Out:
# 465
# 516

# %%
print(len([i for i in har_genes["HAR-associated genes.1"] if i in gene_sym_adata])) #check gene symbols
print(len([i for i in har_genes["HAR-associated genes"] if i in ens_adata])) #check gene ensemble
# more ensg but numbers are pretty small- most dont express in data
# Out:
# 731
# 1030

# %%
# general expression details and tissue, lets go:

def find_exp_genes(hsg_list,adata):
    genes=hsg_list["gene"].tolist()
    genes_to_check=[]
    for gene in genes:
        gene_exp=np.count_nonzero(adata.X[:,adata.var["Gene"]==gene].toarray().flatten())
        if gene_exp>100:
            print(gene, gene_exp)
            genes_to_check.append(gene)
    return genes_to_check
    
def create_exp_table(gene_list,adata):
    exp={}
    Tissues=adata.obs.Tissue.unique().tolist()
    Cell_types= adata.obs.CellClass.unique().tolist()
    for t in Tissues:
        print("tissue: ",t)
        relevant_data=adata[adata.obs.Tissue==t,adata.var["Gene"].isin(gene_list)]
        print(relevant_data)
        tissue_name=t[2:-1]
        tissue_name=tissue_name.replace(" ","_")
        for ct in Cell_types:
            print("cell type: ",ct)
            cell_type_name=ct[2:-1]
            cell_type_name=cell_type_name.replace(" ","_")
            num_cells=sum(relevant_data.obs.CellClass==ct)
            print(num_cells)
            if num_cells>100:
                exp[f'per_exp_{tissue_name}_{cell_type_name}']=(relevant_data.X[relevant_data.obs.CellClass==ct,:]>0).mean(axis=0).A1
                print('yay')
                exp[f'mean_exp_{tissue_name}_{cell_type_name}']=relevant_data.X[relevant_data.obs.CellClass==ct,:].mean(axis=0).A1
                print('yay again')
    
    exp_df=pd.DataFrame.from_dict(exp)
    exp_df["gene"]=adata.var["Gene"][adata.var["Gene"].isin(gene_list)].tolist()

    return exp_df

def create_exp_table_one_cond(gene_list,adata,cond):
    exp={}
    if cond=='CellClass':
        Cell_types= adata.obs.CellClass.unique().tolist()
        for ct in Cell_types:
            print("cell type: ",ct)
            relevant_data=adata[adata.obs.CellClass==ct,adata.var["Gene"].isin(gene_list)]
            cell_type_name=ct[2:-1]
            cell_type_name=cell_type_name.replace(" ","_")
            num_cells=sum(relevant_data.obs.CellClass==ct)
            print(num_cells)
            if num_cells>100:
                exp[f'per_exp_{cell_type_name}']=(relevant_data.X>0).mean(axis=0).A1
                print('yay')
                exp[f'mean_exp_{cell_type_name}']=relevant_data.X.mean(axis=0).A1
                print('yay again')
    elif cond=='Tissue':
        Tissues=adata.obs.Tissue.unique().tolist()
        for t in Tissues:
            print("tissue: ",t)
            relevant_data=adata[adata.obs.Tissue==t,adata.var["Gene"].isin(gene_list)]
            tissue_name=t[2:-1]
            tissue_name=tissue_name.replace(" ","_")
            num_cells=sum(relevant_data.obs.Tissue==t)
            print(num_cells)
            if num_cells>100:
                exp[f'per_exp_{tissue_name}']=(relevant_data.X>0).mean(axis=0).A1
                print('yay')
                exp[f'mean_exp_{tissue_name}']=relevant_data.X.mean(axis=0).A1
                print('yay again')
    elif cond=='Region':
        print("wow")
        Regions=adata.obs.Region.unique().tolist()
        for r in Regions:
            print("tissue: ",r)
            relevant_data=adata[adata.obs.Region==r,adata.var["Gene"].isin(gene_list)]
            tissue_name=r[2:-1]
            tissue_name=tissue_name.replace(" ","_")
            num_cells=sum(relevant_data.obs.Region==r)
            print(num_cells)
            if num_cells>100:
                exp[f'per_exp_{tissue_name}']=(relevant_data.X>0).mean(axis=0).A1
                print('yay')
                exp[f'mean_exp_{tissue_name}']=relevant_data.X.mean(axis=0).A1
                print('yay again')
    exp_df=pd.DataFrame.from_dict(exp)
    exp_df["gene"]=adata.var["Gene"][adata.var["Gene"].isin(gene_list)].tolist()

    return exp_df

# %%
exp_gene_list=find_exp_genes(hsg,adata)
# Out:
# AATBC 1431
# ABCB10 163874
# ABCC12 1788
# ABCC6 14401
# ABCD4 402549
# ABHD17A 212423
# AC062028.1 3053
# ACTR3B 345808
# ADARB1 201390
# ADORA2A-AS1 15849
# AFF3 829407
# AGR3 1550
# AHRR 10825
# AL592528.1 2707
# ALOX5 10286
# AMY1A 116
# AMY2B 69049
# ANAPC1 197023
# ANKRD20A2 4392
# ANKRD20A4 53300
# ANKRD30A 2448
# APEH 212530
# APOL1 1093
# APPBP2 578166
# AQP7 500
# AR 122948
# AREG 1924
# ARHGAP11B 979
# ARHGAP15 54878
# ARHGAP42 162039
# ASPM 251349
# ATP9B 479894
# BAZ2A 303784
# BMPR1A 594042
# BOLA2 428
# BOLL 6559
# BTNL2 6089
# C11orf80 415731
# C1orf229 9839
# C1orf61 1023939
# C20orf203 2049
# C21orf62-AS1 69089
# C2orf78 188
# C3orf36 109
# CAPN1 238408
# CATSPER2 115515
# CBWD2 250204
# CBWD3 41394
# CBWD5 181099
# CCDC127 272618
# CCDC74B 68692
# CCKAR 1699
# CCZ1B 275328
# CD24 1360474
# CD44 35439
# CDH12 346357
# CDK5RAP2 455792
# CELSR2 338626
# CEP170 966172
# CFAP99 6652
# CFC1 10022
# CHRFAM7A 7886
# CHRM3 113602
# CLEC10A 209
# CLTCL1 100981
# CNTNAP2 923466
# COMMD4 421250
# COPS7B 315622
# CRHR1 494
# CROCC 381265
# CSPG4 14836
# CXorf40A 69371
# DDR2 47294
# DDX11 141215
# DDX54 240685
# DGCR6L 437979
# DHRS4L2 114763
# DIXDC1 494306
# DMRTC1B 1080
# DNAH10OS 132
# DPY19L2 240453
# DRD5 1915
# DRD5 1915
# DSG3 297
# DUSP7 32879
# DYNC1I2 1173873
# E2F6 178738
# ECHDC3 86825
# EIF1AY 215422
# EIF3A 776207
# EIF3CL 12750
# ELN 97865
# ERCC5 10229
# ESPN 10621
# FAM153A 1534
# FAM156A 93738
# FAM182B 91250
# FAM228A 8143
# FAM25G 174
# FAM3C 424030
# FAM72C 42183
# FAM72D 63631
# FAM95B1 5458
# FAM95B1 5458
# FANK1 77787
# FBXO25 174540
# FCGR2B 197
# FCGR3A 6338
# FGF7 23324
# FKBP6 2426
# FKBP9 159906
# FMNL1 36402
# FMO2 1469
# FOXD4 2660
# FOXP2 637020
# FUT8 618609
# FXYD2 386
# GADD45G 519215
# GALT 109333
# GGT2 1764
# GIF 985
# GKAP1 352272
# GLG1 824397
# GLRA1 56893
# GLUD2 4309
# GNB5 365812
# GOLGA6L10 45710
# GOLGA8A 302042
# GOLGA8B 167566
# GPR33 185
# GPR42 106
# GPRIN2 13947
# GRAP 5196
# GRIN2C 8244
# GRIN3A 46879
# GTF2H2C 118023
# GTF3C2 182776
# GTF3C5 290765
# GYPA 7486
# GYPB 6974
# GYPC 197298
# GYPE 9429
# GZMA 1193
# HERC2 614360
# HGS 218970
# HIC2 153276
# HIST2H2AA4 2205
# HIST2H4A 6200
# HIST2H4B 1656
# HR 975
# HRH1 16225
# HTR3E 1861
# ICAM1 7258
# JAM3 659545
# KANK1 158451
# KANSL1 989070
# KCTD5 200747
# KIAA0319L 384615
# KIF18A 184369
# KIF26B 287665
# KITLG 146277
# KLHL24 725667
# KMT2C 943945
# KRT16 454
# KRT17 1365
# LCT 1645
# LEPR 124483
# LILRB3 5467
# LINC00240 26615
# LINC00314 501
# LINC00483 1613
# LINC00523 1056
# LINC00632 794424
# LINC01102 173125
# LMAN1L 1709
# LRPAP1 514982
# LRRC37A 36411
# LRRC37A3 195161
# LRRC58 315270
# MAL2 95635
# MALL 538
# MAOA 46278
# MAPT 580886
# MCPH1 483699
# MEP1A 246
# MICA 27509
# MPPE1 180579
# MRC1 6331
# MSI2 1091884
# MST1 36957
# MUC19 2251
# MUC20 2095
# MYCNOS 40827
# MYEOV 1125
# MYO7B 904
# NARF 692833
# NAT1 5407
# NBEA 965275
# NBPF1 214009
# NBPF10 10907
# NBPF12 190744
# NBPF14 103561
# NBPF15 93273
# NBPF3 111356
# NEK2 145941
# NEMF 691685
# NLN 380502
# NOMO3 39759
# NOTCH2NL 122
# NR1H2 238876
# NSF 302501
# NSUN5 150879
# NUDT4 331818
# NUTM2A 839
# NUTM2B 781
# NUTM2D 1186
# OBSCN 92071
# OCLN 16284
# OCM 5132
# OPHN1 479553
# OPRM1 31691
# OR10A2 1667
# OR2A42 362
# OR2A5 101
# OR4N2 277
# OR9Q1 1579
# OTOP1 360
# OTUD7A 258916
# OXGR1 3474
# PAIP1 811571
# PAK2 1005098
# PARG 399670
# PARP4 130405
# PBOV1 221
# PCDH15 149363
# PCDHA2 2481
# PCDHA5 269
# PCDHB10 70321
# PCDHB11 21533
# PCDHB12 27797
# PCDHB13 25641
# PCDHB14 13513
# PCDHB15 72445
# PCDHB6 12144
# PDCD4 512041
# PDCD6 136042
# PDE4DIP 275766
# PDGFD 207454
# PDPR 160860
# PDZD3 686
# PGA5 1109
# PI4KA 394782
# PKD1 185981
# PLEKHA3 336445
# PLEKHM1 84891
# PMP2 40989
# POM121 295986
# PPIP5K1 44880
# PPIP5K2 615512
# PPP1R12B 482900
# PRAME 383
# PRDM2 708544
# PRIM2 479675
# PRKCB 149450
# PRKCH 20566
# PRKDC 841200
# PTPN1 350499
# PVRIG 1435
# RAB21 385164
# RAB3B 134940
# RAB3IP 143429
# RAB6C 1861
# RANBP2 577889
# RASA4 967
# RB1CC1 811746
# RBM39 1333759
# RGPD2 69240
# RGPD3 4729
# RGPD5 1881
# RGPD6 1274
# RGPD8 76352
# RGS6 100404
# RIBC2 40706
# RIMBP3C 1882
# RNF123 129527
# SCML4 47268
# SDHA 508028
# SEC24C 205383
# SEC24D 195768
# SEMA5B 446016
# SERF1B 6214
# SFXN2 83726
# SH3PXD2A 311972
# SLC12A5 160137
# SLC13A1 676
# SLC29A4 276049
# SLC4A1 5582
# SLC4A1AP 285903
# SLC6A13 8437
# SLC6A15 324025
# SLC6A4 6199
# SLC7A6 181057
# SLX1B 3968
# SMAD5 459756
# SMN2 19045
# SNX29 412849
# SPAG5 115252
# SPANXA2-OT1 7147
# SPDYE1 141065
# SPDYE5 60127
# SPPL2B 240542
# SPRY3 24371
# SRGAP2B 267815
# SRGAP2C 296098
# SRP9 1536485
# ST6GAL2 421876
# STAG3 147648
# STRC 4723
# SULT1A1 87196
# SYT15 2308
# SYT15 2308
# SYT2 78875
# TBC1D26 2510
# TBC1D29 353
# TBC1D2B 88303
# TBC1D3 1084
# TBC1D8B 19066
# TBX20 12732
# TCAF2 4867
# TCF15 20720
# TDG 663728
# THOC3 296970
# TIGIT 1020
# TLK2 417503
# TLN1 366896
# TMEM128 349295
# TMEM183A 365996
# TMEM236 3495
# TMEM254 238944
# TMPRSS11E 292
# TNFRSF1B 10806
# TNFRSF9 845
# TPPP 35636
# TPTE 590
# TPTE2 44212
# TRIM50 696
# TRIM60 152
# TRIM74 1229
# UBC 1206260
# USP10 611332
# VAMP7 145816
# VIPR1 7280
# VNN2 646
# WDR66 57635
# WWOX 770609
# ZDHHC11 39573
# ZFC3H1 407908
# ZFP36L1 651626
# ZMYND11 584186
# ZNF286A 17913
# ZNF286A 17913
# ZNF322 290921
# ZNF492 139887
# ZNF519 355746
# ZNF595 130792
# ZNF638 1117497
# ZNF705G 200
# ZNF790 224754
# ZNF843 17145
# ARHGEF35 1051
# CD8B2 1005
# FAM72B 27981
# FCGR1B 4458
# GPR89B 166807
# GTF2IRD2B 232037
# CD8A 13493
# OR2A1 230
# IL32 3975
# MIR1-1HG 361
# AP000679.1 280
# LINC01006 283095
# LINC01547 21932
# SPTSSB 23028
# TDRG1 2794
# LINC02397 10653
# AC007608.1 1451
# SRRM2-AS1 21180
# EXOC3-AS1 88969
# LINC01615 280
# C5orf66 67936
# NTM-AS1 481
# MIR137HG 145768
# SATB2-AS1 26967
# AL031056.1 152
# LINC00458 114
# DICER1-AS1 88746
# UBR5-AS1 54230
# NR2F2-AS1 343454
# AC016576.1 2756
# AC022679.2 44495
# ZNF252P-AS1 6686
# TPM1-AS 3091
# TAPT1-AS1 184179
# GTSCR1 3301
# RARA-AS1 120223
# GATA6-AS1 601
# LINC00868 667
# LINC00602 949
# HYDIN 136671
# CFC1 10022
# PTPN20 48478
# FRMPD2 9567
# HIST2H2BF 85027
# CORO1A 192268
# TCAF1 320043
# NAIP 14725
# ROCK1 736194
# DUSP22 120767
# GTF2I 853561
# ARHGAP11A 175745
# NCF1 3133
# GPRIN2 13947

# %%
exp_gene_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 exp_gene_list
#
# NameError: name 'exp_gene_list' is not defined

# %%
exp_df=create_exp_table(exp_gene_list,adata)
# Out:
# tissue:  b'Cortex'
# View of AnnData object with n_obs × n_vars = 149628 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 366
# yay
# yay again
# cell type:  b'Fibroblast'
# 17
# cell type:  b'Glioblast'
# 8960
# yay
# yay again
# cell type:  b'Immune'
# 484
# yay
# yay again
# cell type:  b'Neuroblast'
# 29398
# yay
# yay again
# cell type:  b'Neural crest'
# 4
# cell type:  b'Neuron'
# 37749
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 12899
# yay
# yay again
# cell type:  b'Oligo'
# 156
# yay
# yay again
# cell type:  b'Radial glia'
# 59032
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 563
# yay
# yay again
# tissue:  b'Hypothalamus'
# View of AnnData object with n_obs × n_vars = 46159 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 391
# yay
# yay again
# cell type:  b'Fibroblast'
# 235
# yay
# yay again
# cell type:  b'Glioblast'
# 6295
# yay
# yay again
# cell type:  b'Immune'
# 1135
# yay
# yay again
# cell type:  b'Neuroblast'
# 4790
# yay
# yay again
# cell type:  b'Neural crest'
# 6
# cell type:  b'Neuron'
# 17795
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 561
# yay
# yay again
# cell type:  b'Oligo'
# 265
# yay
# yay again
# cell type:  b'Radial glia'
# 13139
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 1547
# yay
# yay again
# tissue:  b'Thalamus'
# View of AnnData object with n_obs × n_vars = 109641 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 180
# yay
# yay again
# cell type:  b'Fibroblast'
# 5
# cell type:  b'Glioblast'
# 3091
# yay
# yay again
# cell type:  b'Immune'
# 242
# yay
# yay again
# cell type:  b'Neuroblast'
# 14101
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 30210
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 18462
# yay
# yay again
# cell type:  b'Oligo'
# 31
# cell type:  b'Radial glia'
# 42840
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 479
# yay
# yay again
# tissue:  b'Ventral midbrain'
# View of AnnData object with n_obs × n_vars = 16396 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 137
# yay
# yay again
# cell type:  b'Fibroblast'
# 120
# yay
# yay again
# cell type:  b'Glioblast'
# 3362
# yay
# yay again
# cell type:  b'Immune'
# 469
# yay
# yay again
# cell type:  b'Neuroblast'
# 1178
# yay
# yay again
# cell type:  b'Neural crest'
# 1
# cell type:  b'Neuron'
# 6778
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 226
# yay
# yay again
# cell type:  b'Oligo'
# 475
# yay
# yay again
# cell type:  b'Radial glia'
# 3031
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 619
# yay
# yay again
# tissue:  b'Forebrain cortex'
# View of AnnData object with n_obs × n_vars = 14866 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 22
# cell type:  b'Fibroblast'
# 350
# yay
# yay again
# cell type:  b'Glioblast'
# 1226
# yay
# yay again
# cell type:  b'Immune'
# 62
# cell type:  b'Neuroblast'
# 2259
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 5115
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1563
# yay
# yay again
# cell type:  b'Oligo'
# 20
# cell type:  b'Radial glia'
# 4231
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 18
# tissue:  b'Subcortical forebrain'
# View of AnnData object with n_obs × n_vars = 53730 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 348
# yay
# yay again
# cell type:  b'Fibroblast'
# 23
# cell type:  b'Glioblast'
# 8268
# yay
# yay again
# cell type:  b'Immune'
# 417
# yay
# yay again
# cell type:  b'Neuroblast'
# 5656
# yay
# yay again
# cell type:  b'Neural crest'
# 22
# cell type:  b'Neuron'
# 23213
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 8343
# yay
# yay again
# cell type:  b'Oligo'
# 156
# yay
# yay again
# cell type:  b'Radial glia'
# 6410
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 874
# yay
# yay again
# tissue:  b'Forebrain'
# View of AnnData object with n_obs × n_vars = 193526 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 569
# yay
# yay again
# cell type:  b'Fibroblast'
# 6054
# yay
# yay again
# cell type:  b'Glioblast'
# 17149
# yay
# yay again
# cell type:  b'Immune'
# 455
# yay
# yay again
# cell type:  b'Neuroblast'
# 27558
# yay
# yay again
# cell type:  b'Neural crest'
# 59
# cell type:  b'Neuron'
# 62535
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 18147
# yay
# yay again
# cell type:  b'Oligo'
# 252
# yay
# yay again
# cell type:  b'Radial glia'
# 60263
# yay
# yay again
# cell type:  b'Placodes'
# 1
# cell type:  b'Vascular'
# 484
# yay
# yay again
# tissue:  b'Cerebellum'
# View of AnnData object with n_obs × n_vars = 142128 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 441
# yay
# yay again
# cell type:  b'Fibroblast'
# 292
# yay
# yay again
# cell type:  b'Glioblast'
# 8931
# yay
# yay again
# cell type:  b'Immune'
# 644
# yay
# yay again
# cell type:  b'Neuroblast'
# 44096
# yay
# yay again
# cell type:  b'Neural crest'
# 75
# cell type:  b'Neuron'
# 53815
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 10139
# yay
# yay again
# cell type:  b'Oligo'
# 151
# yay
# yay again
# cell type:  b'Radial glia'
# 22833
# yay
# yay again
# cell type:  b'Placodes'
# 191
# yay
# yay again
# cell type:  b'Vascular'
# 520
# yay
# yay again
# tissue:  b'Dorsal midbrain'
# View of AnnData object with n_obs × n_vars = 42918 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 79
# cell type:  b'Fibroblast'
# 8
# cell type:  b'Glioblast'
# 3488
# yay
# yay again
# cell type:  b'Immune'
# 96
# cell type:  b'Neuroblast'
# 5360
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 10299
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 177
# yay
# yay again
# cell type:  b'Oligo'
# 287
# yay
# yay again
# cell type:  b'Radial glia'
# 22973
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 151
# yay
# yay again
# tissue:  b'Medulla'
# View of AnnData object with n_obs × n_vars = 126659 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 546
# yay
# yay again
# cell type:  b'Fibroblast'
# 1448
# yay
# yay again
# cell type:  b'Glioblast'
# 14545
# yay
# yay again
# cell type:  b'Immune'
# 758
# yay
# yay again
# cell type:  b'Neuroblast'
# 32997
# yay
# yay again
# cell type:  b'Neural crest'
# 204
# yay
# yay again
# cell type:  b'Neuron'
# 38048
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1931
# yay
# yay again
# cell type:  b'Oligo'
# 1147
# yay
# yay again
# cell type:  b'Radial glia'
# 33556
# yay
# yay again
# cell type:  b'Placodes'
# 318
# yay
# yay again
# cell type:  b'Vascular'
# 1161
# yay
# yay again
# tissue:  b'Mesencephalon'
# View of AnnData object with n_obs × n_vars = 162383 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 810
# yay
# yay again
# cell type:  b'Fibroblast'
# 1411
# yay
# yay again
# cell type:  b'Glioblast'
# 7009
# yay
# yay again
# cell type:  b'Immune'
# 706
# yay
# yay again
# cell type:  b'Neuroblast'
# 22640
# yay
# yay again
# cell type:  b'Neural crest'
# 8
# cell type:  b'Neuron'
# 65652
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 928
# yay
# yay again
# cell type:  b'Oligo'
# 318
# yay
# yay again
# cell type:  b'Radial glia'
# 61766
# yay
# yay again
# cell type:  b'Placodes'
# 2
# cell type:  b'Vascular'
# 1133
# yay
# yay again
# tissue:  b'Pons/Cereb'
# View of AnnData object with n_obs × n_vars = 33373 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 80
# cell type:  b'Fibroblast'
# 450
# yay
# yay again
# cell type:  b'Glioblast'
# 3686
# yay
# yay again
# cell type:  b'Immune'
# 167
# yay
# yay again
# cell type:  b'Neuroblast'
# 5962
# yay
# yay again
# cell type:  b'Neural crest'
# 39
# cell type:  b'Neuron'
# 10516
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1205
# yay
# yay again
# cell type:  b'Oligo'
# 92
# cell type:  b'Radial glia'
# 10936
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 240
# yay
# yay again
# tissue:  b'Tel/diencephalon'
# View of AnnData object with n_obs × n_vars = 16795 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 13
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 17
# cell type:  b'Immune'
# 14
# cell type:  b'Neuroblast'
# 1346
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 4798
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 280
# yay
# yay again
# cell type:  b'Oligo'
# 0
# cell type:  b'Radial glia'
# 10297
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 30
# tissue:  b'Diencephalon'
# View of AnnData object with n_obs × n_vars = 34565 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 24
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 203
# yay
# yay again
# cell type:  b'Immune'
# 37
# cell type:  b'Neuroblast'
# 3828
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 11231
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 3179
# yay
# yay again
# cell type:  b'Oligo'
# 0
# cell type:  b'Radial glia'
# 15975
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 88
# tissue:  b'Pons'
# View of AnnData object with n_obs × n_vars = 61533 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 235
# yay
# yay again
# cell type:  b'Fibroblast'
# 212
# yay
# yay again
# cell type:  b'Glioblast'
# 8638
# yay
# yay again
# cell type:  b'Immune'
# 620
# yay
# yay again
# cell type:  b'Neuroblast'
# 12506
# yay
# yay again
# cell type:  b'Neural crest'
# 63
# cell type:  b'Neuron'
# 25615
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1594
# yay
# yay again
# cell type:  b'Oligo'
# 912
# yay
# yay again
# cell type:  b'Radial glia'
# 10144
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 994
# yay
# yay again
# tissue:  b'Striatum'
# View of AnnData object with n_obs × n_vars = 94538 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 253
# yay
# yay again
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 866
# yay
# yay again
# cell type:  b'Immune'
# 122
# yay
# yay again
# cell type:  b'Neuroblast'
# 4330
# yay
# yay again
# cell type:  b'Neural crest'
# 5
# cell type:  b'Neuron'
# 42115
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 5984
# yay
# yay again
# cell type:  b'Oligo'
# 14
# cell type:  b'Radial glia'
# 40560
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 289
# yay
# yay again
# tissue:  b'Telencephalon'
# View of AnnData object with n_obs × n_vars = 7052 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 15
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 94
# cell type:  b'Immune'
# 16
# cell type:  b'Neuroblast'
# 404
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 1429
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 332
# yay
# yay again
# cell type:  b'Oligo'
# 0
# cell type:  b'Radial glia'
# 4750
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 12
# tissue:  b'Hindbrain'
# View of AnnData object with n_obs × n_vars = 49284 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 147
# yay
# yay again
# cell type:  b'Fibroblast'
# 27
# cell type:  b'Glioblast'
# 59
# cell type:  b'Immune'
# 85
# cell type:  b'Neuroblast'
# 13056
# yay
# yay again
# cell type:  b'Neural crest'
# 17
# cell type:  b'Neuron'
# 17539
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1575
# yay
# yay again
# cell type:  b'Oligo'
# 5
# cell type:  b'Radial glia'
# 16518
# yay
# yay again
# cell type:  b'Placodes'
# 87
# cell type:  b'Vascular'
# 169
# yay
# yay again
# tissue:  b'Head'
# View of AnnData object with n_obs × n_vars = 6733 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 48
# cell type:  b'Fibroblast'
# 5915
# yay
# yay again
# cell type:  b'Glioblast'
# 0
# cell type:  b'Immune'
# 31
# cell type:  b'Neuroblast'
# 26
# cell type:  b'Neural crest'
# 282
# yay
# yay again
# cell type:  b'Neuron'
# 29
# cell type:  b'Neuronal IPC'
# 5
# cell type:  b'Oligo'
# 0
# cell type:  b'Radial glia'
# 95
# cell type:  b'Placodes'
# 274
# yay
# yay again
# cell type:  b'Vascular'
# 28
# tissue:  b'Pons/Medulla'
# View of AnnData object with n_obs × n_vars = 13493 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 228
# yay
# yay again
# cell type:  b'Fibroblast'
# 5
# cell type:  b'Glioblast'
# 5776
# yay
# yay again
# cell type:  b'Immune'
# 413
# yay
# yay again
# cell type:  b'Neuroblast'
# 3901
# yay
# yay again
# cell type:  b'Neural crest'
# 22
# cell type:  b'Neuron'
# 866
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 233
# yay
# yay again
# cell type:  b'Oligo'
# 865
# yay
# yay again
# cell type:  b'Radial glia'
# 570
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 614
# yay
# yay again
# tissue:  b'Subcortex'
# View of AnnData object with n_obs × n_vars = 28423 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 730
# yay
# yay again
# cell type:  b'Fibroblast'
# 17
# cell type:  b'Glioblast'
# 8315
# yay
# yay again
# cell type:  b'Immune'
# 220
# yay
# yay again
# cell type:  b'Neuroblast'
# 1329
# yay
# yay again
# cell type:  b'Neural crest'
# 26
# cell type:  b'Neuron'
# 11179
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 4440
# yay
# yay again
# cell type:  b'Oligo'
# 210
# yay
# yay again
# cell type:  b'Radial glia'
# 1304
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 653
# yay
# yay again
# tissue:  b'Enthorinal cortex'
# View of AnnData object with n_obs × n_vars = 10836 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 53
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 2235
# yay
# yay again
# cell type:  b'Immune'
# 54
# cell type:  b'Neuroblast'
# 2697
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 3084
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1248
# yay
# yay again
# cell type:  b'Oligo'
# 59
# cell type:  b'Radial glia'
# 1310
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 96
# tissue:  b'Hippocampus'
# View of AnnData object with n_obs × n_vars = 35060 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 176
# yay
# yay again
# cell type:  b'Fibroblast'
# 39
# cell type:  b'Glioblast'
# 7315
# yay
# yay again
# cell type:  b'Immune'
# 206
# yay
# yay again
# cell type:  b'Neuroblast'
# 6969
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 12966
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 4833
# yay
# yay again
# cell type:  b'Oligo'
# 362
# yay
# yay again
# cell type:  b'Radial glia'
# 1941
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 253
# yay
# yay again
# tissue:  b'Cortical hem'
# View of AnnData object with n_obs × n_vars = 6174 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 1
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 0
# cell type:  b'Immune'
# 15
# cell type:  b'Neuroblast'
# 702
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 6
# cell type:  b'Neuronal IPC'
# 169
# yay
# yay again
# cell type:  b'Oligo'
# 0
# cell type:  b'Radial glia'
# 5281
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 0
# tissue:  b'Frontotemporal cortex'
# View of AnnData object with n_obs × n_vars = 22235 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 66
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 2837
# yay
# yay again
# cell type:  b'Immune'
# 105
# yay
# yay again
# cell type:  b'Neuroblast'
# 5927
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 9130
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 2103
# yay
# yay again
# cell type:  b'Oligo'
# 145
# yay
# yay again
# cell type:  b'Radial glia'
# 1821
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 101
# yay
# yay again
# tissue:  b'Lower cortex'
# View of AnnData object with n_obs × n_vars = 18265 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 89
# cell type:  b'Fibroblast'
# 127
# yay
# yay again
# cell type:  b'Glioblast'
# 2819
# yay
# yay again
# cell type:  b'Immune'
# 132
# yay
# yay again
# cell type:  b'Neuroblast'
# 4876
# yay
# yay again
# cell type:  b'Neural crest'
# 16
# cell type:  b'Neuron'
# 6989
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1567
# yay
# yay again
# cell type:  b'Oligo'
# 101
# yay
# yay again
# cell type:  b'Radial glia'
# 1419
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 130
# yay
# yay again
# tissue:  b'Occipital cortex'
# View of AnnData object with n_obs × n_vars = 13340 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 47
# cell type:  b'Fibroblast'
# 3
# cell type:  b'Glioblast'
# 1901
# yay
# yay again
# cell type:  b'Immune'
# 71
# cell type:  b'Neuroblast'
# 3250
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 5579
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1274
# yay
# yay again
# cell type:  b'Oligo'
# 86
# cell type:  b'Radial glia'
# 1069
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 60
# tissue:  b'Upper cortex'
# View of AnnData object with n_obs × n_vars = 13475 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 53
# cell type:  b'Fibroblast'
# 104
# yay
# yay again
# cell type:  b'Glioblast'
# 1980
# yay
# yay again
# cell type:  b'Immune'
# 51
# cell type:  b'Neuroblast'
# 3039
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 5336
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1124
# yay
# yay again
# cell type:  b'Oligo'
# 56
# cell type:  b'Radial glia'
# 1692
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 40
# tissue:  b'Caudate-Putamen'
# View of AnnData object with n_obs × n_vars = 13177 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 14
# cell type:  b'Fibroblast'
# 0
# cell type:  b'Glioblast'
# 2608
# yay
# yay again
# cell type:  b'Immune'
# 8
# cell type:  b'Neuroblast'
# 9
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 7174
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 2971
# yay
# yay again
# cell type:  b'Oligo'
# 4
# cell type:  b'Radial glia'
# 369
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 20
# tissue:  b'Brain'
# View of AnnData object with n_obs × n_vars = 85997 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 21
# cell type:  b'Fibroblast'
# 1
# cell type:  b'Glioblast'
# 3
# cell type:  b'Immune'
# 145
# yay
# yay again
# cell type:  b'Neuroblast'
# 16235
# yay
# yay again
# cell type:  b'Neural crest'
# 0
# cell type:  b'Neuron'
# 25054
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 1818
# yay
# yay again
# cell type:  b'Oligo'
# 6
# cell type:  b'Radial glia'
# 42561
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 153
# yay
# yay again
# tissue:  b'Midbrain'
# View of AnnData object with n_obs × n_vars = 33466 × 416
#     obs: 'Age', 'CellClass', 'Region', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'sample_id', 'cluster_id', 'n_genes'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'n_cells'
#     uns: 'batch_condition', 'schema_version', 'title'
#     layers: 'ambiguous', 'spliced', 'unspliced'
# cell type:  b'Erythrocyte'
# 328
# yay
# yay again
# cell type:  b'Fibroblast'
# 2217
# yay
# yay again
# cell type:  b'Glioblast'
# 8
# cell type:  b'Immune'
# 121
# yay
# yay again
# cell type:  b'Neuroblast'
# 3793
# yay
# yay again
# cell type:  b'Neural crest'
# 19
# cell type:  b'Neuron'
# 6915
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 499
# yay
# yay again
# cell type:  b'Oligo'
# 0
# cell type:  b'Radial glia'
# 19344
# yay
# yay again
# cell type:  b'Placodes'
# 0
# cell type:  b'Vascular'
# 222
# yay
# yay again

# %%
exp_df
# Out:
#      per_exp_Cortex_Erythrocyte  mean_exp_Cortex_Erythrocyte  \
# 0                      0.000000                     0.000000
# 1                      0.005464                     0.005464
# 2                      0.030055                     0.030055
# 3                      0.000000                     0.000000
# 4                      0.000000                     0.000000
# ..                          ...                          ...
# 411                    0.000000                     0.000000
# 412                    0.005464                     0.005464
# 413                    0.000000                     0.000000
# 414                    0.032787                     0.032787
# 415                    0.442623                     2.237705
#
#      per_exp_Cortex_Glioblast  mean_exp_Cortex_Glioblast  \
# 0                    0.000112                   0.000112
# 1                    0.158482                   0.189955
# 2                    0.314844                   0.489286
# 3                    0.066406                   0.078237
# 4                    0.003125                   0.003125
# ..                        ...                        ...
# 411                  0.009933                   0.010937
# 412                  0.032478                   0.033036
# 413                  0.012723                   0.013393
# 414                  0.103460                   0.116853
# 415                  0.221652                   0.326451
#
#      per_exp_Cortex_Immune  mean_exp_Cortex_Immune  per_exp_Cortex_Neuroblast  \
# 0                 0.000000                0.000000                   0.000646
# 1                 0.090909                0.099174                   0.101231
# 2                 0.299587                0.444215                   0.205932
# 3                 0.002066                0.002066                   0.026532
# 4                 0.002066                0.002066                   0.022757
# ..                     ...                     ...                        ...
# 411               0.000000                0.000000                   0.004796
# 412               0.014463                0.016529                   0.052078
# 413               0.002066                0.002066                   0.015171
# 414               0.183884                0.219008                   0.074461
# 415               0.169421                0.256198                   0.112185
#
#      mean_exp_Cortex_Neuroblast  per_exp_Cortex_Neuron  \
# 0                      0.000646               0.000927
# 1                      0.114532               0.137328
# 2                      0.280563               0.206204
# 3                      0.031295               0.040690
# 4                      0.031159               0.132957
# ..                          ...                    ...
# 411                    0.005715               0.006729
# 412                    0.053609               0.060929
# 413                    0.016430               0.022146
# 414                    0.080414               0.087102
# 415                    0.137492               0.058094
#
#      mean_exp_Cortex_Neuron  ...  mean_exp_Midbrain_Neuroblast  \
# 0                  0.001007  ...                      0.000791
# 1                  0.160216  ...                      0.147640
# 2                  0.276140  ...                      0.396784
# 3                  0.050094  ...                      0.132085
# 4                  0.195105  ...                      0.599789
# ..                      ...  ...                           ...
# 411                0.008239  ...                      0.008173
# 412                0.063445  ...                      0.035856
# 413                0.024372  ...                      0.018719
# 414                0.094413  ...                      0.102557
# 415                0.066916  ...                      0.000000
#
#      per_exp_Midbrain_Neuron  mean_exp_Midbrain_Neuron  \
# 0                   0.000868                  0.000868
# 1                   0.142155                  0.162979
# 2                   0.318004                  0.500506
# 3                   0.139407                  0.191034
# 4                   0.255098                  0.558930
# ..                       ...                       ...
# 411                 0.008388                  0.010123
# 412                 0.042372                  0.044396
# 413                 0.029790                  0.032393
# 414                 0.100217                  0.120029
# 415                 0.000000                  0.000000
#
#      per_exp_Midbrain_Neuronal_IPC  mean_exp_Midbrain_Neuronal_IPC  \
# 0                         0.000000                        0.000000
# 1                         0.098196                        0.124248
# 2                         0.196393                        0.286573
# 3                         0.096192                        0.130261
# 4                         0.270541                        0.583166
# ..                             ...                             ...
# 411                       0.000000                        0.000000
# 412                       0.020040                        0.020040
# 413                       0.014028                        0.014028
# 414                       0.070140                        0.076152
# 415                       0.000000                        0.000000
#
#      per_exp_Midbrain_Radial_glia  mean_exp_Midbrain_Radial_glia  \
# 0                        0.000620                       0.000620
# 1                        0.146919                       0.180469
# 2                        0.274297                       0.421785
# 3                        0.059502                       0.074804
# 4                        0.014682                       0.021350
# ..                            ...                            ...
# 411                      0.004084                       0.004446
# 412                      0.033447                       0.034636
# 413                      0.012924                       0.014682
# 414                      0.105718                       0.128774
# 415                      0.000052                       0.000052
#
#      per_exp_Midbrain_Vascular  mean_exp_Midbrain_Vascular         gene
# 0                     0.000000                    0.000000      TNFRSF9
# 1                     0.081081                    0.081081        NBPF1
# 2                     0.292793                    0.472973    KIAA0319L
# 3                     0.013514                    0.018018        RAB3B
# 4                     0.000000                    0.000000     MIR137HG
# ..                         ...                         ...          ...
# 411                   0.000000                    0.000000  SPANXA2-OT1
# 412                   0.058559                    0.058559     CXorf40A
# 413                   0.031532                    0.040541        SPRY3
# 414                   0.148649                    0.189189        VAMP7
# 415                   0.018018                    0.022523       EIF1AY
#
# [416 rows x 463 columns]

# %%
exp_df.to_csv("/scratch200/reutj/data/exp_df_tissue_celltype_alldata.csv")

# %%
exp_df=pd.read_csv("/scratch200/reutj/data/exp_df_tissue_celltype_alldata.csv")

# %%
exp_gene_list=exp_df["gene"].to_list()

# %%
exp_df_region=create_exp_table_one_cond(exp_gene_list,adata,'Region')
# Out:
# wow
# tissue:  b'Telencephalon'
# 379181
# yay
# yay again
# tissue:  b'Diencephalon'
# 190365
# yay
# yay again
# tissue:  b'Midbrain'
# 255163
# yay
# yay again
# tissue:  b'Forebrain'
# 311939
# yay
# yay again
# tissue:  b'Cerebellum'
# 142128
# yay
# yay again
# tissue:  b'Medulla'
# 126659
# yay
# yay again
# tissue:  b'Pons'
# 94906
# yay
# yay again
# tissue:  b'Hindbrain'
# 62777
# yay
# yay again
# tissue:  b'Head'
# 6733
# yay
# yay again
# tissue:  b'Brain'
# 85997
# yay
# yay again

# %%
exp_df_region
# Out:
#      per_exp_Telencephalon  mean_exp_Telencephalon  per_exp_Diencephalon  \
# 0                 0.000527                0.000554              0.000452
# 1                 0.154314                0.188794              0.096846
# 2                 0.249767                0.367529              0.184209
# 3                 0.066530                0.086856              0.061130
# 4                 0.075639                0.136125              0.146807
# ..                     ...                     ...                   ...
# 411               0.005784                0.006965              0.003063
# 412               0.046231                0.048056              0.028283
# 413               0.020808                0.022654              0.007743
# 414               0.085574                0.096885              0.077309
# 415               0.154079                0.223532              0.176871
#
#      mean_exp_Diencephalon  per_exp_Midbrain  mean_exp_Midbrain  \
# 0                 0.000483          0.000455           0.000490
# 1                 0.110672          0.103585           0.120049
# 2                 0.244583          0.219209           0.305413
# 3                 0.077378          0.038854           0.050352
# 4                 0.299341          0.053358           0.085753
# ..                     ...               ...                ...
# 411               0.003372          0.003519           0.004099
# 412               0.029091          0.035358           0.036526
# 413               0.008079          0.010973           0.011781
# 414               0.084727          0.085189           0.095609
# 415               0.226717          0.129090           0.170914
#
#      per_exp_Forebrain  mean_exp_Forebrain  per_exp_Cerebellum  \
# 0             0.000343            0.000365            0.000584
# 1             0.129295            0.156790            0.164380
# 2             0.217450            0.307627            0.226205
# 3             0.061836            0.082535            0.099052
# 4             0.106322            0.202062            0.022459
# ..                 ...                 ...                 ...
# 411           0.003485            0.004129            0.004721
# 412           0.039396            0.040758            0.048330
# 413           0.012044            0.012810            0.018589
# 414           0.086405            0.096958            0.082271
# 415           0.042021            0.064743            0.164640
#
#      mean_exp_Cerebellum  ...  mean_exp_Medulla  per_exp_Pons  mean_exp_Pons  \
# 0               0.000704  ...          0.000253      0.000263       0.000295
# 1               0.201874  ...          0.088924      0.072282       0.079300
# 2               0.304690  ...          0.168689      0.160201       0.192759
# 3               0.139501  ...          0.127571      0.065096       0.086570
# 4               0.029030  ...          0.043021      0.040703       0.052747
# ..                   ...  ...               ...           ...            ...
# 411             0.005544  ...          0.001871      0.002708       0.002877
# 412             0.049828  ...          0.039484      0.031652       0.032348
# 413             0.019820  ...          0.006490      0.008440       0.008661
# 414             0.090686  ...          0.063856      0.060007       0.064011
# 415             0.218965  ...          0.133105      0.051272       0.063020
#
#      per_exp_Hindbrain  mean_exp_Hindbrain  per_exp_Head  mean_exp_Head  \
# 0             0.000637            0.000669      0.006981       0.009802
# 1             0.156060            0.188939      0.216545       0.256498
# 2             0.343454            0.513723      0.446161       0.713946
# 3             0.205617            0.372875      0.176147       0.276400
# 4             0.126464            0.255619      0.045002       0.154018
# ..                 ...                 ...           ...            ...
# 411           0.006722            0.008172      0.006535       0.007278
# 412           0.058254            0.060994      0.086737       0.092232
# 413           0.019737            0.021505      0.017823       0.018565
# 414           0.117814            0.136117      0.236150       0.286796
# 415           0.066091            0.090320      0.000000       0.000000
#
#      per_exp_Brain  mean_exp_Brain         gene
# 0         0.001279        0.001407      TNFRSF9
# 1         0.216054        0.267684        NBPF1
# 2         0.478784        0.823796    KIAA0319L
# 3         0.258451        0.488889        RAB3B
# 4         0.263998        0.779155     MIR137HG
# ..             ...             ...          ...
# 411       0.008919        0.010779  SPANXA2-OT1
# 412       0.071526        0.074677     CXorf40A
# 413       0.033117        0.036676        SPRY3
# 414       0.185530        0.224578        VAMP7
# 415       0.366327        0.550112       EIF1AY
#
# [416 rows x 21 columns]

# %%
exp_df_tissue=create_exp_table_one_cond(exp_gene_list,adata,'Tissue')
# Out:
# tissue:  b'Cortex'
# 149628
# yay
# yay again
# tissue:  b'Hypothalamus'
# 46159
# yay
# yay again
# tissue:  b'Thalamus'
# 109641
# yay
# yay again
# tissue:  b'Ventral midbrain'
# 16396
# yay
# yay again
# tissue:  b'Forebrain cortex'
# 14866
# yay
# yay again
# tissue:  b'Subcortical forebrain'
# 53730
# yay
# yay again
# tissue:  b'Forebrain'
# 193526
# yay
# yay again
# tissue:  b'Cerebellum'
# 142128
# yay
# yay again
# tissue:  b'Dorsal midbrain'
# 42918
# yay
# yay again
# tissue:  b'Medulla'
# 126659
# yay
# yay again
# tissue:  b'Mesencephalon'
# 162383
# yay
# yay again
# tissue:  b'Pons/Cereb'
# 33373
# yay
# yay again
# tissue:  b'Tel/diencephalon'
# 16795
# yay
# yay again
# tissue:  b'Diencephalon'
# 34565
# yay
# yay again
# tissue:  b'Pons'
# 61533
# yay
# yay again
# tissue:  b'Striatum'
# 94538
# yay
# yay again
# tissue:  b'Telencephalon'
# 7052
# yay
# yay again
# tissue:  b'Hindbrain'
# 49284
# yay
# yay again
# tissue:  b'Head'
# 6733
# yay
# yay again
# tissue:  b'Pons/Medulla'
# 13493
# yay
# yay again
# tissue:  b'Subcortex'
# 28423
# yay
# yay again
# tissue:  b'Enthorinal cortex'
# 10836
# yay
# yay again
# tissue:  b'Hippocampus'
# 35060
# yay
# yay again
# tissue:  b'Cortical hem'
# 6174
# yay
# yay again
# tissue:  b'Frontotemporal cortex'
# 22235
# yay
# yay again
# tissue:  b'Lower cortex'
# 18265
# yay
# yay again
# tissue:  b'Occipital cortex'
# 13340
# yay
# yay again
# tissue:  b'Upper cortex'
# 13475
# yay
# yay again
# tissue:  b'Caudate-Putamen'
# 13177
# yay
# yay again
# tissue:  b'Brain'
# 85997
# yay
# yay again
# tissue:  b'Midbrain'
# 33466
# yay
# yay again

# %%
exp_df_tissue
# Out:
#      per_exp_Cortex  mean_exp_Cortex  per_exp_Hypothalamus  \
# 0          0.000541         0.000575              0.000325
# 1          0.121154         0.143369              0.071449
# 2          0.213643         0.297003              0.152755
# 3          0.055117         0.068817              0.044152
# 4          0.040634         0.058752              0.077233
# ..              ...              ...                   ...
# 411        0.004144         0.004905              0.002101
# 412        0.044049         0.045446              0.021426
# 413        0.013981         0.015057              0.006824
# 414        0.082645         0.090377              0.054702
# 415        0.164648         0.251831              0.168418
#
#      mean_exp_Hypothalamus  per_exp_Thalamus  mean_exp_Thalamus  \
# 0                 0.000390          0.000584           0.000611
# 1                 0.078056          0.105590           0.122664
# 2                 0.189042          0.205042           0.284364
# 3                 0.053034          0.070448           0.091672
# 4                 0.102515          0.186007           0.414781
# ..                     ...               ...                ...
# 411               0.002426          0.003794           0.004168
# 412               0.021968          0.030573           0.031521
# 413               0.006998          0.009212           0.009659
# 414               0.059143          0.084530           0.093542
# 415               0.227821          0.165239           0.210542
#
#      per_exp_Ventral_midbrain  mean_exp_Ventral_midbrain  \
# 0                    0.000061                   0.000061
# 1                    0.038790                   0.042144
# 2                    0.111979                   0.139851
# 3                    0.019334                   0.020554
# 4                    0.018480                   0.020066
# ..                        ...                        ...
# 411                  0.001464                   0.001586
# 412                  0.021469                   0.022201
# 413                  0.005123                   0.005550
# 414                  0.047268                   0.051598
# 415                  0.181691                   0.236216
#
#      per_exp_Forebrain_cortex  mean_exp_Forebrain_cortex  ...  \
# 0                    0.000269                   0.000269  ...
# 1                    0.085968                   0.092560  ...
# 2                    0.130365                   0.148796  ...
# 3                    0.032019                   0.037064  ...
# 4                    0.057716                   0.074398  ...
# ..                        ...                        ...  ...
# 411                  0.001480                   0.001547  ...
# 412                  0.029194                   0.029598  ...
# 413                  0.006996                   0.006996  ...
# 414                  0.047895                   0.050652  ...
# 415                  0.000471                   0.000471  ...
#
#      mean_exp_Occipital_cortex  per_exp_Upper_cortex  mean_exp_Upper_cortex  \
# 0                     0.000750              0.000668               0.000668
# 1                     0.310270              0.266939               0.334026
# 2                     0.590180              0.440594               0.723711
# 3                     0.084483              0.186494               0.264861
# 4                     0.109820              0.151243               0.318145
# ..                         ...                   ...                    ...
# 411                   0.011769              0.008609               0.009870
# 412                   0.071139              0.090983               0.096549
# 413                   0.051574              0.060037               0.065751
# 414                   0.153223              0.158219               0.190501
# 415                   0.000075              0.000223               0.000223
#
#      per_exp_Caudate-Putamen  mean_exp_Caudate-Putamen  per_exp_Brain  \
# 0                   0.000531                  0.000531       0.001279
# 1                   0.324960                  0.458147       0.216054
# 2                   0.306291                  0.520149       0.478784
# 3                   0.064658                  0.094483       0.258451
# 4                   0.182211                  0.511725       0.263998
# ..                       ...                       ...            ...
# 411                 0.007134                  0.009259       0.008919
# 412                 0.039159                  0.039766       0.071526
# 413                 0.027700                  0.031570       0.033117
# 414                 0.090688                  0.111179       0.185530
# 415                 0.235183                  0.344767       0.366327
#
#      mean_exp_Brain  per_exp_Midbrain  mean_exp_Midbrain         gene
# 0          0.001407          0.000657           0.000717      TNFRSF9
# 1          0.267684          0.137423           0.165212        NBPF1
# 2          0.823796          0.276639           0.422190    KIAA0319L
# 3          0.488889          0.075211           0.101386        RAB3B
# 4          0.779155          0.099116           0.205582     MIR137HG
# ..              ...               ...                ...          ...
# 411        0.010779          0.005169           0.005857  SPANXA2-OT1
# 412        0.074677          0.034453           0.035887     CXorf40A
# 413        0.036676          0.016405           0.018168        SPRY3
# 414        0.224578          0.100430           0.121048        VAMP7
# 415        0.550112          0.000179           0.000209       EIF1AY
#
# [416 rows x 63 columns]

# %%
exp_df_tissue.to_csv("/scratch200/reutj/data/exp_df_tissue_alldata.csv")

# %%
exp_df_ct=create_exp_table_one_cond(exp_gene_list,adata,'CellClass')
# Out:
# cell type:  b'Erythrocyte'
# 6510
# yay
# yay again
# cell type:  b'Fibroblast'
# 19080
# yay
# yay again
# cell type:  b'Glioblast'
# 131684
# yay
# yay again
# cell type:  b'Immune'
# 8101
# yay
# yay again
# cell type:  b'Neuroblast'
# 284218
# yay
# yay again
# cell type:  b'Neural crest'
# 868
# yay
# yay again
# cell type:  b'Neuron'
# 558759
# yay
# yay again
# cell type:  b'Neuronal IPC'
# 109809
# yay
# yay again
# cell type:  b'Oligo'
# 6175
# yay
# yay again
# cell type:  b'Radial glia'
# 518030
# yay
# yay again
# cell type:  b'Placodes'
# 873
# yay
# yay again
# cell type:  b'Vascular'
# 11741
# yay
# yay again

# %%
exp_df_ct
# Out:
#      per_exp_Erythrocyte  mean_exp_Erythrocyte  per_exp_Fibroblast  \
# 0               0.000154              0.000154            0.001101
# 1               0.004762              0.004762            0.173532
# 2               0.050691              0.061598            0.352358
# 3               0.003994              0.004147            0.078721
# 4               0.004916              0.005069            0.010901
# ..                   ...                   ...                 ...
# 411             0.000000              0.000000            0.004612
# 412             0.005069              0.005069            0.058753
# 413             0.000307              0.000307            0.011216
# 414             0.039939              0.043011            0.165461
# 415             0.233333              0.944700            0.022222
#
#      mean_exp_Fibroblast  per_exp_Glioblast  mean_exp_Glioblast  \
# 0               0.001258           0.000311            0.000327
# 1               0.204507           0.147262            0.179513
# 2               0.530818           0.311579            0.478297
# 3               0.103512           0.061617            0.082295
# 4               0.013260           0.009667            0.012325
# ..                   ...                ...                 ...
# 411             0.005136           0.005726            0.006751
# 412             0.061740           0.039261            0.040536
# 413             0.011740           0.012781            0.013586
# 414             0.195440           0.096845            0.110127
# 415             0.031132           0.151674            0.212061
#
#      per_exp_Immune  mean_exp_Immune  per_exp_Neuroblast  mean_exp_Neuroblast  \
# 0          0.003333         0.005802            0.000443             0.000457
# 1          0.085545         0.097642            0.123060             0.143503
# 2          0.267992         0.391927            0.226865             0.320856
# 3          0.005925         0.006049            0.107421             0.174831
# 4          0.004814         0.004814            0.130952             0.295161
# ..              ...              ...                 ...                  ...
# 411        0.000000         0.000000            0.005242             0.006242
# 412        0.030243         0.031478            0.049715             0.051570
# 413        0.002592         0.002592            0.015861             0.017209
# 414        0.160968         0.195161            0.080660             0.089470
# 415        0.158869         0.227503            0.112171             0.140994
#
#      ...  mean_exp_Neuronal_IPC  per_exp_Oligo  mean_exp_Oligo  \
# 0    ...               0.000291       0.000486        0.000486
# 1    ...               0.206750       0.105101        0.125182
# 2    ...               0.313107       0.285020        0.422024
# 3    ...               0.095712       0.028826        0.034818
# 4    ...               0.241884       0.061377        0.084534
# ..   ...                    ...            ...             ...
# 411  ...               0.001794       0.002429        0.002753
# 412  ...               0.029998       0.034494        0.035304
# 413  ...               0.014416       0.033684        0.037085
# 414  ...               0.096149       0.072713        0.082105
# 415  ...               0.283838       0.205344        0.292794
#
#      per_exp_Radial_glia  mean_exp_Radial_glia  per_exp_Placodes  \
# 0               0.000388              0.000411          0.033219
# 1               0.121696              0.145084          0.178694
# 2               0.228491              0.326987          0.373425
# 3               0.064012              0.089012          0.293242
# 4               0.015700              0.023066          0.245132
# ..                   ...                   ...               ...
# 411             0.002471              0.002799          0.002291
# 412             0.033726              0.034627          0.113402
# 413             0.008328              0.008853          0.035510
# 414             0.094357              0.106563          0.184422
# 415             0.203399              0.289091          0.092784
#
#      mean_exp_Placodes  per_exp_Vascular  mean_exp_Vascular         gene
# 0             0.053837          0.002214           0.002385      TNFRSF9
# 1             0.213058          0.084490           0.094626        NBPF1
# 2             0.719359          0.322375           0.531982    KIAA0319L
# 3             0.619702          0.012946           0.016097        RAB3B
# 4             1.008018          0.005877           0.006218     MIR137HG
# ..                 ...               ...                ...          ...
# 411           0.003436          0.000767           0.000937  SPANXA2-OT1
# 412           0.124857          0.073844           0.084916     CXorf40A
# 413           0.038946          0.036539           0.039179        SPRY3
# 414           0.235968          0.214207           0.278171        VAMP7
# 415           0.123711          0.204667           0.302019       EIF1AY
#
# [416 rows x 25 columns]

# %%
exp_df_ct.to_csv("/scratch200/reutj/data/exp_df_cell_type_alldata.csv")

# %%
exp_df_tissue=pd.read_csv("/scratch200/reutj/data/exp_df_tissue_alldata.csv")

# %%
exp_df_tissue=exp_df_tissue.drop(columns=['Unnamed: 0'])

# %%
exp_df_tissue.columns[0].split("_")[2]
# Out:
# 'Cortex'

# %%
exp_df_tissue.columns[62]
# Out:
# 'gene'

# %%
tissue=[]
num_exp=[]
mean_per_exp=[]
mean_exp=[]
for i in range(0,exp_df_tissue.shape[1]-1,2):
    tissue.append("_".join(exp_df_tissue.columns[i].split("_")[2:]))
    num_exp.append(sum([j>0.05 for j in exp_df_tissue.iloc[:,i]]))
    mean_per_exp.append(np.mean(exp_df_tissue.iloc[:,i]))
    mean_exp.append(np.mean(exp_df_tissue.iloc[:,i+1]))
tissue_exp=pd.DataFrame({'tissue':tissue,'num_genes_exp':num_exp,'mean_per_exp':mean_per_exp,'mean_exp':mean_exp})
tissue_exp
# Out:
#                    tissue  num_genes_exp  mean_per_exp  mean_exp
# 0                  Cortex            183      0.111983  0.250484
# 1            Hypothalamus            159      0.073526  0.124293
# 2                Thalamus            184      0.100521  0.206753
# 3        Ventral_midbrain            140      0.057187  0.103027
# 4        Forebrain_cortex            147      0.074379  0.132811
# 5   Subcortical_forebrain            206      0.127418  0.333511
# 6               Forebrain            175      0.090166  0.174884
# 7              Cerebellum            194      0.112069  0.253450
# 8         Dorsal_midbrain            184      0.102316  0.185943
# 9                 Medulla            158      0.073638  0.136699
# 10          Mesencephalon            178      0.094670  0.199170
# 11             Pons/Cereb            140      0.066700  0.111695
# 12       Tel/diencephalon            179      0.105649  0.190713
# 13           Diencephalon            164      0.081826  0.143091
# 14                   Pons            168      0.087551  0.169075
# 15               Striatum            165      0.080850  0.147794
# 16          Telencephalon            165      0.087935  0.157256
# 17              Hindbrain            214      0.158644  0.419771
# 18                   Head            219      0.216440  0.606476
# 19           Pons/Medulla            190      0.095963  0.174253
# 20              Subcortex            208      0.138224  0.308859
# 21      Enthorinal_cortex            220      0.204838  0.650356
# 22            Hippocampus            212      0.161411  0.414077
# 23           Cortical_hem            190      0.129336  0.276072
# 24  Frontotemporal_cortex            207      0.178409  0.540669
# 25           Lower_cortex            214      0.173631  0.483969
# 26       Occipital_cortex            209      0.172349  0.508638
# 27           Upper_cortex            218      0.199347  0.641053
# 28        Caudate-Putamen            201      0.156411  0.402025
# 29                  Brain            220      0.187495  0.512269
# 30               Midbrain            202      0.136909  0.323770

# %%
region=[]
num_exp=[]
mean_per_exp=[]
mean_exp=[]
for i in range(0,exp_df_region.shape[1]-1,2):
    region.append("_".join(exp_df_region.columns[i].split("_")[2:]))
    num_exp.append(sum([j>0.05 for j in exp_df_region.iloc[:,i]]))
    mean_per_exp.append(np.mean(exp_df_region.iloc[:,i]))
    mean_exp.append(np.mean(exp_df_region.iloc[:,i+1]))
tissue_exp=pd.DataFrame({'region':region,'num_genes_exp':num_exp,'mean_per_exp':mean_per_exp,'mean_exp':mean_exp})
tissue_exp
# Out:
#           region  num_genes_exp  mean_per_exp  mean_exp
# 0  Telencephalon            196      0.121590  0.296014
# 1   Diencephalon            178      0.090581  0.175199
# 2       Midbrain            183      0.099087  0.207110
# 3      Forebrain            190      0.105408  0.227255
# 4     Cerebellum            194      0.112069  0.253450
# 5        Medulla            158      0.073638  0.136699
# 6           Pons            164      0.080219  0.148898
# 7      Hindbrain            214      0.145172  0.367001
# 8           Head            219      0.216440  0.606476
# 9          Brain            220      0.187495  0.512269

# %%
#total gene expressed:
sum(((adata.X[adata.obs.Region== "b'Telencephalon'",:]>0).sum(axis=0).A1)>100)
# Out:
# np.int64(25236)

# %%
adata.var
# Out:
#                 Chromosome       End        Gene     Start Strand  n_cells
# Accession
# ENSG00000238009          1    133723  AL627309.1     89295      -     1325
# ENSG00000239945          1     91105  AL627309.3     89551      -      339
# ENSG00000225880          1    827522   LINC00115    826206      -    18445
# ENSG00000230368          1    876903      FAM41C    868071      -     1581
# ENSG00000223764          1    921016  AL645608.1    916865      -     3872
# ...                    ...       ...         ...       ...    ...      ...
# ENSG00000198692          Y  20593154      EIF1AY  20575725      +   215422
# ENSG00000280969          Y  20781032      RPS4Y2  20756164      +      120
# ENSG00000235059          Y  22485592  AC008175.1  22438940      +       11
# ENSG00000205944          Y  23291356        DAZ2  23219434      +       58
# ENSG00000205916          Y  24907040        DAZ4  24833843      +        8
#
# [32020 rows x 6 columns]

# %%
adatab=adata.X[adata.obs.Region== "b'Telencephalon'",:].copy()

# %%
sum((adatab[:,adata.var["Gene"].isin(exp_gene_list)]>0).sum(axis=0).A1>100)
# Out:
# np.int64(379)

# %%
#hsg expressed / total gene expressed:
regions_df={'gene':exp_gene_list}
regions=adata.obs.Region.unique().to_list()
adatas=[]
for r in regions:
    print(r)
    adatas.append(adata.X[adata.obs.Region== r,:].copy())

# %%
adatas
# Out:
# [<Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 1132927054 stored elements and shape (379181, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 445469064 stored elements and shape (190365, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 667660248 stored elements and shape (255163, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 829396565 stored elements and shape (311939, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 397792329 stored elements and shape (142128, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 253747037 stored elements and shape (126659, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 201443475 stored elements and shape (94906, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 233042242 stored elements and shape (62777, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 37093011 stored elements and shape (6733, 32020)>,
#  <Compressed Sparse Row sparse matrix of dtype 'int16'
#  	with 404893368 stored elements and shape (85997, 32020)>]

# %%
totals={}
for r in range(len(regions)):
    region=regions[r][2:-1]
    print(region)
    totals[region]=sum(((adatas[r]>0).sum(axis=0).A1)>100)
# Out:
# Telencephalon
# Diencephalon
# Midbrain
# Forebrain
# Cerebellum
# Medulla
# Pons
# Hindbrain
# Head
# Brain
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[171], line 3
#       1 totals={}
#       2 for r in range(len(region)):
# ----> 3     region=regions[r][2:-1]
#       4     print(region)
#       5     totals[region]=sum(((adatas[r]>0).sum(axis=0).A1)>100)
#
# IndexError: list index out of range

# %%
region
# Out:
# 'Brain'

# %%
for i in exp_gene_list:
    print(i)
    for r in range(len(regions)):
        region=regions[r][2:-1]
        print(region)
        hsg_exp=sum(((adatas[r][:,adata.var["Gene"].isin(exp_gene_list)]>0).sum(axis=0).A1)>100)
        print('yay')#number of hsg genes expressing in above 100 cells
        regions_df[f'norm_exp_reg_{region}']=hsg_exp/totals[region]

regions_df=pd.DataFrame.from_dict(regions_df)
regions_df
# Out:
# TNFRSF9
# Telencephalon
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[169], line 6
#       4 region=regions[r][2:-1]
#       5 print(region)
# ----> 6 total=sum(((adatas[r]>0).sum(axis=0).A1)>100)
#       7 print('yay')#number of genes expressing in above 100 cells
#       8 hsg_exp=sum(((adatas[r][:,adata.var["Gene"].isin(exp_gene_list)]>0).sum(axis=0).A1)>100)
#
# File /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/scipy/sparse/_compressed.py:646, in _cs_matrix.sum(self, axis, dtype, out)
#     643     return ret.sum(axis=(), dtype=dtype, out=out)
#     644 else:
#     645     # _spbase handles the situations when axis is in {None, -2, -1, 0, 1}
# --> 646     return _spbase.sum(self, axis=axis, dtype=dtype, out=out)
#
# File /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/scipy/sparse/_base.py:1108, in _spbase.sum(self, axis, dtype, out)
#    1105 # axis = 0 or 1 now
#    1106 if axis == 0:
#    1107     # sum over columns
# -> 1108     ret = self._ascontainer(
#    1109         np.ones((1, M), dtype=res_dtype)
#    1110     ) @ self
#    1111 else:
#    1112     # sum over rows
#    1113     ret = self @ self._ascontainer(
#    1114         np.ones((N, 1), dtype=res_dtype)
#    1115     )
#
# File /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/scipy/sparse/_base.py:675, in _spbase.__rmatmul__(self, other)
#     672 if isscalarlike(other):
#     673     raise ValueError("Scalar operands are not allowed, "
#     674                      "use '*' instead")
# --> 675 return self._rmatmul_dispatch(other)
#
# File /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/scipy/sparse/_base.py:656, in _spbase._rmatmul_dispatch(self, other)
#     654 except AttributeError:
#     655     tr = np.asarray(other).transpose()
# --> 656 ret = self.transpose()._matmul_dispatch(tr)
#     657 if ret is NotImplemented:
#     658     return NotImplemented
#
# File /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/scipy/sparse/_base.py:600, in _spbase._matmul_dispatch(self, other)
#     597 if other.shape != (N,) and other.shape != (N, 1):
#     598     raise ValueError('dimension mismatch')
# --> 600 result = self._matmul_vector(np.ravel(other))
#     602 if isinstance(other, np.matrix):
#     603     result = self._ascontainer(result)
#
# File /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/scipy/sparse/_compressed.py:492, in _cs_matrix._matmul_vector(self, other)
#     490 # csr_matvec or csc_matvec
#     491 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 492 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     494 return result[0] if self.ndim == 1 else result
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
tissue_exp=tissue_exp.sort_values(by='num_genes_exp', ascending=False)
plt.xticks(rotation=90)
plt.bar(tissue_exp.tissue[:15],tissue_exp.num_genes_exp[:15])
# Out:
# <BarContainer object of 15 artists>

# %%
tissue_exp=tissue_exp.sort_values(by='mean_per_exp', ascending=False)
plt.xticks(rotation=90)
plt.bar(tissue_exp.tissue[:15],tissue_exp.mean_per_exp[:15])
# Out:
# <BarContainer object of 15 artists>

# %%
tissue_exp=tissue_exp.sort_values(by='mean_exp', ascending=False)
plt.xticks(rotation=90)
plt.bar(tissue_exp.tissue[:15],tissue_exp.mean_exp[:15])
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# #### since some of the terms are confusiong lets create parent categories:
# * Cerebral Cortex/Neocortex:
# Cortex,
# Forebrain cortex,
# Enthorinal cortex,
# Cortical hem,
# Frontotemporal cortex,
# Lower cortex,
# Occipital cortex,
# Upper cortex
# * Subcortical Regions:
# Hippocampus,
# Striatum,
# Caudate-Putamen,
# Subcortex,
# Subcortical forebrain
# * Diencephalon:
# Thalamus,
# Diencephalon,
# Tel/diencephalon
# * Midbrain:
# Ventral midbrain,
# Dorsal midbrain,
# Mesencephalon,
# Midbrain
# * Hindbrain:
# Hindbrain,
# Cerebellum,
# Pons,
# Medulla,
# Pons/Medulla,
# Pons/Cereb

# %%
tissues = {
    "Cerebral_Cortex": [
        "Cortex",
        "Forebrain_cortex",
        "Enthorinal_cortex",
        "Cortical_hem",
        "Frontotemporal_cortex",
        "Lower_cortex",
        "Occipital_cortex",
        "Upper_cortex"
    ],
    "Subcortical_Regions": [
        "Hippocampus",
        "Striatum",
        "Caudate-Putamen",
        "Subcortex",
        "Subcortical_forebrain"
    ],
    "Diencephalon": [
        "Thalamus",
        "Diencephalon",
        "Tel/diencephalon"
    ],
    "Midbrain": [
        "Ventral_midbrain",
        "Dorsal_midbrain",
        "Mesencephalon",
        "Midbrain"
    ],
    "Hindbrain": [
        "Hindbrain",
        "Cerebellum",
        "Pons",
        "Medulla",
        "Pons/Medulla",
        "Pons/Cereb"
    ]
}

# %%
tissue_exp2={}
for t in list(tissues.keys()):
    subtissues=tissues[t]
    num_exp=[]
    for i in subtissues :
        num_exp.extend(exp_df_tissue.loc[exp_df_tissue[f'per_exp_{i}']>0.05,"gene"].tolist())
    num_exp=list(set(num_exp))
    tissue_exp2[t]=len(num_exp)
tissue_exp2=pd.DataFrame({'region':tissue_exp2.keys(),'num_genes':tissue_exp2.values()})
tissue_exp2
# Out:
#                 region  num_genes
# 0      Cerebral_Cortex        230
# 1  Subcortical_Regions        220
# 2         Diencephalon        190
# 3             Midbrain        205
# 4            Hindbrain        225

# %%
tissue_exp2=tissue_exp2.sort_values(by='num_genes', ascending=False)
plt.xticks(rotation=90)
plt.bar(tissue_exp2.region,tissue_exp2.num_genes)
# Out:
# <BarContainer object of 5 artists>

# %%
#celltype

# %%
exp_df_ct=pd.read_csv("/scratch200/reutj/data/exp_df_cell_type_alldata.csv")

# %%
exp_df_ct=exp_df_ct.drop(columns=['Unnamed: 0'])

# %%
cell_types=[]
num_exp=[]
mean_per_exp=[]
mean_exp=[]
for i in range(0,exp_df_ct.shape[1]-1,2):
    cell_types.append("_".join(exp_df_ct.columns[i].split("_")[2:]))
    num_exp.append(sum([j>0.05 for j in exp_df_ct.iloc[:,i]]))
    mean_per_exp.append(np.mean(exp_df_ct.iloc[:,i]))
    mean_exp.append(np.mean(exp_df_ct.iloc[:,i+1]))
ct_exp=pd.DataFrame({'cell_type':cell_types,'num_genes_exp':num_exp,'mean_per_exp':mean_per_exp,'mean_exp':mean_exp})
ct_exp
# Out:
#        cell_type  num_genes_exp  mean_per_exp  mean_exp
# 0    Erythrocyte             58      0.030845  0.101277
# 1     Fibroblast            211      0.171293  0.431812
# 2      Glioblast            202      0.122057  0.277537
# 3         Immune            174      0.111748  0.265878
# 4     Neuroblast            174      0.106300  0.242916
# 5   Neural_crest            211      0.168253  0.469370
# 6         Neuron            173      0.103871  0.240819
# 7   Neuronal_IPC            189      0.116906  0.266282
# 8          Oligo            187      0.112453  0.265039
# 9    Radial_glia            190      0.109900  0.233334
# 10      Placodes            210      0.163296  0.513658
# 11      Vascular            195      0.138418  0.355024

# %%
ct_exp=ct_exp.sort_values(by='num_genes_exp', ascending=False)
plt.xticks(rotation=90)
plt.bar(ct_exp.cell_type,ct_exp.num_genes_exp)
# Out:
# <BarContainer object of 12 artists>

# %%
ct_exp=ct_exp.sort_values(by='mean_per_exp', ascending=False)
plt.xticks(rotation=90)
plt.bar(ct_exp.cell_type,ct_exp.mean_per_exp)
# Out:
# <BarContainer object of 12 artists>

# %%
ct_exp=ct_exp.sort_values(by='mean_exp', ascending=False)
plt.xticks(rotation=90)
plt.bar(ct_exp.cell_type,ct_exp.mean_exp)
# Out:
# <BarContainer object of 12 artists>

# %%
exp_df_ct=pd.read_csv("/scratch200/reutj/data/exp_df_cell_type_alldata.csv")

# %%
exp_df_ct
# Out:
#      Unnamed: 0  per_exp_Erythrocyte  mean_exp_Erythrocyte  \
# 0             0             0.000154              0.000154
# 1             1             0.004762              0.004762
# 2             2             0.050691              0.061598
# 3             3             0.003994              0.004147
# 4             4             0.004916              0.005069
# ..          ...                  ...                   ...
# 411         411             0.000000              0.000000
# 412         412             0.005069              0.005069
# 413         413             0.000307              0.000307
# 414         414             0.039939              0.043011
# 415         415             0.233333              0.944700
#
#      per_exp_Fibroblast  mean_exp_Fibroblast  per_exp_Glioblast  \
# 0              0.001101             0.001258           0.000311
# 1              0.173532             0.204507           0.147262
# 2              0.352358             0.530818           0.311579
# 3              0.078721             0.103512           0.061617
# 4              0.010901             0.013260           0.009667
# ..                  ...                  ...                ...
# 411            0.004612             0.005136           0.005726
# 412            0.058753             0.061740           0.039261
# 413            0.011216             0.011740           0.012781
# 414            0.165461             0.195440           0.096845
# 415            0.022222             0.031132           0.151674
#
#      mean_exp_Glioblast  per_exp_Immune  mean_exp_Immune  per_exp_Neuroblast  \
# 0              0.000327        0.003333         0.005802            0.000443
# 1              0.179513        0.085545         0.097642            0.123060
# 2              0.478297        0.267992         0.391927            0.226865
# 3              0.082295        0.005925         0.006049            0.107421
# 4              0.012325        0.004814         0.004814            0.130952
# ..                  ...             ...              ...                 ...
# 411            0.006751        0.000000         0.000000            0.005242
# 412            0.040536        0.030243         0.031478            0.049715
# 413            0.013586        0.002592         0.002592            0.015861
# 414            0.110127        0.160968         0.195161            0.080660
# 415            0.212061        0.158869         0.227503            0.112171
#
#      ...  mean_exp_Neuronal_IPC  per_exp_Oligo  mean_exp_Oligo  \
# 0    ...               0.000291       0.000486        0.000486
# 1    ...               0.206750       0.105101        0.125182
# 2    ...               0.313107       0.285020        0.422024
# 3    ...               0.095712       0.028826        0.034818
# 4    ...               0.241884       0.061377        0.084534
# ..   ...                    ...            ...             ...
# 411  ...               0.001794       0.002429        0.002753
# 412  ...               0.029998       0.034494        0.035304
# 413  ...               0.014416       0.033684        0.037085
# 414  ...               0.096149       0.072713        0.082105
# 415  ...               0.283838       0.205344        0.292794
#
#      per_exp_Radial_glia  mean_exp_Radial_glia  per_exp_Placodes  \
# 0               0.000388              0.000411          0.033219
# 1               0.121696              0.145084          0.178694
# 2               0.228491              0.326987          0.373425
# 3               0.064012              0.089012          0.293242
# 4               0.015700              0.023066          0.245132
# ..                   ...                   ...               ...
# 411             0.002471              0.002799          0.002291
# 412             0.033726              0.034627          0.113402
# 413             0.008328              0.008853          0.035510
# 414             0.094357              0.106563          0.184422
# 415             0.203399              0.289091          0.092784
#
#      mean_exp_Placodes  per_exp_Vascular  mean_exp_Vascular         gene
# 0             0.053837          0.002214           0.002385      TNFRSF9
# 1             0.213058          0.084490           0.094626        NBPF1
# 2             0.719359          0.322375           0.531982    KIAA0319L
# 3             0.619702          0.012946           0.016097        RAB3B
# 4             1.008018          0.005877           0.006218     MIR137HG
# ..                 ...               ...                ...          ...
# 411           0.003436          0.000767           0.000937  SPANXA2-OT1
# 412           0.124857          0.073844           0.084916     CXorf40A
# 413           0.038946          0.036539           0.039179        SPRY3
# 414           0.235968          0.214207           0.278171        VAMP7
# 415           0.123711          0.204667           0.302019       EIF1AY
#
# [416 rows x 26 columns]

# %%
exp_df_ct=exp_df_ct.drop(columns=['Unnamed: 0'])

# %%
adata.obs.CellClass
# Out:
# CellID
# b'10X89_1:ACGAGGAAGAGCCTAG'     b'Erythrocyte'
# b'10X89_1:ACGCCAGTCGATAGAA'     b'Erythrocyte'
# b'10X89_1:CTTCTCTAGTCAAGGC'     b'Erythrocyte'
# b'10X89_1:GGGCACTAGCGATATA'     b'Erythrocyte'
# b'10X89_1:TTCTACAAGGTGTGGT'     b'Erythrocyte'
#                                      ...
# b'10X302_7:AGAGAATAGAGGATCC'       b'Vascular'
# b'10X302_8:AAGCCATTCCACCTCA'       b'Vascular'
# b'10X302_8:ACGGTTAGTTAGGCCC'       b'Vascular'
# b'10X302_8:CATGCCTCAACCCGCA'       b'Vascular'
# b'10X302_8:CCTTTGGCAACGATTC'       b'Vascular'
# Name: CellClass, Length: 1655848, dtype: category
# Categories (12, object): ['b'Erythrocyte'', 'b'Fibroblast'', 'b'Glioblast'', 'b'Immune'', ..., 'b'Oligo'', 'b'Placodes'', 'b'Radial glia'', 'b'Vascular'']

# %%
#get top10 percentile
celltypes=adata.obs.CellClass.unique().tolist()
p90={}
for i in celltypes:
    celltype=i[2:-1]
    p90[celltype]=np.percentile(adata.X[adata.obs.CellClass==i,:].mean(axis=0).A1,90)

# %%
p90
# Out:
# {'Erythrocyte': np.float64(0.06497695852534603),
#  'Fibroblast': np.float64(0.9086373165617749),
#  'Glioblast': np.float64(0.5222957990336169),
#  'Immune': np.float64(0.5120478953215658),
#  'Neuroblast': np.float64(0.4230678563634293),
#  'Neural crest': np.float64(1.0552995391705053),
#  'Neuron': np.float64(0.3991073074441527),
#  'Neuronal IPC': np.float64(0.5133841488400925),
#  'Oligo': np.float64(0.44908502024291685),
#  'Radial glia': np.float64(0.48337876184872247),
#  'Placodes': np.float64(0.9932416953035506),
#  'Vascular': np.float64(0.8170087726769283)}

# %%
adata.obs.CellClass.unique()
# Out:
# ['b'Erythrocyte'', 'b'Fibroblast'', 'b'Glioblast'', 'b'Immune'', 'b'Neuroblast'', ..., 'b'Neuronal IPC'', 'b'Oligo'', 'b'Radial glia'', 'b'Placodes'', 'b'Vascular'']
# Length: 12
# Categories (12, object): ['b'Erythrocyte'', 'b'Fibroblast'', 'b'Glioblast'', 'b'Immune'', ..., 'b'Oligo'', 'b'Placodes'', 'b'Radial glia'', 'b'Vascular'']

# %%
top10={}
for i in range(len(celltypes)):
    ind=i*2+1
    for j in exp_df_ct["gene"]:
        ct=celltypes[i][2:-1]
        exp=float(exp_df_ct.iloc[np.where(exp_df_ct["gene"]==j)[0],ind])
        if ct not in top10:
            top10[ct]=[bool(exp>=p90[ct])]
        else:
            top10[ct].append(bool(exp>=p90[ct]))
# Out:
# /tmp/ipykernel_1523753/3649733717.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   exp=float(exp_df_ct.iloc[np.where(exp_df_ct["gene"]==j)[0],ind])

# %%
top10_ct_df=pd.DataFrame.from_dict(top10)
top10_ct_df["gene"]=exp_df_ct["gene"]
top10_ct_df
# Out:
#      Erythrocyte  Fibroblast  Glioblast  Immune  Neuroblast  Neural crest  \
# 0          False       False      False   False       False         False
# 1          False       False      False   False       False         False
# 2          False       False      False   False       False         False
# 3          False       False      False   False       False         False
# 4          False       False      False   False       False         False
# ..           ...         ...        ...     ...         ...           ...
# 411        False       False      False   False       False         False
# 412        False       False      False   False       False         False
# 413        False       False      False   False       False         False
# 414        False       False      False   False       False         False
# 415         True       False      False   False       False         False
#
#      Neuron  Neuronal IPC  Oligo  Radial glia  Placodes  Vascular         gene
# 0     False         False  False        False     False     False      TNFRSF9
# 1     False         False  False        False     False     False        NBPF1
# 2     False         False  False        False     False     False    KIAA0319L
# 3     False         False  False        False     False     False        RAB3B
# 4     False         False  False        False      True     False     MIR137HG
# ..      ...           ...    ...          ...       ...       ...          ...
# 411   False         False  False        False     False     False  SPANXA2-OT1
# 412   False         False  False        False     False     False     CXorf40A
# 413   False         False  False        False     False     False        SPRY3
# 414   False         False  False        False     False     False        VAMP7
# 415   False         False  False        False     False     False       EIF1AY
#
# [416 rows x 13 columns]

# %%
top10_ct_df
# Out:
#      Erythrocyte  Fibroblast  Glioblast  Immune  Neuroblast  Neural crest  \
# 0          False       False      False   False       False         False
# 1          False       False      False   False       False         False
# 2          False       False      False   False       False         False
# 3          False       False      False   False       False         False
# 4          False       False      False   False       False         False
# ..           ...         ...        ...     ...         ...           ...
# 411        False       False      False   False       False         False
# 412        False       False      False   False       False         False
# 413        False       False      False   False       False         False
# 414        False       False      False   False       False         False
# 415         True       False      False   False       False         False
#
#      Neuron  Neuronal IPC  Oligo  Radial glia  Placodes  Vascular         gene
# 0     False         False  False        False     False     False      TNFRSF9
# 1     False         False  False        False     False     False        NBPF1
# 2     False         False  False        False     False     False    KIAA0319L
# 3     False         False  False        False     False     False        RAB3B
# 4     False         False  False        False      True     False     MIR137HG
# ..      ...           ...    ...          ...       ...       ...          ...
# 411   False         False  False        False     False     False  SPANXA2-OT1
# 412   False         False  False        False     False     False     CXorf40A
# 413   False         False  False        False     False     False        SPRY3
# 414   False         False  False        False     False     False        VAMP7
# 415   False         False  False        False     False     False       EIF1AY
#
# [416 rows x 13 columns]

# %%
top10_ct_df["gene"][3]
# Out:
# 'RAB3B'

# %%
celltypes[int(np.where(top10_ct_df.iloc[4,:12])[0])]
# Out:
# /tmp/ipykernel_1523753/3921544999.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   celltypes[int(np.where(top10_ct_df.iloc[4,:12])[0])]
# "b'Placodes'"

# %%
uniqly_expressed=[]
for i in range(416):
    if sum(top10_ct_df.iloc[i,:12])==1:
        ct=celltypes[int(np.where(top10_ct_df.iloc[i,:12])[0])][2:-1]
        print(top10_ct_df["gene"][i],"gene expressed top uniquly in: ", ct)
        uniqly_expressed.append((top10_ct_df["gene"][i],ct))
# Out:
# MIR137HG gene expressed top uniquly in:  Placodes
# SRGAP2B gene expressed top uniquly in:  Immune
# FCGR3A gene expressed top uniquly in:  Immune
# NEK2 gene expressed top uniquly in:  Neuronal IPC
# ABCB10 gene expressed top uniquly in:  Erythrocyte
# ESPN gene expressed top uniquly in:  Erythrocyte
# TNFRSF1B gene expressed top uniquly in:  Immune
# FCGR1B gene expressed top uniquly in:  Immune
# SRGAP2C gene expressed top uniquly in:  Immune
# PDE4DIP gene expressed top uniquly in:  Placodes
# TMEM183A gene expressed top uniquly in:  Erythrocyte
# CHRM3 gene expressed top uniquly in:  Oligo
# MRC1 gene expressed top uniquly in:  Immune
# CAPN1 gene expressed top uniquly in:  Erythrocyte
# SLC6A13 gene expressed top uniquly in:  Fibroblast
# BAZ2A gene expressed top uniquly in:  Erythrocyte
# DPY19L2 gene expressed top uniquly in:  Oligo
# KITLG gene expressed top uniquly in:  Vascular
# PRKCH gene expressed top uniquly in:  Vascular
# OTUD7A gene expressed top uniquly in:  Placodes
# GOLGA8A gene expressed top uniquly in:  Oligo
# CSPG4 gene expressed top uniquly in:  Vascular
# ARHGAP11A gene expressed top uniquly in:  Neuronal IPC
# IL32 gene expressed top uniquly in:  Vascular
# CORO1A gene expressed top uniquly in:  Immune
# SLC7A6 gene expressed top uniquly in:  Immune
# SLC4A1 gene expressed top uniquly in:  Erythrocyte
# FMNL1 gene expressed top uniquly in:  Immune
# TLK2 gene expressed top uniquly in:  Neuronal IPC
# ZNF519 gene expressed top uniquly in:  Neuronal IPC
# ABHD17A gene expressed top uniquly in:  Vascular
# ICAM1 gene expressed top uniquly in:  Immune
# NR1H2 gene expressed top uniquly in:  Erythrocyte
# TCF15 gene expressed top uniquly in:  Vascular
# PTPN1 gene expressed top uniquly in:  Immune
# HRH1 gene expressed top uniquly in:  Immune
# RNF123 gene expressed top uniquly in:  Erythrocyte
# GYPE gene expressed top uniquly in:  Erythrocyte
# GYPB gene expressed top uniquly in:  Erythrocyte
# GYPA gene expressed top uniquly in:  Erythrocyte
# FAM3C gene expressed top uniquly in:  Neural crest
# LINC01006 gene expressed top uniquly in:  Erythrocyte
# FKBP9 gene expressed top uniquly in:  Vascular
# ACTR3B gene expressed top uniquly in:  Glioblast
# PMP2 gene expressed top uniquly in:  Oligo
# KANK1 gene expressed top uniquly in:  Oligo
# EIF1AY gene expressed top uniquly in:  Erythrocyte
# /tmp/ipykernel_1523753/2884793817.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ct=celltypes[int(np.where(top10_ct_df.iloc[i,:12])[0])][2:-1]

# %%
#לצייר בוקספלוט

# %%
for i in range(416):
    if sum(top10_ct_df.iloc[i,:12])==1:
        ct=celltypes[int(np.where(top10_ct_df.iloc[i,:12])[0])][2:-1]
        print(top10_ct_df["gene"][i],"gene expressed top uniquly in: ", ct)
        uniqly_expressed.append((top10_ct_df["gene"][i],ct))

# %%
#do the same for tissues
tissuetypes=adata.obs.Tissue.unique().tolist()
p90_t={}
for i in tissuetypes:
    tissuetype=i[2:-1]
    p90_t[tissuetype]=np.percentile(adata.X[adata.obs.Tissue==i,:].mean(axis=0).A1,90)

# %%
p90_t
# Out:
# {'Cortex': np.float64(0.43855294463589967),
#  'Hypothalamus': np.float64(0.2481227929547984),
#  'Thalamus': np.float64(0.3940341660510306),
#  'Ventral midbrain': np.float64(0.1988960722127421),
#  'Forebrain cortex': np.float64(0.2224673752186155),
#  'Subcortical forebrain': np.float64(0.6028754885539123),
#  'Forebrain': np.float64(0.3371670989943007),
#  'Cerebellum': np.float64(0.43637003264679497),
#  'Dorsal midbrain': np.float64(0.37998741786654233),
#  'Medulla': np.float64(0.2520713095792968),
#  'Mesencephalon': np.float64(0.38821366768668664),
#  'Pons/Cereb': np.float64(0.21885955712699204),
#  'Tel/diencephalon': np.float64(0.38971717773146675),
#  'Diencephalon': np.float64(0.27872414291910697),
#  'Pons': np.float64(0.30411811548271617),
#  'Striatum': np.float64(0.28578032114063745),
#  'Telencephalon': np.float64(0.31269143505388136),
#  'Hindbrain': np.float64(0.7981028325621545),
#  'Head': np.float64(1.2906579533640028),
#  'Pons/Medulla': np.float64(0.3384273326910358),
#  'Subcortex': np.float64(0.5879463814516128),
#  'Enthorinal cortex': np.float64(1.0846345514949576),
#  'Hippocampus': np.float64(0.7311266400456027),
#  'Cortical hem': np.float64(0.48560090702946074),
#  'Frontotemporal cortex': np.float64(0.8479829098269451),
#  'Lower cortex': np.float64(0.8291486449493161),
#  'Occipital cortex': np.float64(0.8174137931033829),
#  'Upper cortex': np.float64(1.04364378478672),
#  'Caudate-Putamen': np.float64(0.6849055171889927),
#  'Brain': np.float64(1.0353675128200266),
#  'Midbrain': np.float64(0.6652752046852175)}

# %%
exp_df_tissue=exp_df_tissue.drop(columns=['Unnamed: 0'])

# %%
exp_df_tissue
# Out:
#      per_exp_Cortex  mean_exp_Cortex  per_exp_Hypothalamus  \
# 0          0.000541         0.000575              0.000325
# 1          0.121154         0.143369              0.071449
# 2          0.213643         0.297003              0.152755
# 3          0.055117         0.068817              0.044152
# 4          0.040634         0.058752              0.077233
# ..              ...              ...                   ...
# 411        0.004144         0.004905              0.002101
# 412        0.044049         0.045446              0.021426
# 413        0.013981         0.015057              0.006824
# 414        0.082645         0.090377              0.054702
# 415        0.164648         0.251831              0.168418
#
#      mean_exp_Hypothalamus  per_exp_Thalamus  mean_exp_Thalamus  \
# 0                 0.000390          0.000584           0.000611
# 1                 0.078056          0.105590           0.122664
# 2                 0.189042          0.205042           0.284364
# 3                 0.053034          0.070448           0.091672
# 4                 0.102515          0.186007           0.414781
# ..                     ...               ...                ...
# 411               0.002426          0.003794           0.004168
# 412               0.021968          0.030573           0.031521
# 413               0.006998          0.009212           0.009659
# 414               0.059143          0.084530           0.093542
# 415               0.227821          0.165239           0.210542
#
#      per_exp_Ventral_midbrain  mean_exp_Ventral_midbrain  \
# 0                    0.000061                   0.000061
# 1                    0.038790                   0.042144
# 2                    0.111979                   0.139851
# 3                    0.019334                   0.020554
# 4                    0.018480                   0.020066
# ..                        ...                        ...
# 411                  0.001464                   0.001586
# 412                  0.021469                   0.022201
# 413                  0.005123                   0.005550
# 414                  0.047268                   0.051598
# 415                  0.181691                   0.236216
#
#      per_exp_Forebrain_cortex  mean_exp_Forebrain_cortex  ...  \
# 0                    0.000269                   0.000269  ...
# 1                    0.085968                   0.092560  ...
# 2                    0.130365                   0.148796  ...
# 3                    0.032019                   0.037064  ...
# 4                    0.057716                   0.074398  ...
# ..                        ...                        ...  ...
# 411                  0.001480                   0.001547  ...
# 412                  0.029194                   0.029598  ...
# 413                  0.006996                   0.006996  ...
# 414                  0.047895                   0.050652  ...
# 415                  0.000471                   0.000471  ...
#
#      mean_exp_Occipital_cortex  per_exp_Upper_cortex  mean_exp_Upper_cortex  \
# 0                     0.000750              0.000668               0.000668
# 1                     0.310270              0.266939               0.334026
# 2                     0.590180              0.440594               0.723711
# 3                     0.084483              0.186494               0.264861
# 4                     0.109820              0.151243               0.318145
# ..                         ...                   ...                    ...
# 411                   0.011769              0.008609               0.009870
# 412                   0.071139              0.090983               0.096549
# 413                   0.051574              0.060037               0.065751
# 414                   0.153223              0.158219               0.190501
# 415                   0.000075              0.000223               0.000223
#
#      per_exp_Caudate-Putamen  mean_exp_Caudate-Putamen  per_exp_Brain  \
# 0                   0.000531                  0.000531       0.001279
# 1                   0.324960                  0.458147       0.216054
# 2                   0.306291                  0.520149       0.478784
# 3                   0.064658                  0.094483       0.258451
# 4                   0.182211                  0.511725       0.263998
# ..                       ...                       ...            ...
# 411                 0.007134                  0.009259       0.008919
# 412                 0.039159                  0.039766       0.071526
# 413                 0.027700                  0.031570       0.033117
# 414                 0.090688                  0.111179       0.185530
# 415                 0.235183                  0.344767       0.366327
#
#      mean_exp_Brain  per_exp_Midbrain  mean_exp_Midbrain         gene
# 0          0.001407          0.000657           0.000717      TNFRSF9
# 1          0.267684          0.137423           0.165212        NBPF1
# 2          0.823796          0.276639           0.422190    KIAA0319L
# 3          0.488889          0.075211           0.101386        RAB3B
# 4          0.779155          0.099116           0.205582     MIR137HG
# ..              ...               ...                ...          ...
# 411        0.010779          0.005169           0.005857  SPANXA2-OT1
# 412        0.074677          0.034453           0.035887     CXorf40A
# 413        0.036676          0.016405           0.018168        SPRY3
# 414        0.224578          0.100430           0.121048        VAMP7
# 415        0.550112          0.000179           0.000209       EIF1AY
#
# [416 rows x 63 columns]

# %%
#לעשות אחוזים של ביטוי כמה גנים שהם רק human מתבטאים מתוך כל התאים לנרמל..

# %%
#do the same for region
# Out:
# ['Cortex', 'Forebrain_cortex', 'Enthorinal_cortex', 'Cortical_hem', 'Frontotemporal_cortex', 'Lower_cortex', 'Occipital_cortex', 'Upper_cortex']
# ['Hippocampus', 'Striatum', 'Caudate-Putamen', 'Subcortex', 'Subcortical_forebrain']
# ['Thalamus', 'Diencephalon', 'Tel/diencephalon']
# ['Ventral_midbrain', 'Dorsal_midbrain', 'Mesencephalon', 'Midbrain']
# ['Hindbrain', 'Cerebellum', 'Pons', 'Medulla', 'Pons/Medulla', 'Pons/Cereb']

# %%
adata.obs.Region.unique()
# Out:
# ['b'Telencephalon'', 'b'Diencephalon'', 'b'Midbrain'', 'b'Forebrain'', 'b'Cerebellum'', 'b'Medulla'', 'b'Pons'', 'b'Hindbrain'', 'b'Head'', 'b'Brain'']
# Categories (10, object): ['b'Brain'', 'b'Cerebellum'', 'b'Diencephalon'', 'b'Forebrain'', ..., 'b'Medulla'', 'b'Midbrain'', 'b'Pons'', 'b'Telencephalon'']

# %%
adata.obs.Subregion.unique()
# Out:
# ['b'Cortex'', 'b'Hypothalamus'', 'b'Thalamus'', 'b'Midbrain ventral'', 'b'Subcortex'', ..., 'b'Telencephalon'', 'b'Hindbrain'', 'b'Head'', 'b'Hippocampus'', 'b'Brain'']
# Length: 18
# Categories (18, object): ['b'Brain'', 'b'Cerebellum'', 'b'Cortex'', 'b'Diencephalon'', ..., 'b'Striatum'', 'b'Subcortex'', 'b'Telencephalon'', 'b'Thalamus'']

# %%
np.where(exp_df_ct["gene"]=='SPRY3')[0]
# Out:
# array([413])

# %%
float(exp_df_ct.iloc[np.where(exp_df_ct["gene"]=='SPRY3')[0],2])
# Out:
# /tmp/ipykernel_1523753/1331833414.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(exp_df_ct.iloc[np.where(exp_df_ct["gene"]=='SPRY3')[0],2])
# 0.0112159329140461

# %%
#get top10 percentile- cell class
cells=adata.obs.CellClass.unique().tolist()
p90={}
for i in tissues:
    tissue=i[2:-1]
    p90[tissue]=np.percentile(adata.X[adata.obs.CellClass==i,:].mean(axis=0).A1,90)

# %%
#check genes across tissues or cell types:
#define top10% for each tiisue or cell type
#mark true if gene is in the top 10% or not..
