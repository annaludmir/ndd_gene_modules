# %% [markdown]
# # Human specific genes initial enrichments

# %%
import scanpy as sc
import pandas as pd
import numpy as np
# Out:
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#upload hsg

# %%
hsg=pd.read_csv("/scratch200/reutj/data/hsg_gene_lists/updated_human_specific_genes2.csv")

# %%
#lets try new speceficity- k(1,3,5)
adj_spec_rg_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_cellclass_radialglia.csv")
adj_spec_rg_v3_3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellClass_Radialglia_3.csv")
adj_spec_rg_v3_5=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellClass_Radialglia_5.csv")
adj_spec_rg_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_cellclass_radialglia.csv")
adj_spec_rg_v2_3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellClass_Radialglia_3.csv")
adj_spec_rg_v2_5=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellClass_Radialglia_5.csv")

# %%
adj_spec_rg_v3
# Out:
#        Unnamed: 0  index         gene  mean_exp  exp_ratio  per_exp_con  \
# 0               0  11612         LIX1  0.188329  19.605009     0.671157
# 1               1   8128         HES1  0.575792   5.604049     0.922599
# 2               2   7444          VIM  1.654712   3.229141     0.999442
# 3               3  12656         SOX2  0.769756   3.864756     0.986790
# 4               4  11336        TTYH1  0.628090   4.485442     0.949206
# ...           ...    ...          ...       ...        ...          ...
# 14166       14166   9400       ZNF628  0.023373   1.011542     0.061549
# 14167       14167   9399      SLC2A10  0.017487   2.516864     0.078331
# 14168       14168   9396        RBM15  0.048655   1.293074     0.145834
# 14169       14169   2750  ST3GAL6-AS1  0.013494   1.917059     0.046515
# 14170       14170   2715   AC064807.1  0.036637   1.298223     0.101068
#
#        per_exp_other  spec_score
# 0           0.068319       10.61
# 1           0.215607        9.40
# ...

# %%
adj_spec_rg_v3_3
# Out:
#       Unnamed: 0  index      gene  mean_exp   exp_ratio  per_exp_con  \
# 0              0   8411      LIX1  0.188329   19.605555     0.671157
# 1              1   5422      HES1  0.575792    5.604069     0.922599
# 2              2     36      AMBN  0.046057  120.230293     0.319242
# 3              3   9321      SOX2  0.769756    3.864764     0.986790
# 4              4   9027   ZFP36L1  0.456467    4.830634     0.936405
# ...          ...    ...       ...       ...         ...          ...
# 9967        9967   9907   FAM234B  0.056229    0.720970     0.103375
# 9968        9968   9909     CXXC4  0.069025    1.038135     0.146653
# 9969        9969   9912  SLC9A3R1  0.051568    1.121662     0.122837
# 9970        9970   9914   FAM19A2  0.120594    0.504371     0.125107
# 9971        9971   9915    DYNLT3  0.062498    0.948872     0.135936
#
#       per_exp_other  spec_score
# 0          0.068319       14.02
# 1          0.215607       10.25
# 2          0.003675        7.47
# ...

# %%
adj_spec_rg_v3_5
# Out:
#       Unnamed: 0  index        gene  mean_exp   exp_ratio  per_exp_con  \
# 0              0   8411        LIX1  0.188329   19.605555     0.671157
# 1              1     36        AMBN  0.046057  120.230293     0.319242
# 2              2   5422        HES1  0.575792    5.604069     0.922599
# 3              3   9027     ZFP36L1  0.456467    4.830634     0.936405
# 4              4   9321        SOX2  0.769756    3.864764     0.986790
# ...          ...    ...         ...       ...         ...          ...
# 9967        9967   8253      DIRAS1  0.106365    0.447550     0.131470
# 9968        9968    582  AL117190.2  0.056046    1.132904     0.118260
# 9969        9969    586        CNR1  0.447423    0.106619     0.119339
# 9970        9970    587   HIST2H2BE  0.074716    0.536739     0.103226
# 9971        9971    592        NOL4  0.475590    0.235837     0.248242
#
#       per_exp_other  spec_score
# 0          0.068319       19.39
# 1          0.003675       11.66
# ...

# %%
adj_spec_rg_v3.loc[adj_spec_rg_v3["gene"].isin(hsg["gene"]),:]
# Out:
#        Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 5               5  12323  ZFP36L1  0.456467   4.830614     0.936405
# 27             27   6288  C1orf61  1.561392   1.581307     0.995460
# 186           186  12318     SRP9  1.168796   1.277304     0.983217
# 219           219   4534    CDH12  0.358465   3.059065     0.661631
# 310           310   6823    RBM39  0.978591   1.204894     0.958174
# ...           ...    ...      ...       ...        ...          ...
# 13951       13951   9645  SLC29A4  0.168800   0.443924     0.186693
# 13996       13996   2728    AMY2B  0.038443   0.547771     0.054106
# 14035       14035   9193   FAM72C  0.011010   4.287924     0.072415
# 14064       14064   2814  TBC1D2B  0.053380   0.695093     0.093737
# 14165       14165   9402  PCDHB11  0.010764   0.580721     0.015443
#
#        per_exp_other  spec_score
# 5           0.253194        6.73
# 27          0.964075        2.74
# 186         0.967574        1.64
# ...

# %%
adj_spec_rg_v3_3.loc[adj_spec_rg_v3_3["gene"].isin(hsg["gene"]),:]
# Out:
#       Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 4              4   9027  ZFP36L1  0.456467   4.830634     0.936405
# 37            37   3801  C1orf61  1.561392   1.581309     0.995460
# 117          117   2330    CDH12  0.358465   3.059077     0.661631
# 208          208   9022     SRP9  1.168796   1.277306     0.983217
# 343          343   4272    RBM39  0.978591   1.204895     0.958174
# ...          ...    ...      ...       ...        ...          ...
# 9764        9764   3842    PDCD6  0.072639   0.681617     0.120679
# 9810        9810   3760    NSUN5  0.051540   1.105113     0.132884
# 9832        9832     82   FBXO25  0.082468   0.512177     0.112194
# 9844        9844   9799    RAB3B  0.040979   1.464621     0.115916
# 9845        9845   9801   SLC7A6  0.094639   0.586996     0.134670
#
#       per_exp_other  spec_score
# 4          0.253194        7.04
# 37         0.964075        2.06
# 117        0.261237        1.57
# ...

# %%
adj_spec_rg_v3_5.loc[adj_spec_rg_v3_5["gene"].isin(hsg["gene"]),:]
# Out:
#       Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 3              3   9027  ZFP36L1  0.456467   4.830634     0.936405
# 39            39   3801  C1orf61  1.561392   1.581309     0.995460
# 69            69   2330    CDH12  0.358465   3.059077     0.661631
# 215          215   9022     SRP9  1.168796   1.277306     0.983217
# 349          349   4272    RBM39  0.978591   1.204895     0.958174
# ...          ...    ...      ...       ...        ...          ...
# 9754        9754   6031   NBPF12  0.109143   0.600733     0.166338
# 9792        9792   9721    CBWD5  0.076435   0.871932     0.152160
# 9860        9860     82   FBXO25  0.082468   0.512177     0.112194
# 9884        9884   9799    RAB3B  0.040979   1.464621     0.115916
# 9891        9891   9801   SLC7A6  0.094639   0.586996     0.134670
#
#       per_exp_other  spec_score
# 3          0.253194        7.37
# 39         0.964075        1.88
# 69         0.261237        1.63
# ...

# %%
adj_spec_rg_v3_3.loc[adj_spec_rg_v3_3["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#       Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  \
# 1              1   5422   HES1  0.575792   5.604069     0.922599
# 3              3   9321   SOX2  0.769756   3.864764     0.986790
# 6              6   4818    VIM  1.654712   3.229144     0.999442
# 32            32   1464   PAX6  0.598966   2.326739     0.918320
# 223          223   3358    NES  0.222428   3.398677     0.643955
# 283          283   1821  FABP7  1.549100   1.151573     0.892383
# 1497        1497    858   DLL1  0.182442   2.280509     0.439214
#
#       per_exp_other  spec_score
# 1          0.215607       10.25
# 3          0.349185        7.17
# 6          0.758822        6.10
# 32         0.511251        2.18
# 223        0.254459        1.20
# 283        0.912327        1.06
# 1497       0.262007        0.26

# %%
adj_spec_rg_v3_5.loc[adj_spec_rg_v3_5["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#       Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  \
# 2              2   5422   HES1  0.575792   5.604069     0.922599
# 4              4   9321   SOX2  0.769756   3.864764     0.986790
# 7              7   4818    VIM  1.654712   3.229144     0.999442
# 37            37   1464   PAX6  0.598966   2.326739     0.918320
# 178          178   3358    NES  0.222428   3.398677     0.643955
# 294          294   1821  FABP7  1.549100   1.151573     0.892383
# 1388        1388    858   DLL1  0.182442   2.280509     0.439214
#
#       per_exp_other  spec_score
# 2          0.215607       11.25
# 4          0.349185        6.84
# 7          0.758822        5.36
# 37         0.511251        1.91
# 178        0.254459        1.25
# 294        0.912327        0.96
# 1388       0.262007        0.27

# %%
adj_spec_rg_v3.loc[adj_spec_rg_v3["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#        Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  \
# 1               1   8128   HES1  0.575792   5.604049     0.922599
# 2               2   7444    VIM  1.654712   3.229141     0.999442
# 3               3  12656   SOX2  0.769756   3.864756     0.986790
# 36             36   3109   PAX6  0.598966   2.326733     0.918320
# 251           251   3857  FABP7  1.549100   1.151572     0.892383
# 367           367   5786    NES  0.222428   3.398654     0.643955
# 1734         1734   1976   DLL1  0.182442   2.280493     0.439214
# 11061       11061   7573    TNC  0.072537   0.692482     0.087597
# 12378       12378   5292   GFAP  0.047974   0.722173     0.074796
#
#        per_exp_other  spec_score
# 1           0.215607        9.40
# 2           0.758822        7.95
# 3           0.349185        7.55
# 36          0.511251        2.58
# 251         0.912327        1.42
# 367         0.254459        1.14
# 1734        0.262007        0.25
# 11061       0.094044        0.00
# ...

# %% [markdown]
# ## conclusion
# looking at diffenernt k seems like k=3 is better leveraging genes with less expression in per_con_other but not too much
# such that per_exp_con is also important. gene markerws have better places though some of them like NES seem to be in weaker position but filtering can still count that in the top sig genes. lets try
#
# * get significant genes

# %%
adata=sc.read_h5ad("/scratch200/reutj/data/updated_cortex_data_hg38.h5ad")

# %%
#filter cells with less than 200 genes expressd anf=d genes that express in less than 3 cells
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
ens_adata=adata.var["Accession"].to_list()
gene_sym_adata=adata.var_names.to_list()

# %%
#hsg that express in the database
print(len([i for i in hsg["gene"] if i in gene_sym_adata])) #check gene symbols
print(len([i for i in hsg["ens"] if i in ens_adata])) #check gene ensemble
#better use ensembels
# Out:
# 429
# 477

# %%
hsg_in_data=hsg.loc[hsg["ens"].isin([i for i in hsg["ens"] if i in ens_adata])]

# %%
#upload speceficity lists - full

# %%
#radial glia
adj_spec_rg_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellClass_Radialglia_3.csv")
adj_spec_rg_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellClass_Radialglia_3.csv")
spec_rg_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v3_CellClass_RadialGlia.csv")
spec_rg_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v2_CellClass_RadialGlia.csv")

# %%
adj_spec_rg_v3.head()
# Out:
#    Unnamed: 0  index     gene  mean_exp   exp_ratio  per_exp_con  \
# 0           0   8411     LIX1  0.188329   19.605555     0.671157
# 1           1   5422     HES1  0.575792    5.604069     0.922599
# 2           2     36     AMBN  0.046057  120.230293     0.319242
# 3           3   9321     SOX2  0.769756    3.864764     0.986790
# 4           4   9027  ZFP36L1  0.456467    4.830634     0.936405
#
#    per_exp_other  spec_score
# 0       0.068319       14.02
# 1       0.215607       10.25
# 2       0.003675        7.47
# 3       0.349185        7.17
# 4       0.253194        7.04

# %%
adj_spec_rg_v2.head()
# Out:
#    Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0   3457     HES1  0.960999   6.091746     0.907509
# 1           1   6292     SOX2  0.887134   4.919087     0.938244
# 2           2   2994      VIM  1.476532   4.135159     0.994029
# 3           3   6073  ZFP36L1  0.592609   5.998567     0.825188
# 4           4   5480    TTYH1  0.654476   5.030751     0.858998
#
#    per_exp_other  spec_score
# 0       0.165827       11.81
# 1       0.248798        8.31
# 2       0.443500        8.17
# 3       0.167194        7.01
# 4       0.220370        6.11

# %%
spec_rg_v3.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  per_exp_con  per_exp_other  \
# 0           0     59       AMBN  0.046057     0.319242       0.003675
# 1           1     74  LINC00698  0.009027     0.050608       0.001750
# 2           2     77       SNCG  0.022143     0.153239       0.005645
# 3           3   9058      ECEL1  0.020129     0.154579       0.009078
# 4           4   9864       LIX1  0.188329     0.671157       0.068319
#
#    spec_score
# 0      120.23
# 1       44.50
# 2       40.03
# 3       22.53
# 4       19.61

# %%
spec_rg_v2.head()
# Out:
#    Unnamed: 0  index   gene  mean_exp  per_exp_con  per_exp_other  spec_score
# 0           0     24   AMBN  0.042418     0.129575       0.003810       34.86
# 1           1   6961  ECEL1  0.026464     0.075790       0.007742        9.75
# 2           2   8811   CTGF  0.119340     0.245465       0.030950        9.35
# 3           3   8617  GCHFR  0.021114     0.058271       0.006805        8.55
# 4           4   3204  THSD1  0.029873     0.080670       0.009870        8.32

# %%
#get marker genes- 
adj_spec_rg_v3.loc[adj_spec_rg_v3["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#       Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  \
# 1              1   5422   HES1  0.575792   5.604069     0.922599
# 3              3   9321   SOX2  0.769756   3.864764     0.986790
# 6              6   4818    VIM  1.654712   3.229144     0.999442
# 32            32   1464   PAX6  0.598966   2.326739     0.918320
# 223          223   3358    NES  0.222428   3.398677     0.643955
# 283          283   1821  FABP7  1.549100   1.151573     0.892383
# 1497        1497    858   DLL1  0.182442   2.280509     0.439214
#
#       per_exp_other  spec_score
# 1          0.215607       10.25
# 3          0.349185        7.17
# 6          0.758822        6.10
# 32         0.511251        2.18
# 223        0.254459        1.20
# 283        0.912327        1.06
# 1497       0.262007        0.26

# %%
adj_spec_rg_v2.loc[adj_spec_rg_v2["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#       Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  \
# 0              0   3457   HES1  0.960999   6.091746     0.907509
# 1              1   6292   SOX2  0.887134   4.919087     0.938244
# 2              2   2994    VIM  1.476532   4.135159     0.994029
# 16            16    861  FABP7  1.188749   2.224393     0.870046
# 52            52    705   PAX6  0.532511   2.832088     0.714935
# 639          639   1907    NES  0.171214   3.818639     0.342820
# 3016        3016    390   DLL1  0.170330   1.685358     0.212336
#
#       per_exp_other  spec_score
# 0          0.165827       11.81
# 1          0.248798        8.31
# 2          0.443500        8.17
# 16         0.484039        2.50
# 52         0.273722        1.68
# 639        0.092630        0.30
# 3016       0.138354        0.03

# %%
spec_rg_v3.loc[spec_rg_v3["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#       Unnamed: 0  index   gene  mean_exp  per_exp_con  per_exp_other  \
# 64            64   6566   HES1  0.575792     0.922599       0.215607
# 174          174  10858   SOX2  0.769756     0.986790       0.349185
# 253          253   4347    NES  0.222428     0.643955       0.254459
# 308          308   5914    VIM  1.654712     0.999442       0.758822
# 744          744   2055   PAX6  0.598966     0.918320       0.511251
# 788          788   1239   DLL1  0.182442     0.439214       0.262007
# 4826        4826   2569  FABP7  1.549100     0.892383       0.912327
# 9576        9576   3876   GFAP  0.047974     0.074796       0.093439
# 9866        9866   6037    TNC  0.072537     0.087597       0.094044
#
#       spec_score
# 64          5.60
# 174         3.86
# 253         3.40
# 308         3.23
# 744         2.33
# 788         2.28
# 4826        1.15
# 9576        0.72
# 9866        0.69

# %%
spec_rg_v2.loc[spec_rg_v2["gene"].isin(["SOX2","PAX6","FABP7","GFAP","HES1","VIM","BLBP","NES","TNC","DLL1"]),:]
# Out:
#       Unnamed: 0  index   gene  mean_exp  per_exp_con  per_exp_other  \
# 30            30   4838   HES1  0.960999     0.907509       0.165827
# 73            73   8465   SOX2  0.887134     0.938244       0.248798
# 148          148   4275    VIM  1.476532     0.994029       0.443500
# 199          199   2914    NES  0.171214     0.342820       0.092630
# 321          321   2516   GFAP  0.026837     0.053679       0.016683
# 465          465   1214   PAX6  0.532511     0.714935       0.273722
# 867          867   1514  FABP7  1.188749     0.870046       0.484039
# 1552        1552    703   DLL1  0.170330     0.212336       0.138354
#
#       spec_score
# 30          6.09
# 73          4.92
# 148         4.14
# 199         3.82
# 321         3.24
# 465         2.83
# 867         2.22
# 1552        1.69

# %%
#significanrt results
from scipy import stats
adj_spec_rg_v3.loc[stats.zscore(adj_spec_rg_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index     gene  mean_exp   exp_ratio  per_exp_con  \
# 0             0   8411     LIX1  0.188329   19.605555     0.671157
# 1             1   5422     HES1  0.575792    5.604069     0.922599
# 2             2     36     AMBN  0.046057  120.230293     0.319242
# 3             3   9321     SOX2  0.769756    3.864764     0.986790
# 4             4   9027  ZFP36L1  0.456467    4.830634     0.936405
# ..          ...    ...      ...       ...         ...          ...
# 345         345   2377   HNRNPD  1.003867    1.195242     0.953262
# 346         346   4184     GLO1  0.464146    1.791805     0.844937
# 347         347   7792      BSG  0.595653    1.598851     0.878949
# 348         348   5149     RHOA  0.665914    1.475642     0.913891
# 349         349   1534  ADAMTS9  0.102211    6.417310     0.445540
#
#      per_exp_other  spec_score
# 0         0.068319       14.02
# 1         0.215607       10.25
# 2         0.003675        7.47
# 3         0.349185        7.17
# ...

# %%
#for viewing
adata_v3=adata[adata.obs['Chemistry']=='v3',:]

# %%
#look at the lowest genes
sc.pl.umap(adata_v3, color="ADAMTS9",vmax=1)

# %%
sc.pl.umap(adata_v3, color="HNRNPD",vmax=8)
#looks less convincing

# %%
#### try to build new cut-off with this parameters:
- spec_scores should be on the high side, zscore>2
- expressed in at least 30% of the cells
- exp_ratio > 1
- the ratio between per_exp_con and other should be sufficient (according to my tryings before..)

# %%
import seaborn as sns
sns.displot(x=np.log((adj_spec_rg_v3["per_exp_con"]/adj_spec_rg_v3["per_exp_other"])+1e-6))

# %%
np.percentile(np.log((adj_spec_rg_v3["per_exp_con"]/adj_spec_rg_v3["per_exp_other"])+1e-6),90)
# Out:
# np.float64(0.5290576511943144)

# %%
adj_spec_rg_v3.loc[(stats.zscore(adj_spec_rg_v3.spec_score)>2)&(adj_spec_rg_v3.exp_ratio>1)&(adj_spec_rg_v3.per_exp_con>0.3)&(np.log((adj_spec_rg_v3["per_exp_con"]/adj_spec_rg_v3["per_exp_other"])+1e-6)>0.5),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp   exp_ratio  per_exp_con  \
# 0             0   8411        LIX1  0.188329   19.605555     0.671157
# 1             1   5422        HES1  0.575792    5.604069     0.922599
# 2             2     36        AMBN  0.046057  120.230293     0.319242
# 3             3   9321        SOX2  0.769756    3.864764     0.986790
# 4             4   9027     ZFP36L1  0.456467    4.830634     0.936405
# ..          ...    ...         ...       ...         ...          ...
# 308         308    128        AHI1  0.334697    2.283216     0.738585
# 325         325   3111  AC016205.1  0.316144    2.636853     0.568973
# 332         332   3549        YAP1  0.244820    2.693288     0.652811
# 338         338   5874      PARD3B  0.499535    1.711970     0.757266
# 349         349   1534     ADAMTS9  0.102211    6.417310     0.445540
#
#      per_exp_other  spec_score
# 0         0.068319       14.02
# 1         0.215607       10.25
# ...

# %%
sc.pl.umap(adata_v3, color="PARD3B",vmax=6) #KIND OF OK

# %%
sig_adj_spec_rg_v3=adj_spec_rg_v3.loc[(stats.zscore(adj_spec_rg_v3.spec_score)>2)&(adj_spec_rg_v3.exp_ratio>1)&(adj_spec_rg_v3.per_exp_con>0.3)&(np.log((spec_rg_v3["per_exp_con"]/spec_rg_v3["per_exp_other"])+1e-6)>0.5),:]

# %%
adj_spec_rg_v2.loc[stats.zscore(adj_spec_rg_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index          gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   3457          HES1  0.960999   6.091746     0.907509
# 1             1   6292          SOX2  0.887134   4.919087     0.938244
# 2             2   2994           VIM  1.476532   4.135159     0.994029
# 3             3   6073       ZFP36L1  0.592609   5.998567     0.825188
# 4             4   5480         TTYH1  0.654476   5.030751     0.858998
# ..          ...    ...           ...       ...        ...          ...
# 210         210    697        NCKAP5  0.673417   1.817907     0.714647
# 211         211   4909      MARCKSL1  2.206081   0.815205     0.972115
# 212         212   5681  TMEM161B-AS1  0.873284   1.473049     0.796636
# 213         213   2014         PSAT1  0.342512   3.110855     0.551701
# 214         214   4609          TMA7  1.314198   1.105767     0.904069
#
#      per_exp_other  spec_score
# 0         0.165827       11.81
# 1         0.248798        8.31
# ...

# %%
np.percentile(np.log((adj_spec_rg_v2["per_exp_con"]/adj_spec_rg_v2["per_exp_other"])+1e-6),90)
# Out:
# np.float64(0.7475057902497335)

# %%
adj_spec_rg_v2.loc[(stats.zscore(adj_spec_rg_v2.spec_score)>2)&(adj_spec_rg_v2.exp_ratio>1)&(adj_spec_rg_v2.per_exp_con>0.3)&(np.log((adj_spec_rg_v2["per_exp_con"]/adj_spec_rg_v2["per_exp_other"])+1e-6)>0.74),:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   3457      HES1  0.960999   6.091746     0.907509
# 1             1   6292      SOX2  0.887134   4.919087     0.938244
# 2             2   2994       VIM  1.476532   4.135159     0.994029
# 3             3   6073   ZFP36L1  0.592609   5.998567     0.825188
# 4             4   5480     TTYH1  0.654476   5.030751     0.858998
# 5             5   1826     CREB5  0.818472   4.056559     0.893188
# 6             6    593     NPAS3  0.855277   3.673735     0.893946
# 7             7   3210     DACH1  0.937527   3.198836     0.931030
# 8             8   6139     HMGA2  0.695319   3.747304     0.826976
# 9             9   4176      GLI3  0.557790   4.020330     0.784784
# 10           10   6120   SHROOM3  0.513242   4.161476     0.727999
# 11           11   5013      EMX2  0.838816   2.784768     0.881246
# 12           12    732      SOX3  0.316204   6.751171     0.582360
# ...

# %%
adata_v2=adata[adata.obs['Chemistry']=='v2',:]

# %%
sc.pl.umap(adata_v2, color="PSAT1",vmax=3)

# %%
sig_adj_spec_rg_v2=adj_spec_rg_v2.loc[(stats.zscore(adj_spec_rg_v2.spec_score)>2)&(adj_spec_rg_v2.exp_ratio>1)&(adj_spec_rg_v2.per_exp_con>0.3)&(np.log((adj_spec_rg_v2["per_exp_con"]/adj_spec_rg_v2["per_exp_other"])+1e-6)>0.74),:]

# %%
#herer ther are much more sinificant results that means that zscore can go down to one and it will still be cool
spec_rg_v3.loc[stats.zscore(spec_rg_v3.spec_score)>2,:] #SEMMS LIKE TOO LITTLE
# Out:
#      Unnamed: 0  index       gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     59       AMBN  0.046057     0.319242       0.003675
# 1             1     74  LINC00698  0.009027     0.050608       0.001750
# 2             2     77       SNCG  0.022143     0.153239       0.005645
# 3             3   9058      ECEL1  0.020129     0.154579       0.009078
# 4             4   9864       LIX1  0.188329     0.671157       0.068319
# ..          ...    ...        ...       ...          ...            ...
# 126         126  10367   SLC25A21  0.016921     0.083206       0.017451
# 127         127   1892      DOCK5  0.010811     0.061363       0.014117
# 128         128   2308      VCAM1  0.049573     0.249209       0.058185
# 129         129   7574     FAM72C  0.011010     0.072415       0.018771
# 130         130     48  HIST2H2AB  0.009067     0.055372       0.014106
#
#      spec_score
# 0        120.23
# 1         44.50
# 2         40.03
# 3         22.53
# ...

# %%
import seaborn as sns
sns.displot(spec_rg_v3, x="per_exp_other") #not normal i think quantile is better here

# %%
sns.displot(adj_spec_rg_v3,x= 'spec_score')

# %%
sns.displot(spec_rg_v3,x= np.log(spec_rg_v3['spec_score'] + 1e-6))#now its good and normal

# %%
sns.displot(spec_rg_v3,x= np.log(spec_rg_v3['spec_score'] + 1e-6))

# %%
np.percentile((np.log(spec_rg_v3['spec_score'] + 1e-6)),95)
# Out:
# np.float64(0.9400076491163949)

# %%
spec_rg_v3.loc[np.log(spec_rg_v3['spec_score'] + 1e-6)>0.94,:]
# Out:
#      Unnamed: 0  index       gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     59       AMBN  0.046057     0.319242       0.003675
# 1             1     74  LINC00698  0.009027     0.050608       0.001750
# 2             2     77       SNCG  0.022143     0.153239       0.005645
# 3             3   9058      ECEL1  0.020129     0.154579       0.009078
# 4             4   9864       LIX1  0.188329     0.671157       0.068319
# ..          ...    ...        ...       ...          ...            ...
# 589         589     66       MXD3  0.086590     0.250847       0.115665
# 590         590   7742      FYCO1  0.025640     0.111041       0.043154
# 591         591   2620      METRN  0.238079     0.639155       0.231374
# 592         592   7581       GLI3  0.776805     0.962527       0.451526
# 593         593    107     SEMA3D  0.014543     0.060842       0.023822
#
#      spec_score
# 0        120.23
# 1         44.50
# 2         40.03
# 3         22.53
# ...

# %%
#make per_other to be also in the low 10 percent
spec_rg_v3.loc[(np.log(spec_rg_v3['spec_score'] + 1e-6)>0.94)&(spec_rg_v3.per_exp_other<=np.percentile(spec_rg_v3.per_exp_other, 10)),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     59        AMBN  0.046057     0.319242       0.003675
# 1             1     74   LINC00698  0.009027     0.050608       0.001750
# 2             2     77        SNCG  0.022143     0.153239       0.005645
# 3             3   9058       ECEL1  0.020129     0.154579       0.009078
# 4             4   9864        LIX1  0.188329     0.671157       0.068319
# ..          ...    ...         ...       ...          ...            ...
# 579         579   5573       TRAF5  0.028721     0.125740       0.048920
# 582         582   9476  AC107072.1  0.020502     0.091244       0.034869
# 584         584   2367        SDC1  0.016898     0.080043       0.033890
# 590         590   7742       FYCO1  0.025640     0.111041       0.043154
# 593         593    107      SEMA3D  0.014543     0.060842       0.023822
#
#      spec_score
# 0        120.23
# 1         44.50
# 2         40.03
# 3         22.53
# ...

# %%
sc.pl.umap(adata_v3, color="TRAF5",vmax=1)#LOOKS OK

# %%
sig_spec_rg_v3=spec_rg_v3.loc[(np.log(spec_rg_v3['spec_score'] + 1e-6)>0.94)&(spec_rg_v3.per_exp_other<=np.percentile(spec_rg_v3.per_exp_other, 10)),:]

# %%
np.percentile((np.log(spec_rg_v2['spec_score'] + 1e-6)),95)
# Out:
# np.float64(1.0577906413700164)

# %%
spec_rg_v2.loc[stats.zscore(spec_rg_v2.spec_score)>2,:]
#much more results here
# Out:
#      Unnamed: 0  index      gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     24      AMBN  0.042418     0.129575       0.003810
# 1             1   6961     ECEL1  0.026464     0.075790       0.007742
# 2             2   8811      CTGF  0.119340     0.245465       0.030950
# 3             3   8617     GCHFR  0.021114     0.058271       0.006805
# 4             4   3204     THSD1  0.029873     0.080670       0.009870
# ..          ...    ...       ...       ...          ...            ...
# 369         369   8706    ZNF521  0.120521     0.232219       0.072715
# 370         370   8877       ST5  0.099644     0.190740       0.061085
# 371         371   4643      HMMR  0.066273     0.132682       0.042983
# 372         372   6406  CDC42EP4  0.228063     0.411972       0.141910
# 373         373   3045     PSAT1  0.342512     0.551701       0.194159
#
#      spec_score
# 0         34.86
# 1          9.75
# 2          9.35
# 3          8.55
# 4          8.32
# ...

# %%
spec_rg_v2.loc[(np.log(spec_rg_v2['spec_score'] + 1e-6))>1.05,:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     24      AMBN  0.042418     0.129575       0.003810
# 1             1   6961     ECEL1  0.026464     0.075790       0.007742
# 2             2   8811      CTGF  0.119340     0.245465       0.030950
# 3             3   8617     GCHFR  0.021114     0.058271       0.006805
# 4             4   3204     THSD1  0.029873     0.080670       0.009870
# ..          ...    ...       ...       ...          ...            ...
# 452         452   2425    ENOSF1  0.071972     0.142078       0.050374
# 453         453   4001     NDC80  0.148975     0.248132       0.090818
# 454         454   2355     PDGFD  0.203649     0.316329       0.107335
# 455         455   1512     SALL3  0.032800     0.064393       0.021991
# 456         456   2131  C17orf53  0.023413     0.052936       0.017594
#
#      spec_score
# 0         34.86
# 1          9.75
# 2          9.35
# 3          8.55
# 4          8.32
# ...

# %%
sc.pl.umap(adata_v2, color="C17orf53",vmax=1)#VERY WEAK BUT LOOKS OK

# %%
spec_rg_v2.loc[((np.log(spec_rg_v2['spec_score'] + 1e-6))>1.05)&(spec_rg_v2.per_exp_other<=np.percentile(spec_rg_v2.per_exp_other, 10)),:]
#v2 has lower expression (meaning many genes will have very low expression) so maybe lower the threshold all together
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     24        AMBN  0.042418     0.129575       0.003810
# 1             1   6961       ECEL1  0.026464     0.075790       0.007742
# 2             2   8811        CTGF  0.119340     0.245465       0.030950
# 3             3   8617       GCHFR  0.021114     0.058271       0.006805
# 4             4   3204       THSD1  0.029873     0.080670       0.009870
# ..          ...    ...         ...       ...          ...            ...
# 449         449   6366        RPGR  0.055884     0.111677       0.039033
# 450         450   5635  AC099850.2  0.038530     0.082685       0.028638
# 451         451   8484        MAFF  0.033199     0.068212       0.023760
# 455         455   1512       SALL3  0.032800     0.064393       0.021991
# 456         456   2131    C17orf53  0.023413     0.052936       0.017594
#
#      spec_score
# 0         34.86
# 1          9.75
# 2          9.35
# 3          8.55
# ...

# %%
sig_spec_rg_v2=spec_rg_v2.loc[((np.log(spec_rg_v2['spec_score'] + 1e-6))>1.05)&(spec_rg_v2.per_exp_other<=np.percentile(spec_rg_v2.per_exp_other, 10)),:]

# %%
#enrichments
To perform enrichment analysis we would use fisher exact test. this tests the hypothesis that two populations that intessect with other are indepemdent. To do so we whould make a contingency table that takes into consideration: 

- number og hsg in data (here 477)
- number of hsg in the intesection (sig_adj_spec_pro_v3 -7)
- number of total genes in the data (ens adata 30251)
- number of genes in the specificy score (153)

# %%
#function
from scipy.stats import hypergeom
from scipy.stats import fisher_exact

def fisher_test(hsg_table,sig_table,n_genes=30251,n_hsg=477):
    hsg_intersection=list(set(sig_table["gene"]) & set(hsg_table["gene"]))
    table=np.array([[len(hsg_intersection),n_hsg-len(hsg_intersection)],
                    [len(sig_table)-len(hsg_intersection),n_genes-len(sig_table)-len(hsg_intersection)]])
    res = fisher_exact(table, alternative='two-sided')
    return (hsg_intersection , res.pvalue)

# %%
fisher_test(hsg,sig_adj_spec_rg_v3)
# Out:
# (['ZFP36L1', 'CDH12', 'SRP9', 'RBM39', 'C1orf61'], 1.0)

# %%
fisher_test(hsg,sig_adj_spec_rg_v2)
# Out:
# (['CDH12', 'ZFP36L1'], np.float64(0.13301561136449197))

# %%
fisher_test(hsg,sig_spec_rg_v3) #YES
# Out:
# (['RIBC2',
#   'FAM72D',
#   'CHRM3',
#   'ELN',
#   'PRKCB',
#   'FANK1',
#   'CCDC74B',
#   'NEK2',
#   'AR',
#   'FAM72B',
#   'FAM72C'],
#  np.float64(0.019394842411860663))

# %%
fisher_test(hsg,sig_spec_rg_v2) #CLOSE..
# Out:
# (['FAM72D', 'GYPC', 'EIF1AY', 'NBPF14', 'NEK2', 'PARP4', 'AR', 'FAM72C'],
#  np.float64(0.07977312722210202))

# %%
#lets draw the sig results!!

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import rc_context
from matplotlib import colors
colors2 = plt.cm.Reds(np.linspace(0.3, 1, 80))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,5))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)
with rc_context({"figure.figsize": (3, 3)}):
    sc.pl.umap(adata, color=["CHRM3","AR","PRKCB","ELN","NEK2","FANK1","CCDC74B","RIBC2","FAM72B","FAM72C","FAM72D","CellClass"],ncols=3,color_map=mymap,frameon=False,vmax=15)
    sc.pl.umap(adata, color=["Age","CellCyclePhase"],ncols=3,frameon=False)
    #"Age","CellCyclePhase"

# %%
#PREVIOUS RESULTS (NO RESTRICTING TO EXP_OTHER- ASK MIRI)
import matplotlib.pyplot as plt
from matplotlib.pyplot import rc_context
from matplotlib import colors
colors2 = plt.cm.Reds(np.linspace(0.3, 1, 80))
colors3 = plt.cm.Greys_r(np.linspace(0.7,0.8,5))
colorsComb = np.vstack([colors3, colors2])
mymap = colors.LinearSegmentedColormap.from_list('my_colormap', colorsComb)
with rc_context({"figure.figsize": (3, 3)}):
    sc.pl.umap(adata, color=["KIF18A","AR","NBPF14","ASPM","NEK2","ZFP36L1","CDH12","GYPC","PARP4","FAM72C","FAM72D","EIF1AY"],ncols=3,color_map=mymap,frameon=False,vmax=15)
    sc.pl.umap(adata, color=["CellClass","Age","CellCyclePhase"],ncols=3,frameon=False)
    #"Age","CellCyclePhase"

# %% [markdown]
# ASPM is a spindle pole/centrosome protein, essential for neurogenic mitosis and possibly controlling the fate-switch to asymmetric cell division.
# Mutations in the ASPM gene are the most common cause of autosomal recessive primary microcephaly
# https://pmc.ncbi.nlm.nih.gov/articles/PMC374243/
# Our data suggest that evolutionary selection of specific segments of the ASPM sequence strongly relates to differences in cerebral cortical size.
# NEK2- This gene encodes a serine/threonine-protein kinase that is involved in mitotic regulation. This protein is localized to the centrosome, and undetectable during G1 phase, but accumulates progressively throughout the S phase, reaching maximal levels in late G2 phase. GENE DUPLICATION. KIF18A-KIF18A is a member of the kinesin superfamily of microtubule-associated molecular motors (see MIM 148760) that use hydrolysis of ATP to produce force and movement along microtubules. The protein is expressed in the germinal zones during mid-fetal brain development. These data suggest that the centrosome-associated cell division machinery may be critical to neocortical evolution FAM72D-belong to gene duplication family, in this article related to neural stem cell renwall https://www.sciencedirect.com/science/article/pii/S0197018624001803

# %%
#do the same for neuronal ipc

# %%
#upload speceficity lists

# %%
#ipc
adj_spec_ipc_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellClass_NeuronalIPC.csv")
adj_spec_ipc_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellClass_NeuronalIPC.csv")
spec_ipc_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v3_CellClass_NeuronalIPC.csv")
spec_ipc_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v2_CellClass_NeuronalIPC.csv")

# %%
adj_spec_ipc_v3.head()
# Out:
#    Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     11    EOMES  0.268052   7.633444     0.923623
# 1           1     16    INSM1  0.338304   4.984971     0.948235
# 2           2     17  NEUROG1  0.104469  10.335981     0.661733
# 3           3   1116  GADD45G  0.362668   4.069853     0.921170
# 4           4      9  NEUROD4  0.090735   8.560279     0.699396
#
#    per_exp_other  spec_score
# 0       0.157929       12.26
# 1       0.339480        6.31
# 2       0.073755        5.50
# 3       0.364231        4.50
# 4       0.089196        4.08

# %%
adj_spec_ipc_v2.head()
# Out:
#    Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     10    EOMES  0.176261  10.656878     0.753617
# 1           1    601     HES6  0.623997   3.640165     0.951276
# 2           2    584   ELAVL2  0.408506   4.254756     0.889992
# 3           3    554  GADD45G  0.309659   4.400168     0.752038
# 4           4     14    INSM1  0.098450   9.971405     0.534587
#
#    per_exp_other  spec_score
# 0       0.076654        9.74
# 1       0.414562        5.05
# 2       0.284205        4.87
# 3       0.213570        3.31
# 4       0.058383        2.96

# %%
spec_ipc_v3.head()
# Out:
#    Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0           0   3472        E2F2  0.024068     0.338530       0.028832
# 1           1   1535   LINC01967  0.008251     0.099238       0.006968
# 2           2     20     NEUROG1  0.104469     0.661733       0.073755
# 3           3   1424  AC004852.2  0.041401     0.264430       0.029030
# 4           4    909        MNX1  0.006952     0.103355       0.010034
#
#    spec_score
# 0       12.77
# 1       12.56
# 2       10.34
# 3       10.04
# 4        8.86

# %%
spec_ipc_v2.head()
# Out:
#    Unnamed: 0  index     gene  mean_exp  per_exp_con  per_exp_other  \
# 0           0      9  PSTPIP1  0.006228     0.053130       0.003079
# 1           1     10  NEUROD4  0.049468     0.363493       0.022369
# 2           2    931   PHLDB2  0.026198     0.191084       0.015149
# 3           3     18  NEUROG1  0.067515     0.367044       0.033529
# 4           4     12    EOMES  0.176261     0.753617       0.076654
#
#    spec_score
# 0       17.90
# 1       15.10
# 2       12.18
# 3       10.73
# 4       10.66

# %%
#get marker genes (ipc):
adj_spec_ipc_v3.loc[adj_spec_ipc_v3["gene"].isin(["EOMES","ASCL1","NHLH1","ELAVL2","HES6","NEUROD4"]),:]
#pretty good
# Out:
#     Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0            0     11    EOMES  0.268052   7.633444     0.923623
# 4            4      9  NEUROD4  0.090735   8.560279     0.699396
# 6            6   1192     HES6  0.761177   2.877791     0.994394
# 9            9   1125    ASCL1  0.262202   3.889339     0.851187
# 18          18   1167   ELAVL2  0.555569   2.593123     0.967154
# 96          96      3    NHLH1  0.220067   3.034599     0.736971
#
#     per_exp_other  spec_score
# 0        0.157929       12.26
# 4        0.089196        4.08
# 6        0.677616        3.82
# 9        0.321726        2.99
# 18       0.571606        2.72
# 96       0.233799        1.50

# %%
adj_spec_ipc_v2.loc[adj_spec_ipc_v2["gene"].isin(["EOMES","ASCL1","NHLH1","ELAVL2","HES6","NEUROD4"]),:]
# Out:
#      Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     10    EOMES  0.176261  10.656878     0.753617
# 1             1    601     HES6  0.623997   3.640165     0.951276
# 2             2    584   ELAVL2  0.408506   4.254756     0.889992
# 35           35    556    ASCL1  0.162040   5.111937     0.551683
# 46           46      8  NEUROD4  0.049468  15.104744     0.363493
# 136         136      3    NHLH1  0.222239   3.531001     0.575224
#
#      per_exp_other  spec_score
# 0         0.076654        9.74
# 1         0.414562        5.05
# 2         0.284205        4.87
# 35        0.126308        1.56
# 46        0.022369        1.46
# 136       0.147149        1.18

# %%
spec_ipc_v3.loc[spec_ipc_v3["gene"].isin(["EOMES","ASCL1","NHLH1","ELAVL2","HES6","NEUROD4"]),:]
#obviousoly this gives other results- marker genes are less important
# Out:
#      Unnamed: 0  index     gene  mean_exp  per_exp_con  per_exp_other  \
# 7             7     11  NEUROD4  0.090735     0.699396       0.089196
# 9             9     13    EOMES  0.268052     0.923623       0.157929
# 157         157   1504    ASCL1  0.262202     0.851187       0.321726
# 281         281      4    NHLH1  0.220067     0.736971       0.233799
# 326         326   1583     HES6  0.761177     0.994394       0.677616
# 398         398   1552   ELAVL2  0.555569     0.967154       0.571606
#
#      spec_score
# 7          8.56
# 9          7.63
# 157        3.89
# 281        3.03
# 326        2.88
# 398        2.59

# %%
spec_ipc_v2.loc[spec_ipc_v2["gene"].isin(["EOMES","ASCL1","NHLH1","ELAVL2","HES6","NEUROD4"]),:]
# Out:
#     Unnamed: 0  index     gene  mean_exp  per_exp_con  per_exp_other  \
# 1            1     10  NEUROD4  0.049468     0.363493       0.022369
# 4            4     12    EOMES  0.176261     0.753617       0.076654
# 25          25    882    ASCL1  0.162040     0.551683       0.126308
# 43          43    921   ELAVL2  0.408506     0.889992       0.284205
# 79          79    942     HES6  0.623997     0.951276       0.414562
# 92          92      3    NHLH1  0.222239     0.575224       0.147149
#
#     spec_score
# 1        15.10
# 4        10.66
# 25        5.11
# 43        4.25
# 79        3.64
# 92        3.53

# %%
adj_spec_ipc_v3.loc[stats.zscore(adj_spec_ipc_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     11    EOMES  0.268052   7.633444     0.923623
# 1             1     16    INSM1  0.338304   4.984971     0.948235
# 2             2     17  NEUROG1  0.104469  10.335981     0.661733
# 3             3   1116  GADD45G  0.362668   4.069853     0.921170
# 4             4      9  NEUROD4  0.090735   8.560279     0.699396
# ..          ...    ...      ...       ...        ...          ...
# 441         441   3728     TCP1  0.838874   1.215828     0.952089
# 442         442   7453    HSBP1  0.957412   1.124569     0.976001
# 443         443   2190    SNRPB  0.346390   1.919213     0.818867
# 444         444   2207    CHEK1  0.167431   2.914769     0.652974
# 445         445   7672    BANF1  0.549983   1.508128     0.904704
#
#      per_exp_other  spec_score
# 0         0.157929       12.26
# 1         0.339480        6.31
# 2         0.073755        5.50
# 3         0.364231        4.50
# ...

# %%
np.percentile(np.log((adj_spec_ipc_v3["per_exp_con"]/adj_spec_ipc_v3["per_exp_other"])+1e-6),90)
# Out:
# np.float64(0.4917485551247072)

# %%
adj_spec_ipc_v3.loc[(stats.zscore(adj_spec_ipc_v3.spec_score)>2)&(adj_spec_ipc_v3.exp_ratio>1)& (adj_spec_ipc_v3.per_exp_con>0.3)&(np.log((adj_spec_ipc_v3["per_exp_con"]/adj_spec_ipc_v3["per_exp_other"])+1e-6)>0.5),:]
# Out:
#      Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     11    EOMES  0.268052   7.633444     0.923623
# 1             1     16    INSM1  0.338304   4.984971     0.948235
# 2             2     17  NEUROG1  0.104469  10.335981     0.661733
# 3             3   1116  GADD45G  0.362668   4.069853     0.921170
# 4             4      9  NEUROD4  0.090735   8.560279     0.699396
# ..          ...    ...      ...       ...        ...          ...
# 409         409   3042    UHRF1  0.167134   3.025189     0.656127
# 428         428   3434     SDC2  0.131696   3.486860     0.609179
# 438         438   2691     GMNN  0.236247   2.396737     0.718665
# 440         440   6751     SGO2  0.137926   3.880206     0.518875
# 444         444   2207    CHEK1  0.167431   2.914769     0.652974
#
#      per_exp_other  spec_score
# 0         0.157929       12.26
# 1         0.339480        6.31
# 2         0.073755        5.50
# 3         0.364231        4.50
# ...

# %%
sc.pl.umap(adata_v3, color="CHEK1",vmax=8)
#kind of?

# %%
sig_adj_spec_ipc_v3=adj_spec_ipc_v3.loc[(stats.zscore(adj_spec_ipc_v3.spec_score)>2)&(adj_spec_ipc_v3.exp_ratio>1)& (adj_spec_ipc_v3.per_exp_con>0.3)&(np.log((adj_spec_ipc_v3["per_exp_con"]/adj_spec_ipc_v3["per_exp_other"])+1e-6)>0.5),:]

# %%
adj_spec_ipc_v2.loc[stats.zscore(adj_spec_ipc_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     10    EOMES  0.176261  10.656878     0.753617
# 1             1    601     HES6  0.623997   3.640165     0.951276
# 2             2    584   ELAVL2  0.408506   4.254756     0.889992
# 3             3    554  GADD45G  0.309659   4.400168     0.752038
# 4             4     14    INSM1  0.098450   9.971405     0.534587
# ..          ...    ...      ...       ...        ...          ...
# 303         303   1900   CDKAL1  0.531027   1.765134     0.696278
# 304         304   3140    PSMA4  0.973432   1.201946     0.839558
# 305         305   2316  C1orf61  2.088215   0.794607     0.942991
# 306         306   3859    UBE2I  0.754441   1.384325     0.801881
# 307         307    504    GPM6A  1.621195   0.930466     0.893280
#
#      per_exp_other  spec_score
# 0         0.076654        9.74
# 1         0.414562        5.05
# 2         0.284205        4.87
# 3         0.213570        3.31
# ...

# %%
np.percentile(np.log((adj_spec_ipc_v2["per_exp_con"]/adj_spec_ipc_v2["per_exp_other"])+1e-6),90)
# Out:
# np.float64(0.5118612292991763)

# %%
#also here we may apply the same rules
adj_spec_ipc_v2.loc[(stats.zscore(adj_spec_ipc_v2.spec_score)>2) & (adj_spec_ipc_v2.exp_ratio>1.5) & (adj_spec_ipc_v2.per_exp_con>0.3) &(np.log((adj_spec_ipc_v2["per_exp_con"]/adj_spec_ipc_v2["per_exp_other"])+1e-6)>0.5),:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     10     EOMES  0.176261  10.656878     0.753617
# 1             1    601      HES6  0.623997   3.640165     0.951276
# 2             2    584    ELAVL2  0.408506   4.254756     0.889992
# 3             3    554   GADD45G  0.309659   4.400168     0.752038
# 4             4     14     INSM1  0.098450   9.971405     0.534587
# 5             5   4517     HMGB2  1.051908   2.393706     0.882562
# 6             6    401  CACNA2D1  0.818722   2.330895     0.934245
# 7             7   2475     TOP2A  0.472597   3.312590     0.677998
# 8             8   4812     DLEU2  0.487658   2.845796     0.808259
# 9             9   1605  HIST1H4C  0.792649   2.695649     0.724684
# 16           16    531   SLCO5A1  0.425099   2.824329     0.770384
# 17           17   5325     HMGN2  0.403983   2.927776     0.754471
# 19           19     13    PLXNA2  0.439918   2.706322     0.767754
# ...

# %%
sc.pl.umap(adata_v2, color="EPHA3",vmax=3)#okish?

# %%
sig_adj_spec_ipc_v2=adj_spec_ipc_v2.loc[(stats.zscore(adj_spec_ipc_v2.spec_score)>2) & (adj_spec_ipc_v2.exp_ratio>1.5) & (adj_spec_ipc_v2.per_exp_con>0.3) &(np.log((adj_spec_ipc_v2["per_exp_con"]/adj_spec_ipc_v2["per_exp_other"])+1e-6)>0.5),:]

# %%
spec_ipc_v3.loc[stats.zscore(spec_ipc_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0   3472        E2F2  0.024068     0.338530       0.028832
# 1             1   1535   LINC01967  0.008251     0.099238       0.006968
# 2             2     20     NEUROG1  0.104469     0.661733       0.073755
# 3             3   1424  AC004852.2  0.041401     0.264430       0.029030
# 4             4    909        MNX1  0.006952     0.103355       0.010034
# ..          ...    ...         ...       ...          ...            ...
# 433         433   9718       ACBD7  0.019303     0.126128       0.041819
# 434         434   1495     SLC35F3  0.026964     0.108873       0.041546
# 435         435   1567      PLPPR4  0.141954     0.484103       0.224565
# 436         436   6274       ABCB4  0.014367     0.076903       0.027967
# 437         437   3422       CENPH  0.177363     0.651660       0.287223
#
#      spec_score
# 0         12.77
# 1         12.56
# 2         10.34
# 3         10.04
# ...

# %%
sc.pl.umap(adata_v3, color="CENPH",vmax=3)#sababa?? proliferating looks like..

# %%
np.percentile((np.log(spec_ipc_v3['spec_score'] + 1e-6)),95)
# Out:
# np.float64(0.7227064682382652)

# %%
spec_ipc_v3.loc[((np.log(spec_ipc_v3['spec_score'] + 1e-6))>0.72)&(spec_ipc_v3.per_exp_other<=np.percentile(spec_ipc_v3.per_exp_other, 10)),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0   3472        E2F2  0.024068     0.338530       0.028832
# 1             1   1535   LINC01967  0.008251     0.099238       0.006968
# 2             2     20     NEUROG1  0.104469     0.661733       0.073755
# 3             3   1424  AC004852.2  0.041401     0.264430       0.029030
# 4             4    909        MNX1  0.006952     0.103355       0.010034
# ..          ...    ...         ...       ...          ...            ...
# 586         586   1425   LINC01170  0.018050     0.064991       0.024807
# 589         589   6980     CDK2AP1  0.027941     0.145134       0.060815
# 590         590   9503  AL592166.1  0.012764     0.076027       0.029622
# 591         591   8718     TMEM143  0.016955     0.091793       0.038114
# 601         601   1959    HIST1H3A  0.011397     0.064465       0.026274
#
#      spec_score
# 0         12.77
# 1         12.56
# 2         10.34
# 3         10.04
# ...

# %%
sc.pl.umap(adata_v3, color="TMEM143",vmax=1)#sababa

# %%
#results are convincing enougth this way.. (and retaining sox2)
sig_spec_ipc_v3=spec_ipc_v3.loc[((np.log(spec_ipc_v3['spec_score'] + 1e-6))>0.72)&(spec_ipc_v3.per_exp_other<=np.percentile(spec_ipc_v3.per_exp_other, 10)),:]

# %%
spec_ipc_v2.loc[stats.zscore(spec_ipc_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0      9   PSTPIP1  0.006228     0.053130       0.003079
# 1             1     10   NEUROD4  0.049468     0.363493       0.022369
# 2             2    931    PHLDB2  0.026198     0.191084       0.015149
# 3             3     18   NEUROG1  0.067515     0.367044       0.033529
# 4             4     12     EOMES  0.176261     0.753617       0.076654
# ..          ...    ...       ...       ...          ...            ...
# 293         293    144    PMAIP1  0.045866     0.120068       0.049157
# 294         294   3096    KIF18A  0.099828     0.246515       0.093682
# 295         295    863   TMEM158  0.049678     0.128156       0.050545
# 296         296   3739  ARHGEF39  0.020165     0.064374       0.024163
# 297         297   2359    TRIP13  0.063076     0.182930       0.070871
#
#      spec_score
# 0         17.90
# 1         15.10
# 2         12.18
# 3         10.73
# 4         10.66
# ...

# %%
sc.pl.umap(adata_v3, color="TRIP13",vmax=1)#ahh

# %%
np.percentile((np.log(spec_ipc_v2['spec_score'] + 1e-6)),95)
# Out:
# np.float64(0.7323683744823419)

# %%
spec_ipc_v2.loc[((np.log(spec_ipc_v2['spec_score'] + 1e-6))>0.73)&(spec_ipc_v2.per_exp_other<=np.percentile(spec_ipc_v2.per_exp_other, 10)),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0      9     PSTPIP1  0.006228     0.053130       0.003079
# 1             1     10     NEUROD4  0.049468     0.363493       0.022369
# 2             2    931      PHLDB2  0.026198     0.191084       0.015149
# 3             3     18     NEUROG1  0.067515     0.367044       0.033529
# 5             5    824     C7orf33  0.009142     0.064177       0.005444
# ..          ...    ...         ...       ...          ...            ...
# 425         425   8125  AC079594.2  0.030205     0.078183       0.034456
# 429         429   2303        POLE  0.044771     0.107115       0.050060
# 430         430   6385    HIST1H4J  0.045234     0.109679       0.048811
# 431         431   1070  AC091133.2  0.031159     0.075289       0.033699
# 437         437   3478      ZNF486  0.025837     0.064571       0.028807
#
#      spec_score
# 0         17.90
# 1         15.10
# 2         12.18
# 3         10.73
# ...

# %%
sc.pl.umap(adata_v2, color="HIST1H4J",vmax=1)# kind of ok?

# %%
sig_spec_ipc_v2=spec_ipc_v2.loc[((np.log(spec_ipc_v2['spec_score'] + 1e-6))>0.73)&(spec_ipc_v2.per_exp_other<=np.percentile(spec_ipc_v2.per_exp_other, 10)),:]

# %%
#intersections

# %%
fisher_test(hsg,sig_adj_spec_ipc_v3)
# Out:
# (['ASPM', 'KIF26B', 'GADD45G'], np.float64(0.25657254715683436))

# %%
fisher_test(hsg,sig_adj_spec_ipc_v2)
# Out:
# (['GADD45G'], np.float64(0.5773864863519581))

# %%
fisher_test(hsg,sig_spec_ipc_v3)
# Out:
# (['FAM72D', 'SYT2', 'RIBC2', 'FAM72B', 'FAM72C'],
#  np.float64(0.3918736919616248))

# %%
fisher_test(hsg,sig_spec_ipc_v2)
# Out:
# (['SPAG5', 'FAM72D', 'ZNF492', 'FAM72C', 'ARHGAP42'],
#  np.float64(0.1991883084049868))

# %%
#all non significant

# %%
#do the same for proliferating cells

# %%
#upload speceficity lists

# %%
#radial glia
adj_spec_pro_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_proliferating.csv")
adj_spec_pro_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_proliferating.csv")
spec_pro_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v3_proliferating.csv")# not sure about these..
spec_pro_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v2_proliferating.csv")

# %%
adj_spec_pro_v3.head()
# Out:
#    Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0   5648        HES1  0.575792  57.103471     0.768220
# 1           1   9575        SOX2  0.769756  25.131830     0.950964
# 2           2   9282     ZFP36L1  0.456467  36.145681     0.826525
# 3           3   3310  AC016205.1  0.316144  54.379286     0.572189
# 4           4   1644        SOX3  0.298838  28.791400     0.730789
#
#    per_exp_other  spec_score
# 0       0.051040       89.03
# 1       0.114641       62.94
# 2       0.061422       53.74
# 3       0.025979       31.91
# 4       0.042728       25.07

# %%
adj_spec_pro_v2.head()
# Out:
#    Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0   3497     HES1  0.960999  38.927892     0.783015
# 1           1   6314     SOX2  0.887134  25.167144     0.882203
# 2           2   6096  ZFP36L1  0.592609  26.384530     0.728080
# 3           3   4211     GLI3  0.557790  21.326204     0.753935
# 4           4   1872    CREB5  0.818472  13.319050     0.817875
#
#    per_exp_other  spec_score
# 0       0.047747       64.86
# 1       0.071721       48.03
# 2       0.047393       27.34
# 3       0.050286       22.45
# 4       0.112347       18.91

# %%
spec_pro_v3.head()
# Out:
#    Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0           0   3341  AC011139.1  0.013775     0.071946       0.000280
# 1           1     70      IFI44L  0.051236     0.212868       0.002086
# 2           2     62        AMBN  0.046057     0.164206       0.001961
# 3           3     42      ATP1A2  0.067412     0.239030       0.004187
# 4           4     57    HIST1H3B  0.051320     0.215709       0.003222
#
#    spec_score
# 0      258.56
# 1      118.07
# 2      114.56
# 3       88.41
# 4       82.88

# %%
spec_pro_v2.head()
# Out:
#    Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0           0     41      IFI44L  0.072146     0.149861       0.002267
# 1           1   6016     C2orf48  0.027681     0.065323       0.000933
# 2           2     36        AMBN  0.042418     0.092685       0.001583
# 3           3   7742        CRB2  0.195313     0.345034       0.008007
# 4           4   2225  AC087632.1  0.139011     0.262422       0.005940
#
#    spec_score
# 0       70.00
# 1       63.14
# 2       59.48
# 3       52.49
# 4       50.13

# %%
adj_spec_pro_v3.loc[stats.zscore(adj_spec_pro_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   5648        HES1  0.575792  57.103471     0.768220
# 1             1   9575        SOX2  0.769756  25.131830     0.950964
# 2             2   9282     ZFP36L1  0.456467  36.145681     0.826525
# 3             3   3310  AC016205.1  0.316144  54.379286     0.572189
# 4             4   1644        SOX3  0.298838  28.791400     0.730789
# ..          ...    ...         ...       ...        ...          ...
# 108         108   8679       CCNA2  0.153699  23.956483     0.388885
# 109         109   1664      TCF7L1  0.283699   7.099361     0.641557
# 110         110   1473     COL11A1  0.434534   4.733731     0.763193
# 111         111   6261        BMP7  0.132517  20.735143     0.441845
# 112         112   2491       BRCA1  0.144705  18.172180     0.460756
#
#      per_exp_other  spec_score
# 0         0.051040       89.03
# 1         0.114641       62.94
# 2         0.061422       53.74
# ...

# %%
sc.pl.umap(adata_v3, color="BRCA1",vmax=5)#very good

# %%
np.percentile(np.log((adj_spec_pro_v3["per_exp_con"]/adj_spec_pro_v3["per_exp_other"])+1e-6),90)
# Out:
# np.float64(0.9187872937568565)

# %%
adj_spec_pro_v3.loc[(stats.zscore(adj_spec_pro_v3.spec_score)>2) & (adj_spec_rg_v3.exp_ratio>1) &(adj_spec_pro_v3.per_exp_con>0.3) &(np.log((adj_spec_pro_v3["per_exp_con"]/adj_spec_pro_v3["per_exp_other"])+1e-6)>0.9) ,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   5648        HES1  0.575792  57.103471     0.768220
# 1             1   9575        SOX2  0.769756  25.131830     0.950964
# 2             2   9282     ZFP36L1  0.456467  36.145681     0.826525
# 3             3   3310  AC016205.1  0.316144  54.379286     0.572189
# 4             4   1644        SOX3  0.298838  28.791400     0.730789
# ..          ...    ...         ...       ...        ...          ...
# 108         108   8679       CCNA2  0.153699  23.956483     0.388885
# 109         109   1664      TCF7L1  0.283699   7.099361     0.641557
# 110         110   1473     COL11A1  0.434534   4.733731     0.763193
# 111         111   6261        BMP7  0.132517  20.735143     0.441845
# 112         112   2491       BRCA1  0.144705  18.172180     0.460756
#
#      per_exp_other  spec_score
# 0         0.051040       89.03
# 1         0.114641       62.94
# 2         0.061422       53.74
# ...

# %%
sig_adj_spec_pro_v3=adj_spec_pro_v3.loc[(stats.zscore(adj_spec_pro_v3.spec_score)>2) & (adj_spec_rg_v3.exp_ratio>1) &(adj_spec_pro_v3.per_exp_con>0.3) &(np.log((adj_spec_pro_v3["per_exp_con"]/adj_spec_pro_v3["per_exp_other"])+1e-6)>0.9) ,:]

# %%
adj_spec_pro_v2.loc[stats.zscore(adj_spec_pro_v2.spec_score)>2,:]
# Out:
#     Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0            0   3497        HES1  0.960999  38.927892     0.783015
# 1            1   6314        SOX2  0.887134  25.167144     0.882203
# 2            2   6096     ZFP36L1  0.592609  26.384530     0.728080
# 3            3   4211        GLI3  0.557790  21.326204     0.753935
# 4            4   1872       CREB5  0.818472  13.319050     0.817875
# 5            5   3249       DACH1  0.937527   8.793763     0.915566
# 6            6   1778  AC016205.1  0.384186  30.542862     0.530698
# 7            7   3034         VIM  1.476532   7.270665     0.911891
# 8            8    633       NPAS3  0.855277   8.743269     0.829101
# 9            9   4531       HMGB2  1.051908   8.155083     0.842034
# 10          10   5510       TTYH1  0.654476  11.403738     0.752176
# 11          11      9   LINC01965  0.422536  33.348677     0.464694
# 12          12    783       FBXL7  0.528434  12.465938     0.683680
# ...

# %%
np.percentile(np.log((adj_spec_pro_v2["per_exp_con"]/adj_spec_pro_v2["per_exp_other"])+1e-6),90)
# Out:
# np.float64(1.1119630505852913)

# %%
#also here we may apply the same rules
adj_spec_pro_v2.loc[(stats.zscore(adj_spec_pro_v2.spec_score)>2) & (adj_spec_rg_v2.exp_ratio>1) &(adj_spec_pro_v2.per_exp_con>0.3) &(np.log((adj_spec_pro_v2["per_exp_con"]/adj_spec_pro_v2["per_exp_other"])+1e-6)>1.1) ,:]
# Out:
#     Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0            0   3497        HES1  0.960999  38.927892     0.783015
# 1            1   6314        SOX2  0.887134  25.167144     0.882203
# 2            2   6096     ZFP36L1  0.592609  26.384530     0.728080
# 3            3   4211        GLI3  0.557790  21.326204     0.753935
# 4            4   1872       CREB5  0.818472  13.319050     0.817875
# 5            5   3249       DACH1  0.937527   8.793763     0.915566
# 6            6   1778  AC016205.1  0.384186  30.542862     0.530698
# 8            8    633       NPAS3  0.855277   8.743269     0.829101
# 9            9   4531       HMGB2  1.051908   8.155083     0.842034
# 10          10   5510       TTYH1  0.654476  11.403738     0.752176
# 11          11      9   LINC01965  0.422536  33.348677     0.464694
# 12          12    783       FBXL7  0.528434  12.465938     0.683680
# 13          13    460        DOK5  0.607263   9.808078     0.746259
# ...

# %%
sc.pl.umap(adata_v2, color="ZWINT",vmax=5)#very good

# %%
sig_adj_spec_pro_v2=adj_spec_pro_v2.loc[(stats.zscore(adj_spec_pro_v2.spec_score)>2) & (adj_spec_rg_v2.exp_ratio>1) &(adj_spec_pro_v2.per_exp_con>0.3) &(np.log((adj_spec_pro_v2["per_exp_con"]/adj_spec_pro_v2["per_exp_other"])+1e-6)>1.1) ,:]

# %%
spec_pro_v3.loc[stats.zscore(spec_pro_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0   3341  AC011139.1  0.013775     0.071946       0.000280
# 1             1     70      IFI44L  0.051236     0.212868       0.002086
# 2             2     62        AMBN  0.046057     0.164206       0.001961
# 3             3     42      ATP1A2  0.067412     0.239030       0.004187
# 4             4     57    HIST1H3B  0.051320     0.215709       0.003222
# ..          ...    ...         ...       ...          ...            ...
# 303         303  11645       KRT18  0.012261     0.051054       0.004825
# 304         304   9457     TP53I13  0.048511     0.229649       0.018679
# 305         305   3428       NR2E1  0.171915     0.569424       0.055881
# 306         306  11533     TMEM45A  0.013251     0.058678       0.005635
# 307         307   4215       GSTM4  0.015866     0.076263       0.006429
#
#      spec_score
# 0        258.56
# 1        118.07
# 2        114.56
# 3         88.41
# ...

# %%
np.percentile(spec_pro_v3.per_exp_other, 10)
# Out:
# np.float64(0.0489851192329244)

# %%
np.percentile((np.log(spec_pro_v3['spec_score'] + 1e-6)),95)
# Out:
# np.float64(1.919859618482926)

# %%
spec_pro_v3.loc[(np.log(spec_pro_v3['spec_score'] + 1e-6)>1.91)&(spec_pro_v3.per_exp_other<=np.percentile(spec_pro_v3.per_exp_other, 10)),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0   3341  AC011139.1  0.013775     0.071946       0.000280
# 1             1     70      IFI44L  0.051236     0.212868       0.002086
# 2             2     62        AMBN  0.046057     0.164206       0.001961
# 3             3     42      ATP1A2  0.067412     0.239030       0.004187
# 4             4     57    HIST1H3B  0.051320     0.215709       0.003222
# ..          ...    ...         ...       ...          ...            ...
# 605         605   4267       MBNL3  0.042562     0.163477       0.023598
# 606         606  11444       LMCD1  0.018366     0.080767       0.013106
# 608         608    630    C6orf118  0.026407     0.109247       0.020516
# 611         611   1781  AL035078.4  0.049537     0.170653       0.027396
# 612         612   7006        NID1  0.023951     0.098726       0.016764
#
#      spec_score
# 0        258.56
# 1        118.07
# 2        114.56
# 3         88.41
# ...

# %%
sc.pl.umap(adata_v3, color="NID1",vmax=1)#GOOD

# %%
sig_spec_pro_v3=spec_pro_v3.loc[(np.log(spec_pro_v3['spec_score'] + 1e-6)>1.91)&(spec_pro_v3.per_exp_other<=np.percentile(spec_pro_v3.per_exp_other, 10)),:]

# %%
sig_spec_pro_v3_2=spec_pro_v3.loc[(np.log(spec_pro_v3['spec_score'] + 1e-6)>1.91),:]

# %%
spec_pro_v2.loc[stats.zscore(spec_pro_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     41      IFI44L  0.072146     0.149861       0.002267
# 1             1   6016     C2orf48  0.027681     0.065323       0.000933
# 2             2     36        AMBN  0.042418     0.092685       0.001583
# 3             3   7742        CRB2  0.195313     0.345034       0.008007
# 4             4   2225  AC087632.1  0.139011     0.262422       0.005940
# ..          ...    ...         ...       ...          ...            ...
# 334         334     40        MXD3  0.103012     0.196461       0.018553
# 335         335    815      FBXO32  0.162870     0.240253       0.028119
# 336         336   5050       FBXO5  0.189602     0.326844       0.035063
# 337         337   3339       STK33  0.078483     0.153495       0.013392
# 338         338   1805      KLHL13  0.076954     0.150940       0.013676
#
#      spec_score
# 0         70.00
# 1         63.14
# 2         59.48
# 3         52.49
# ...

# %%
np.percentile((np.log(spec_pro_v2['spec_score'] + 1e-6)),90)
# Out:
# np.float64(1.203572304712038)

# %%
spec_pro_v2.loc[(np.log(spec_pro_v2['spec_score'] + 1e-6)>1.20)&(spec_pro_v2.per_exp_other<=np.percentile(spec_pro_v2.per_exp_other, 10)),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     41      IFI44L  0.072146     0.149861       0.002267
# 1             1   6016     C2orf48  0.027681     0.065323       0.000933
# 2             2     36        AMBN  0.042418     0.092685       0.001583
# 3             3   7742        CRB2  0.195313     0.345034       0.008007
# 4             4   2225  AC087632.1  0.139011     0.262422       0.005940
# ..          ...    ...         ...       ...          ...            ...
# 898         898   4915    ARHGEF26  0.064595     0.113535       0.034532
# 901         901   4707     RHOBTB1  0.059534     0.101011       0.029891
# 904         904   1410       MINCR  0.046708     0.079983       0.024612
# 905         905   6521        CCNF  0.057205     0.105608       0.031107
# 906         906   5029     TMEM109  0.035265     0.065448       0.019510
#
#      spec_score
# 0         70.00
# 1         63.14
# 2         59.48
# 3         52.49
# ...

# %%
sc.pl.umap(adata_v2, color="ECEL1",vmax=1)#GOOD- ALTHOUGH MORE IN RADIAL GLIA..

# %%
sc.pl.umap(adata_v2, color="NOTCH1",vmax=1)

# %%
sig_spec_pro_v2=spec_pro_v2.loc[(np.log(spec_pro_v2['spec_score'] + 1e-6)>2.08)&(spec_pro_v2.per_exp_other<=np.percentile(spec_pro_v2.per_exp_other, 10)),:]

# %%
sig_spec_pro_v2_2=spec_pro_v2.loc[(np.log(spec_pro_v2['spec_score'] + 1e-6)>2.08),:]

# %%
#intersections

# %%
fisher_test(hsg,sig_adj_spec_pro_v3)
# Out:
# (['PDGFD', 'ZFP36L1', 'ASPM'], np.float64(0.22355605731937464))

# %%
fisher_test(hsg,sig_adj_spec_pro_v2)##ahh
# Out:
# (['PDGFD', 'ZFP36L1', 'CDH12'], np.float64(0.0447672411708384))

# %%
fisher_test(hsg,sig_spec_pro_v3)
# Out:
# (['SPAG5',
#   'RIBC2',
#   'PDGFD',
#   'FAM72D',
#   'ELN',
#   'KIF18A',
#   'FANK1',
#   'NBPF14',
#   'NEK2',
#   'ASPM',
#   'AR',
#   'FAM72B',
#   'FAM72C'],
#  np.float64(0.06573499799691679))

# %%
fisher_test(hsg,sig_spec_pro_v3_2)#non sig
# Out:
# (['ZFP36L1',
#   'SPAG5',
#   'RIBC2',
#   'PDGFD',
#   'FAM72D',
#   'ELN',
#   'KIF18A',
#   'FANK1',
#   'GYPC',
#   'NBPF14',
#   'NEK2',
#   'ASPM',
#   'AR',
#   'FAM72B',
#   'FAM72C'],
#  np.float64(0.09488186009232553))

# %%
fisher_test(hsg,sig_spec_pro_v2)
#significant- most of those genes, except spag5 and PDGFD where enriched in the rg state
# Out:
# (['SPAG5',
#   'FAM72D',
#   'PDGFD',
#   'KIF18A',
#   'NBPF14',
#   'NEK2',
#   'PARP4',
#   'ASPM',
#   'FAM72C'],
#  np.float64(0.22233007247206077))

# %%
fisher_test(hsg,sig_spec_pro_v2_2)
# Out:
# (['ZFP36L1',
#   'SPAG5',
#   'FAM72D',
#   'CDH12',
#   'PDGFD',
#   'KIF18A',
#   'NBPF14',
#   'NEK2',
#   'PARP4',
#   'ASPM',
#   'FAM72C'],
#  np.float64(0.12431133416858932))

# %%
sig_spec_pro_v2.loc[sig_spec_pro_v2.gene.isin([ i for i in hsg["gene"].tolist() if i in sig_spec_pro_v2["gene"].tolist()]),:]
# Out:
#      Unnamed: 0  index    gene  mean_exp  per_exp_con  per_exp_other  \
# 30           30   5771  FAM72C  0.019970     0.050757       0.001323
# 52           52   6879  FAM72D  0.030357     0.073815       0.002315
# 53           53   2416   PDGFD  0.203649     0.334897       0.013558
# 64           64   3150  KIF18A  0.099828     0.194063       0.007924
# 92           92   4010   SPAG5  0.046208     0.109723       0.004145
# 126         126   5094    NEK2  0.085997     0.154678       0.008361
# 138         138   4796    ASPM  0.189346     0.283449       0.018246
# 184         184   4209  NBPF14  0.055191     0.118603       0.007050
# 421         421   5532   PARP4  0.032580     0.065302       0.007440
#
#      spec_score
# 30        33.73
# 52        29.14
# 53        29.01
# 64        27.46
# 92        24.51
# 126       21.86
# 138       21.19
# 184       18.10
# 421        8.75

# %%
spec_pro_v2.loc[spec_pro_v2.gene.isin([ i for i in hsg["gene"].tolist() if i in spec_pro_v2["gene"].tolist()]),:][:20]
# Out:
#       Unnamed: 0  index     gene  mean_exp  per_exp_con  per_exp_other  \
# 30            30   5771   FAM72C  0.019970     0.050757       0.001323
# 52            52   6879   FAM72D  0.030357     0.073815       0.002315
# 53            53   2416    PDGFD  0.203649     0.334897       0.013558
# 64            64   3150   KIF18A  0.099828     0.194063       0.007924
# 74            74   8243  ZFP36L1  0.592609     0.728080       0.047393
# 92            92   4010    SPAG5  0.046208     0.109723       0.004145
# 126          126   5094     NEK2  0.085997     0.154678       0.008361
# 138          138   4796     ASPM  0.189346     0.283449       0.018246
# 184          184   4209   NBPF14  0.055191     0.118603       0.007050
# 238          238   2011    CDH12  0.424851     0.538049       0.046188
# 421          421   5532    PARP4  0.032580     0.065302       0.007440
# 472          472   3493     GYPC  0.073489     0.144217       0.020041
# ...

# %%
sig_spec_pro_v3.loc[sig_spec_pro_v3.gene.isin([ i for i in hsg["gene"].tolist() if i in sig_spec_pro_v3["gene"].tolist()]),:]
# Out:
#      Unnamed: 0  index    gene  mean_exp  per_exp_con  per_exp_other  \
# 71           71   6958    NEK2  0.072793     0.217858       0.010242
# 72           72   7753  FAM72C  0.011010     0.066116       0.001774
# 120         120   5706   SPAG5  0.055838     0.248505       0.011192
# 133         133   6611    ASPM  0.212008     0.438537       0.039225
# 141         141   9086  FAM72D  0.020359     0.107826       0.004530
# 161         161   3844   PDGFD  0.228547     0.532441       0.040969
# 198         198     67  FAM72B  0.012153     0.072544       0.003658
# 326         326   4717  KIF18A  0.114191     0.333888       0.041996
# 388         388    833   RIBC2  0.014482     0.070190       0.006335
# 397         397   2947     ELN  0.019714     0.092316       0.008639
# 407         407   5936  NBPF14  0.060868     0.260073       0.030727
# 488         488   9763      AR  0.035034     0.142211       0.016749
# 507         507    356   FANK1  0.013933     0.053483       0.007020
#
# ...

# %%
#reverse action- hsg in the full adj_spec lists
adj_spec_pro_v3.loc[adj_spec_pro_v3.gene.isin(hsg["gene"].tolist()),:][:20]
# Out:
#       Unnamed: 0  index     gene  mean_exp  exp_ratio  per_exp_con  \
# 2              2   9282  ZFP36L1  0.456467  36.145681     0.826525
# 39            39   2955    PDGFD  0.228547  21.067245     0.532441
# 62            62   5536     ASPM  0.212008  24.059673     0.438537
# 116          116   2499    CDH12  0.358465   6.614519     0.594353
# 190          190   4010  C1orf61  1.561392   1.705574     0.992675
# 479          479   9277     SRP9  1.168796   1.217630     0.976846
# 539          539   9319    PDCD4  0.328449   2.740401     0.703524
# 567          567   3749   KIF18A  0.114191  12.791656     0.333888
# 595          595   4487    RBM39  0.978591   1.206405     0.960028
# 630          630   9577     MSI2  0.916095   1.333530     0.875206
# 675          675   5849     NEK2  0.072793  34.676253     0.217858
# 777          777   2895    PRKDC  0.622948   1.464679     0.840017
# 892          892   4681    SPAG5  0.055838  26.083127     0.248505
# ...

# %%
#maybe do some kind of bootstrap with the rankings...?

# %%
#maybe rank also based on the difference between the sets.. + low number of per_exp_other

# %%
np.percentile(np.log((spec_pro_v2["per_exp_con"]/spec_pro_v2["per_exp_other"])+1e-6),90)
# Out:
# np.float64(1.1728869532785844)

# %%
sig_spec_pro_v2_3=spec_pro_v2.loc[(np.log(spec_pro_v2['spec_score'] + 1e-6)>1.2)&(spec_pro_v2.per_exp_other<=np.percentile(spec_pro_v2.per_exp_other, 10))&(((np.log(spec_pro_v2["per_exp_con"]/spec_pro_v2["per_exp_other"])+1e-6))>1.17),:]

# %%
sig_spec_pro_v2_3
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     41      IFI44L  0.072146     0.149861       0.002267
# 1             1   6016     C2orf48  0.027681     0.065323       0.000933
# 2             2     36        AMBN  0.042418     0.092685       0.001583
# 3             3   7742        CRB2  0.195313     0.345034       0.008007
# 4             4   2225  AC087632.1  0.139011     0.262422       0.005940
# ..          ...    ...         ...       ...          ...            ...
# 898         898   4915    ARHGEF26  0.064595     0.113535       0.034532
# 901         901   4707     RHOBTB1  0.059534     0.101011       0.029891
# 904         904   1410       MINCR  0.046708     0.079983       0.024612
# 905         905   6521        CCNF  0.057205     0.105608       0.031107
# 906         906   5029     TMEM109  0.035265     0.065448       0.019510
#
#      spec_score
# 0         70.00
# 1         63.14
# 2         59.48
# 3         52.49
# ...

# %%
fisher_test(hsg,sig_spec_pro_v2_3)
# Out:
# (['SPAG5',
#   'FAM72D',
#   'PDGFD',
#   'FAM182B',
#   'KIF18A',
#   'GYPC',
#   'EIF1AY',
#   'NBPF14',
#   'DDX11',
#   'ZNF492',
#   'NEK2',
#   'PARP4',
#   'ASPM',
#   'FAM72C'],
#  np.float64(0.20212430230377917))

# %%
#play with ranks cause they are not correct, also thinik about another measure for the ratio..
import numpy as np
from scipy.stats import ks_2samp

ranked_genes=sig_spec_pro_v2_3["gene"].tolist()
# Get ranks of genes in the ranked list
ranks = {gene: i + 1 for i, gene in enumerate(ranked_genes)}

# Extract ranks for genes in set2
gene_set_ranks = [ranks[gene] for gene in hsg_in_data["gene"] if gene in ranks]

# Create an array of all ranks and assign a rank of len(ranked_genes)+1 to missing genes
all_ranks = np.array([ranks[gene] if gene in ranks else len(ranked_genes) + 1 for gene in hsg_in_data["gene"]])

# Perform KS test to check if gene set ranks are skewed to lower ranks
ks_stat, p_value = ks_2samp(all_ranks, np.arange(1, len(ranked_genes) + 1))

print(f"KS Statistic: {ks_stat}, P-value: {p_value}")
# Out:
# KS Statistic: 0.9706498951781971, P-value: 2.085024620024511e-297

# %%
spec_pro_v2.loc[spec_pro_v2.gene.isin(hsg["gene"].tolist()),:][:20]
# Out:
#       Unnamed: 0  index     gene  mean_exp  per_exp_con  per_exp_other  \
# 30            30   5771   FAM72C  0.019970     0.050757       0.001323
# 52            52   6879   FAM72D  0.030357     0.073815       0.002315
# 53            53   2416    PDGFD  0.203649     0.334897       0.013558
# 64            64   3150   KIF18A  0.099828     0.194063       0.007924
# 74            74   8243  ZFP36L1  0.592609     0.728080       0.047393
# 92            92   4010    SPAG5  0.046208     0.109723       0.004145
# 126          126   5094     NEK2  0.085997     0.154678       0.008361
# 138          138   4796     ASPM  0.189346     0.283449       0.018246
# 184          184   4209   NBPF14  0.055191     0.118603       0.007050
# 238          238   2011    CDH12  0.424851     0.538049       0.046188
# 421          421   5532    PARP4  0.032580     0.065302       0.007440
# 472          472   3493     GYPC  0.073489     0.144217       0.020041
# ...

# %%
np.mean(spec_pro_v2["spec_score"])#lets go above this mean
# Out:
# np.float64(2.2488557489743872)

# %%
np.percentile(spec_pro_v2["spec_score"],90)
# Out:
# np.float64(3.331999999999998)

# %%
spec_pro_v2.loc[(spec_pro_v2['spec_score'] >3.33)&(spec_pro_v2.per_exp_other<=np.percentile(spec_pro_v3.per_exp_other, 5)),:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  per_exp_con  per_exp_other  \
# 0             0     41      IFI44L  0.072146     0.149861       0.002267
# 1             1   6016     C2orf48  0.027681     0.065323       0.000933
# 2             2     36        AMBN  0.042418     0.092685       0.001583
# 3             3   7742        CRB2  0.195313     0.345034       0.008007
# 4             4   2225  AC087632.1  0.139011     0.262422       0.005940
# ..          ...    ...         ...       ...          ...            ...
# 862         862   3166      ANKRD6  0.044939     0.077837       0.022250
# 863         863   3317       EGLN3  0.048039     0.087858       0.024624
# 866         866   8856       AKAP7  0.033205     0.059124       0.015872
# 873         873   3093        ELF1  0.029440     0.052872       0.015176
# 885         885    262       EVA1C  0.051400     0.078580       0.025202
#
#      spec_score
# 0         70.00
# 1         63.14
# 2         59.48
# 3         52.49
# ...

# %%
sc.pl.umap(adata_v2, color="RHOBTB1",vmax=1)#?

# %%
sig_spec_pro_v2_2=spec_pro_v2.loc[(spec_pro_v2['spec_score'] >3.33)&(spec_pro_v2.per_exp_other<=np.percentile(spec_pro_v2.per_exp_other, 5)),:]

# %%
sig_spec_pro_v3_3=spec_pro_v3.loc[(spec_pro_v3['spec_score'] >6.82)&(spec_pro_v3.per_exp_other<=np.percentile(spec_pro_v3.per_exp_other, 10)),:]

# %%
spec_pro_v3_3=spec_pro_v3.loc[(spec_pro_v3['spec_score'] >3.22),:]

# %%
fisher_test(hsg,sig_spec_pro_v3_3)#no
# Out:
# (['SPAG5',
#   'RIBC2',
#   'PDGFD',
#   'FAM72D',
#   'ELN',
#   'KIF18A',
#   'FANK1',
#   'NBPF14',
#   'NEK2',
#   'ASPM',
#   'AR',
#   'FAM72B',
#   'FAM72C'],
#  np.float64(0.06355343415716905))

# %%
fisher_test(hsg,sig_spec_pro_v2_2)#no
# Out:
# (['SPAG5',
#   'FAM72D',
#   'PDGFD',
#   'FAM182B',
#   'KIF18A',
#   'EIF1AY',
#   'NBPF14',
#   'NEK2',
#   'PARP4',
#   'FAM72C'],
#  np.float64(0.2368943541988082))

# %%
#speceficity- mhow much is it disperesed among cells, how much to restrict the per_other and the per_con down

# %%
#adj_spec_ go over the criteria, is it too harsh? is it not?

# %%
sns.displot(spec_pro_v3,x= np.log(spec_pro_v3['spec_score'] + 1e-6))

# %%
#thinking about removing speceficity from

# %%
with rc_context({"figure.figsize": (3, 3)}):
    sc.pl.umap(adata, color=["PDGFD","SPAG5","CellClass"],ncols=3,color_map=mymap,frameon=False,vmax=15)
    sc.pl.umap(adata, color=["Age","CellCyclePhase"],ncols=2,frameon=False)
    #"Age","CellCyclePhase"

# %%
#GENESTHAT WERE SIGNIFICANT BEFORE
"PARP4","GYPC"

# %%
spec_pro_v2.loc[spec_pro_v2["gene"]=="PARP4",:]
# Out:
#      Unnamed: 0  index   gene  mean_exp  per_exp_con  per_exp_other  \
# 421         421   5532  PARP4   0.03258     0.065302        0.00744
#
#      spec_score
# 421        8.75

# %%
sc.pl.umap(adata_v3, color="PARP4",vmax=1)#ok

# %%
"TCF7L2" in hsg["gene"].tolist()
# Out:
# False

# %%
with rc_context({"figure.figsize": (3, 3)}):
    sc.pl.umap(adata, color=["NBPF14","TCF7L2","EIF1AY","PARP4","FAM72D","GYPC","NEK2","KIF18A","CellClass"],ncols=3,color_map=mymap,frameon=False,vmax=15)
    sc.pl.umap(adata, color=["Age","CellCyclePhase"],ncols=3,frameon=False)

# %% [markdown]
# NEK2- This gene encodes a serine/threonine-protein kinase that is involved in mitotic regulation. This protein is localized to the centrosome, and undetectable during G1 phase, but accumulates progressively throughout the S phase, reaching maximal levels in late G2 phase. GENE DUPLICATION.
# KIF18A-KIF18A is a member of the kinesin superfamily of microtubule-associated molecular motors (see MIM 148760) that use hydrolysis of ATP to produce force and movement along microtubules. The protein is expressed in the germinal zones during mid-fetal brain development. These data suggest that the centrosome-associated cell division machinery may be critical to neocortical evolution
# FAM72D-belong to gene duplication family, in this article related to neural stem cell renwall https://www.sciencedirect.com/science/article/pii/S0197018624001803

# %%
fisher_test(hsg,sig_spec_rg_v3)
#kaha_kaha
# Out:
# (['STRA6', 'PRKCB', 'FANK1', 'ZFP36L1', 'FAM72C', 'NEK2'],
#  np.float64(0.06488974569803027))

# %%
fisher_test(hsg,sig_spec_ipc_v2)
# Out:
# (['FAM72C',
#   'FAM72B',
#   'LYPD1',
#   'GADD45G',
#   'FAM72D',
#   'ARHGAP42',
#   'GKAP1',
#   'SPAG5',
#   'ZNF492',
#   'KIF18A',
#   'NEK2',
#   'ASPM'],
#  np.float64(0.0779797619954392))

# %%
fisher_test(hsg,sig_spec_ipc_v3)
# Out:
# (['FAM72C',
#   'FAM72B',
#   'RIBC2',
#   'LYPD1',
#   'GADD45G',
#   'FAM72D',
#   'SYT2',
#   'ACVR1C',
#   'KIF26B',
#   'SPAG5',
#   'ZNF492',
#   'KIF18A',
#   'NEK2',
#   'ASPM'],
#  np.float64(0.1262832995827437))

# %%
fisher_test(hsg,sig_spec_pro_v3)
# Out:
# (['FZD8', 'PDGFD', 'SPAG5', 'FAM72D', 'ZFP36L1', 'KIF18A', 'NEK2', 'ASPM'],
#  np.float64(0.26683554227094025))

# %%
fisher_test(hsg,sig_spec_pro_v2)
# Out:
# (['CDH12',
#   'NBPF14',
#   'FZD8',
#   'PDGFD',
#   'SPAG5',
#   'ZFP36L1',
#   'KIF18A',
#   'NEK2',
#   'ASPM'],
#  np.float64(0.10308306378204507))

# %%
#other enricxhments not enriched at all

# %%
adata.obs["CellCyclePhase"].unique()
# Out:
# ['Non-cycling', 'PostM', 'S', 'G1', 'G2M']
# Categories (5, object): ['G1', 'G2M', 'Non-cycling', 'PostM', 'S']

# %%
#g2m
adj_spec_g2m_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellCyclePhase_G2M.csv")
adj_spec_g2m_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellCyclePhase_G2M.csv")
spec_g2m_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v3_CellCyclePhase_G2M.csv")
spec_g2m_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v2_CellCyclePhase_G2M.csv")

# %%
adj_spec_g2m_v3.head()
# Out:
#    Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  per_exp_other  \
# 0           0  14498   PLK1  0.091422  24.074309     0.985102       0.084815
# 1           1   9030  CCNB1  0.163658  18.022941     0.998432       0.147950
# 2           2  11669   NEK2  0.072793  26.158928     0.969681       0.075538
# 3           3  11735  CDC20  0.138970  17.997961     0.995818       0.121452
# 4           4  14373  UBE2C  0.299501  12.787970     0.999216       0.231976
#
#    spec_score
# 0       40.69
# 1       39.57
# 2       37.89
# 3       35.94
# 4       33.59

# %%
adj_spec_g2m_v2.head()
# Out:
#    Unnamed: 0  index   gene  mean_exp  exp_ratio  per_exp_con  per_exp_other  \
# 0           0  11330   PLK1  0.116330  22.571019     0.915616       0.059529
# 1           1   6311  CCNB1  0.182962  16.625958     0.963946       0.100106
# 2           2   8803  CDC20  0.187565  15.399555     0.968591       0.101661
# 3           3  11211  UBE2C  0.435641   9.662549     0.997788       0.246377
# 4           4   7333  AURKA  0.097218  21.988596     0.865959       0.054059
#
#    spec_score
# 0       32.19
# 1       31.40
# 2       29.03
# 3       25.04
# 4       24.61

# %%
spec_g2m_v3.head()
# Out:
#    Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0  15900        PIF1  0.037101  37.387649     0.872452
# 1           1  12718       PDCL2  0.001898  26.982214     0.083116
# 2           2  11669        NEK2  0.072793  26.158928     0.969681
# 3           3   9280  AC090159.1  0.002401  24.138224     0.096707
# 4           4  14498        PLK1  0.091422  24.074309     0.985102
#
#    per_exp_other  spec_score
# 0       0.034109       37.39
# 1       0.002756       26.98
# 2       0.075538       26.16
# 3       0.003950       24.14
# 4       0.084815       24.07

# %%
spec_g2m_v2.head()
# Out:
#    Unnamed: 0  index    gene  mean_exp  exp_ratio  per_exp_con  per_exp_other  \
# 0           0  12617    PIF1  0.045283  44.476630     0.675182       0.017139
# 1           1   8740    NEK2  0.085997  24.264997     0.828467       0.046679
# 2           2   9591  FAM72C  0.019970  23.147231     0.302256       0.013008
# 3           3  13224  GAS2L3  0.074814  22.765200     0.758903       0.041694
# 4           4  11330    PLK1  0.116330  22.571019     0.915616       0.059529
#
#    spec_score
# 0       44.48
# 1       24.26
# 2       23.15
# 3       22.77
# 4       22.57

# %%
#from scipy import stats
adj_spec_g2m_v3.loc[stats.zscore(adj_spec_g2m_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0  14498       PLK1  0.091422  24.074309     0.985102
# 1             1   9030      CCNB1  0.163658  18.022941     0.998432
# 2             2  11669       NEK2  0.072793  26.158928     0.969681
# 3             3  11735      CDC20  0.138970  17.997961     0.995818
# 4             4  14373      UBE2C  0.299501  12.787970     0.999216
# ..          ...    ...        ...       ...        ...          ...
# 158         158  16039     IQGAP3  0.044837   9.973285     0.674595
# 159         159  11534  LINC01572  0.276989   3.290967     0.885259
# 160         160   5327      FBXL7  0.628671   2.209733     0.929430
# 161         161  15055      CENPW  0.174718   3.917130     0.874804
# 162         162  16315      SCLT1  0.363359   2.841622     0.923419
#
#      per_exp_other  spec_score
# 0         0.084815       40.69
# 1         0.147950       39.57
# 2         0.075538       37.89
# ...

# %%
sig_adj_spec_g2m_v3=adj_spec_g2m_v3.loc[stats.zscore(adj_spec_g2m_v3.spec_score)>2,:]

# %%
adj_spec_g2m_v2.loc[stats.zscore(adj_spec_g2m_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index    gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0  11330    PLK1  0.116330  22.571019     0.915616
# 1             1   6311   CCNB1  0.182962  16.625958     0.963946
# 2             2   8803   CDC20  0.187565  15.399555     0.968591
# 3             3  11211   UBE2C  0.435641   9.662549     0.997788
# 4             4   7333   AURKA  0.097218  21.988596     0.865959
# ..          ...    ...     ...       ...        ...          ...
# 133         133  13105    SOX2  0.887134   1.912828     0.880226
# 134         134   7004     RAN  1.372704   1.503674     0.992037
# 135         135   9710   CIP2A  0.130097   5.781399     0.661248
# 136         136   3328    PAX6  0.532511   2.281228     0.887304
# 137         137   8274  MPPED2  0.969621   1.724376     0.955430
#
#      per_exp_other  spec_score
# 0         0.059529       32.19
# 1         0.100106       31.40
# 2         0.101661       29.03
# 3         0.246377       25.04
# ...

# %%
adj_spec_g2m_v2.loc[(stats.zscore(adj_spec_g2m_v2.spec_score)>2)&(adj_spec_g2m_v2.per_exp_con>adj_spec_g2m_v2.per_exp_other),:]
# Out:
#      Unnamed: 0  index    gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0  11330    PLK1  0.116330  22.571019     0.915616
# 1             1   6311   CCNB1  0.182962  16.625958     0.963946
# 2             2   8803   CDC20  0.187565  15.399555     0.968591
# 3             3  11211   UBE2C  0.435641   9.662549     0.997788
# 4             4   7333   AURKA  0.097218  21.988596     0.865959
# ..          ...    ...     ...       ...        ...          ...
# 133         133  13105    SOX2  0.887134   1.912828     0.880226
# 134         134   7004     RAN  1.372704   1.503674     0.992037
# 135         135   9710   CIP2A  0.130097   5.781399     0.661248
# 136         136   3328    PAX6  0.532511   2.281228     0.887304
# 137         137   8274  MPPED2  0.969621   1.724376     0.955430
#
#      per_exp_other  spec_score
# 0         0.059529       32.19
# 1         0.100106       31.40
# 2         0.101661       29.03
# 3         0.246377       25.04
# ...

# %%
sig_adj_spec_g2m_v2=adj_spec_g2m_v2.loc[(stats.zscore(adj_spec_g2m_v2.spec_score)>2)&(adj_spec_g2m_v2.per_exp_con>adj_spec_g2m_v2.per_exp_other),:]

# %%
spec_g2m_v3.loc[stats.zscore(spec_g2m_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0  15900        PIF1  0.037101  37.387649     0.872452
# 1             1  12718       PDCL2  0.001898  26.982214     0.083116
# 2             2  11669        NEK2  0.072793  26.158928     0.969681
# 3             3   9280  AC090159.1  0.002401  24.138224     0.096707
# 4             4  14498        PLK1  0.091422  24.074309     0.985102
# ..          ...    ...         ...       ...        ...          ...
# 352         352  13230   LINC01515  0.094351   3.520809     0.502091
# 353         353  16261       HLA-B  0.018347   3.507303     0.172504
# 354         354  15232       CENPC  0.254282   3.497324     0.926817
# 355         355   3983  AC002558.2  0.002620   3.495909     0.029796
# 356         356   2871        FIGN  0.162046   3.502180     0.700470
#
#      per_exp_other  spec_score
# 0         0.034109       37.39
# 1         0.002756       26.98
# 2         0.075538       26.16
# ...

# %%
#results are convincing enougth this way.
sig_spec_g2m_v3=spec_g2m_v3.loc[stats.zscore(spec_g2m_v3.spec_score)>2,:]

# %%
spec_g2m_v2.loc[stats.zscore(spec_g2m_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0  12617        PIF1  0.045283  44.476630     0.675182
# 1             1   8740        NEK2  0.085997  24.264997     0.828467
# 2             2   9591      FAM72C  0.019970  23.147231     0.302256
# 3             3  13224      GAS2L3  0.074814  22.765200     0.758903
# 4             4  11330        PLK1  0.116330  22.571019     0.915616
# ..          ...    ...         ...       ...        ...          ...
# 270         270  10036       TGIF1  0.195884   3.826506     0.693762
# 271         271  11096    H1FX-AS1  0.033580   3.813196     0.166888
# 272         272   5176  DIAPH3-AS1  0.004838   3.795707     0.024994
# 273         273   7423        MCAM  0.038783   3.789504     0.185468
# 274         274   2812  AL928654.1  0.017045   3.792790     0.084716
#
#      per_exp_other  spec_score
# 0         0.017139       44.48
# 1         0.046679       24.26
# 2         0.013008       23.15
# ...

# %%
sig_spec_g2m_v2=spec_g2m_v2.loc[stats.zscore(spec_g2m_v2.spec_score)>2,:]

# %%
#intersections

# %%
fisher_test(hsg,sig_adj_spec_g2m_v3)
# Out:
# (['KIF18A', 'NEK2', 'SPAG5', 'ASPM'], np.float64(0.3616801962001313))

# %%
fisher_test(hsg,sig_adj_spec_g2m_v2)
# Out:
# (['KIF18A', 'NEK2', 'ASPM'], np.float64(0.5074841912546252))

# %%
fisher_test(hsg,sig_spec_g2m_v3)
#kind of
#fam family enrochment
# Out:
# (['FAM72C',
#   'FAM72B',
#   'CD96',
#   'FAM95B1',
#   'SPAG5',
#   'MYLK2',
#   'ZNF850',
#   'FAM72D',
#   'KIF18A',
#   'NEK2',
#   'ASPM'],
#  np.float64(0.05853608863652911))

# %%
fisher_test(hsg,sig_spec_g2m_v2)
# Out:
# (['FAM72C', 'FAM72B', 'SPAG5', 'ZNF850', 'FAM72D', 'KIF18A', 'NEK2', 'ASPM'],
#  np.float64(0.1498524427155466))

# %%
#s phase
adj_spec_s_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellCyclePhase_S.csv")
adj_spec_s_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellCyclePhase_S.csv")
spec_s_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v3_CellCyclePhase_S.csv")
spec_s_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v2_CellCyclePhase_S.csv")

# %%
adj_spec_s_v3.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1           1     77   HIST1H1B  0.099459  19.617977     0.777370
# 2           2   6011   HIST1H4C  1.108086   4.707637     1.000000
# 3           3   5573   HIST1H1A  0.144922  13.097078     0.832803
# 4           4   3793      SPC25  0.179435  10.408504     0.889965
#
#    per_exp_other  spec_score
# 0       0.035845       16.36
# 1       0.059261       12.28
# 2       0.779287       11.43
# 3       0.115153       11.11
# 4       0.129083       11.01

# %%
adj_spec_s_v2.head()
# Out:
#    Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0   4483  HIST1H4C  0.792649   6.539680     0.999903
# 1           1   5867     TOP2A  0.472597   5.114684     0.937998
# 2           2   2725     SPC25  0.245736   6.989310     0.828134
# 3           3   8922     HMGB2  1.051908   3.062979     0.996987
# 4           4   9721      CDK1  0.377297   4.398839     0.861953
#
#    per_exp_other  spec_score
# 0       0.393120       16.74
# 1       0.192518        8.61
# 2       0.141481        6.80
# 3       0.497381        6.69
# 4       0.193239        5.06

# %%
spec_s_v3.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1           1     83   HIST1H3B  0.051320  26.178221     0.604567
# 2           2     82  HIST1H2AI  0.013582  23.221731     0.211972
# 3           3     70  HIST1H2AM  0.070652  23.081309     0.660415
# 4           4     78  HIST1H2AH  0.029836  22.003694     0.421038
#
#    per_exp_other  spec_score
# 0       0.035845       31.87
# 1       0.029175       26.18
# 2       0.009177       23.22
# 3       0.041508       23.08
# 4       0.021644       22.00

# %%
spec_s_v2.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     62  HIST1H2AJ  0.030919  19.602972     0.236443
# 1           1     54  HIST1H2AM  0.032025  15.948846     0.229835
# 2           2   4089   HIST1H1A  0.041192  15.180505     0.287512
# 3           3     59   HIST1H1B  0.018586  14.360240     0.141108
# 4           4     60  HIST1H2AH  0.018228  12.786401     0.134305
#
#    per_exp_other  spec_score
# 0       0.013209       19.60
# 1       0.015026       15.95
# 2       0.020315       15.18
# 3       0.009900       14.36
# 4       0.010164       12.79

# %%
from scipy import stats
adj_spec_s_v3.loc[stats.zscore(adj_spec_s_v3.spec_score)>2,:]
#seems ok althoug the last results are a bit week
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1             1     77   HIST1H1B  0.099459  19.617977     0.777370
# 2             2   6011   HIST1H4C  1.108086   4.707637     1.000000
# 3             3   5573   HIST1H1A  0.144922  13.097078     0.832803
# 4             4   3793      SPC25  0.179435  10.408504     0.889965
# ..          ...    ...        ...       ...        ...          ...
# 451         451   3777       SOX3  0.298838   2.364777     0.732595
# 452         452   7457     DDX39A  0.272629   2.317567     0.798685
# 453         453  13528       PPIG  0.611364   1.418625     0.931903
# 454         454   7781      RBM39  0.978591   1.121342     0.975363
# 455         455   5897      PRKDC  0.622948   1.436888     0.915709
#
#      per_exp_other  spec_score
# 0         0.035845       16.36
# 1         0.059261       12.28
# 2         0.779287       11.43
# ...

# %%
adj_spec_s_v3.loc[(stats.zscore(adj_spec_s_v3.spec_score)>2) & (adj_spec_s_v3.exp_ratio>1) & (adj_spec_s_v3.per_exp_con>adj_spec_s_v3.per_exp_other),:]
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1             1     77   HIST1H1B  0.099459  19.617977     0.777370
# 2             2   6011   HIST1H4C  1.108086   4.707637     1.000000
# 3             3   5573   HIST1H1A  0.144922  13.097078     0.832803
# 4             4   3793      SPC25  0.179435  10.408504     0.889965
# ..          ...    ...        ...       ...        ...          ...
# 451         451   3777       SOX3  0.298838   2.364777     0.732595
# 452         452   7457     DDX39A  0.272629   2.317567     0.798685
# 453         453  13528       PPIG  0.611364   1.418625     0.931903
# 454         454   7781      RBM39  0.978591   1.121342     0.975363
# 455         455   5897      PRKDC  0.622948   1.436888     0.915709
#
#      per_exp_other  spec_score
# 0         0.035845       16.36
# 1         0.059261       12.28
# 2         0.779287       11.43
# ...

# %%
sig_adj_spec_s_v3=adj_spec_s_v3.loc[(stats.zscore(adj_spec_s_v3.spec_score)>2) & (adj_spec_s_v3.exp_ratio>1) & (adj_spec_s_v3.per_exp_con>adj_spec_s_v3.per_exp_other),:]

# %%
adj_spec_s_v2.loc[stats.zscore(adj_spec_s_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   4483  HIST1H4C  0.792649   6.539680     0.999903
# 1             1   5867     TOP2A  0.472597   5.114684     0.937998
# 2             2   2725     SPC25  0.245736   6.989310     0.828134
# 3             3   8922     HMGB2  1.051908   3.062979     0.996987
# 4             4   9721      CDK1  0.377297   4.398839     0.861953
# ..          ...    ...       ...       ...        ...          ...
# 403         403   4130     PSMC3  0.556253   1.515066     0.731098
# 404         404   9373   RACGAP1  0.150062   4.140888     0.503936
# 405         405   2511      PPA1  1.095815   1.004433     0.838776
# 406         406   5570      LSM7  0.886186   1.114549     0.822157
# 407         407   8324      LHX2  0.435701   1.800865     0.674101
#
#      per_exp_other  spec_score
# 0         0.393120       16.74
# 1         0.192518        8.61
# 2         0.141481        6.80
# 3         0.497381        6.69
# ...

# %%
#also here we may apply the same rules
#clear weak results
adj_spec_s_v2.loc[(stats.zscore(adj_spec_s_v2.spec_score)>2) & (adj_spec_s_v2.exp_ratio>1) & (adj_spec_s_v2.per_exp_con>adj_spec_s_v2.per_exp_other),:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   4483  HIST1H4C  0.792649   6.539680     0.999903
# 1             1   5867     TOP2A  0.472597   5.114684     0.937998
# 2             2   2725     SPC25  0.245736   6.989310     0.828134
# 3             3   8922     HMGB2  1.051908   3.062979     0.996987
# 4             4   9721      CDK1  0.377297   4.398839     0.861953
# ..          ...    ...       ...       ...        ...          ...
# 403         403   4130     PSMC3  0.556253   1.515066     0.731098
# 404         404   9373   RACGAP1  0.150062   4.140888     0.503936
# 405         405   2511      PPA1  1.095815   1.004433     0.838776
# 406         406   5570      LSM7  0.886186   1.114549     0.822157
# 407         407   8324      LHX2  0.435701   1.800865     0.674101
#
#      per_exp_other  spec_score
# 0         0.393120       16.74
# 1         0.192518        8.61
# 2         0.141481        6.80
# 3         0.497381        6.69
# ...

# %%
sig_adj_spec_s_v2=adj_spec_s_v2.loc[(stats.zscore(adj_spec_s_v2.spec_score)>2) & (adj_spec_s_v2.exp_ratio>1) & (adj_spec_s_v2.per_exp_con>adj_spec_s_v2.per_exp_other),:]

# %%
spec_s_v3.loc[stats.zscore(spec_s_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1             1     83   HIST1H3B  0.051320  26.178221     0.604567
# 2             2     82  HIST1H2AI  0.013582  23.221731     0.211972
# 3             3     70  HIST1H2AM  0.070652  23.081309     0.660415
# 4             4     78  HIST1H2AH  0.029836  22.003694     0.421038
# ..          ...    ...        ...       ...        ...          ...
# 337         337  10794       CGAS  0.013606   3.174087     0.090104
# 338         338   5938      POLD1  0.062039   3.162849     0.376125
# 339         339   9516       TTF2  0.077835   3.150666     0.428166
# 340         340   5038     HIRIP3  0.139032   3.150357     0.659654
# 341         341   6599      HMGN5  0.160111   3.149900     0.688097
#
#      per_exp_other  spec_score
# 0         0.035845       31.87
# 1         0.029175       26.18
# 2         0.009177       23.22
# ...

# %%
#results are convincing enougth this way.. (and retaining sox2)
sig_spec_s_v3=spec_s_v3.loc[stats.zscore(spec_s_v3.spec_score)>2,:]

# %%
spec_s_v2.loc[stats.zscore(spec_s_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     62   HIST1H2AJ  0.030919  19.602972     0.236443
# 1             1     54   HIST1H2AM  0.032025  15.948846     0.229835
# 2             2   4089    HIST1H1A  0.041192  15.180505     0.287512
# 3             3     59    HIST1H1B  0.018586  14.360240     0.141108
# 4             4     60   HIST1H2AH  0.018228  12.786401     0.134305
# ..          ...    ...         ...       ...        ...          ...
# 342         342   4814       PRIM1  0.182700   2.617042     0.463168
# 343         343   4309  AL160262.1  0.022964   2.616777     0.064480
# 344         344   4425       ZNF90  0.058965   2.622669     0.174393
# 345         345     12     NEUROD4  0.049468   2.611835     0.123810
# 346         346    717       CLCN5  0.040449   2.609752     0.117590
#
#      per_exp_other  spec_score
# 0         0.013209       19.60
# 1         0.015026       15.95
# 2         0.020315       15.18
# ...

# %%
sig_spec_s_v2=spec_s_v2.loc[stats.zscore(spec_s_v2.spec_score)>2,:]

# %%
#intersections

# %%
fisher_test(hsg,sig_adj_spec_s_v3)
# Out:
# (['PRIM2',
#   'CDH12',
#   'SRP9',
#   'C1orf61',
#   'RBM39',
#   'NPAS3',
#   'ASPM',
#   'ZFP36L1',
#   'PRKDC'],
#  np.float64(0.43289478454880426))

# %%
fisher_test(hsg,sig_adj_spec_s_v2)
# Out:
# (['CDH12', 'SRP9', 'C1orf61', 'RBM39', 'NPAS3', 'ZFP36L1'],
#  np.float64(0.647186227709313))

# %%
fisher_test(hsg,sig_spec_s_v3)
# Out:
# (['FAM72C', 'FAM72D', 'SPAG5', 'RIBC2', 'ZNF492', 'KIF18A', 'ASPM', 'FAM72B'],
#  np.float64(0.3933251379039877))

# %%
fisher_test(hsg,sig_spec_s_v2)
# Out:
# (['FAM72C', 'FAM72D', 'SPAG5', 'CCDC74B', 'RIBC2', 'ZNF492', 'KIF18A', 'ASPM'],
#  np.float64(0.3967306146256801))

# %%
#g2ms phase
adj_spec_s_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v3_CellCyclePhase_S.csv")
adj_spec_s_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/adj_spec_v2_CellCyclePhase_S.csv")
spec_s_v3=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v3_CellCyclePhase_S.csv")
spec_s_v2=pd.read_csv("/scratch200/reutj/data/spec_score_tables/spec_v2_CellCyclePhase_S.csv")

# %%
adj_spec_s_v3.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1           1     77   HIST1H1B  0.099459  19.617977     0.777370
# 2           2   6011   HIST1H4C  1.108086   4.707637     1.000000
# 3           3   5573   HIST1H1A  0.144922  13.097078     0.832803
# 4           4   3793      SPC25  0.179435  10.408504     0.889965
#
#    per_exp_other  spec_score
# 0       0.035845       16.36
# 1       0.059261       12.28
# 2       0.779287       11.43
# 3       0.115153       11.11
# 4       0.129083       11.01

# %%
adj_spec_s_v2.head()
# Out:
#    Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0   4483  HIST1H4C  0.792649   6.539680     0.999903
# 1           1   5867     TOP2A  0.472597   5.114684     0.937998
# 2           2   2725     SPC25  0.245736   6.989310     0.828134
# 3           3   8922     HMGB2  1.051908   3.062979     0.996987
# 4           4   9721      CDK1  0.377297   4.398839     0.861953
#
#    per_exp_other  spec_score
# 0       0.393120       16.74
# 1       0.192518        8.61
# 2       0.141481        6.80
# 3       0.497381        6.69
# 4       0.193239        5.06

# %%
spec_s_v3.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1           1     83   HIST1H3B  0.051320  26.178221     0.604567
# 2           2     82  HIST1H2AI  0.013582  23.221731     0.211972
# 3           3     70  HIST1H2AM  0.070652  23.081309     0.660415
# 4           4     78  HIST1H2AH  0.029836  22.003694     0.421038
#
#    per_exp_other  spec_score
# 0       0.035845       31.87
# 1       0.029175       26.18
# 2       0.009177       23.22
# 3       0.041508       23.08
# 4       0.021644       22.00

# %%
spec_s_v2.head()
# Out:
#    Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0           0     62  HIST1H2AJ  0.030919  19.602972     0.236443
# 1           1     54  HIST1H2AM  0.032025  15.948846     0.229835
# 2           2   4089   HIST1H1A  0.041192  15.180505     0.287512
# 3           3     59   HIST1H1B  0.018586  14.360240     0.141108
# 4           4     60  HIST1H2AH  0.018228  12.786401     0.134305
#
#    per_exp_other  spec_score
# 0       0.013209       19.60
# 1       0.015026       15.95
# 2       0.020315       15.18
# 3       0.009900       14.36
# 4       0.010164       12.79

# %%
from scipy import stats
adj_spec_s_v3.loc[stats.zscore(adj_spec_s_v3.spec_score)>2,:]
#seems ok althoug the last results are a bit week
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1             1     77   HIST1H1B  0.099459  19.617977     0.777370
# 2             2   6011   HIST1H4C  1.108086   4.707637     1.000000
# 3             3   5573   HIST1H1A  0.144922  13.097078     0.832803
# 4             4   3793      SPC25  0.179435  10.408504     0.889965
# ..          ...    ...        ...       ...        ...          ...
# 451         451   3777       SOX3  0.298838   2.364777     0.732595
# 452         452   7457     DDX39A  0.272629   2.317567     0.798685
# 453         453  13528       PPIG  0.611364   1.418625     0.931903
# 454         454   7781      RBM39  0.978591   1.121342     0.975363
# 455         455   5897      PRKDC  0.622948   1.436888     0.915709
#
#      per_exp_other  spec_score
# 0         0.035845       16.36
# 1         0.059261       12.28
# 2         0.779287       11.43
# ...

# %%
adj_spec_s_v3.loc[(stats.zscore(adj_spec_s_v3.spec_score)>2) & (adj_spec_s_v3.exp_ratio>1) & (adj_spec_s_v3.per_exp_con>adj_spec_s_v3.per_exp_other),:]
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1             1     77   HIST1H1B  0.099459  19.617977     0.777370
# 2             2   6011   HIST1H4C  1.108086   4.707637     1.000000
# 3             3   5573   HIST1H1A  0.144922  13.097078     0.832803
# 4             4   3793      SPC25  0.179435  10.408504     0.889965
# ..          ...    ...        ...       ...        ...          ...
# 451         451   3777       SOX3  0.298838   2.364777     0.732595
# 452         452   7457     DDX39A  0.272629   2.317567     0.798685
# 453         453  13528       PPIG  0.611364   1.418625     0.931903
# 454         454   7781      RBM39  0.978591   1.121342     0.975363
# 455         455   5897      PRKDC  0.622948   1.436888     0.915709
#
#      per_exp_other  spec_score
# 0         0.035845       16.36
# 1         0.059261       12.28
# 2         0.779287       11.43
# ...

# %%
sig_adj_spec_s_v3=adj_spec_s_v3.loc[(stats.zscore(adj_spec_s_v3.spec_score)>2) & (adj_spec_s_v3.exp_ratio>1) & (adj_spec_s_v3.per_exp_con>adj_spec_s_v3.per_exp_other),:]

# %%
adj_spec_s_v2.loc[stats.zscore(adj_spec_s_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   4483  HIST1H4C  0.792649   6.539680     0.999903
# 1             1   5867     TOP2A  0.472597   5.114684     0.937998
# 2             2   2725     SPC25  0.245736   6.989310     0.828134
# 3             3   8922     HMGB2  1.051908   3.062979     0.996987
# 4             4   9721      CDK1  0.377297   4.398839     0.861953
# ..          ...    ...       ...       ...        ...          ...
# 403         403   4130     PSMC3  0.556253   1.515066     0.731098
# 404         404   9373   RACGAP1  0.150062   4.140888     0.503936
# 405         405   2511      PPA1  1.095815   1.004433     0.838776
# 406         406   5570      LSM7  0.886186   1.114549     0.822157
# 407         407   8324      LHX2  0.435701   1.800865     0.674101
#
#      per_exp_other  spec_score
# 0         0.393120       16.74
# 1         0.192518        8.61
# 2         0.141481        6.80
# 3         0.497381        6.69
# ...

# %%
#also here we may apply the same rules
#clear weak results
adj_spec_s_v2.loc[(stats.zscore(adj_spec_s_v2.spec_score)>2) & (adj_spec_s_v2.exp_ratio>1) & (adj_spec_s_v2.per_exp_con>adj_spec_s_v2.per_exp_other),:]
# Out:
#      Unnamed: 0  index      gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0   4483  HIST1H4C  0.792649   6.539680     0.999903
# 1             1   5867     TOP2A  0.472597   5.114684     0.937998
# 2             2   2725     SPC25  0.245736   6.989310     0.828134
# 3             3   8922     HMGB2  1.051908   3.062979     0.996987
# 4             4   9721      CDK1  0.377297   4.398839     0.861953
# ..          ...    ...       ...       ...        ...          ...
# 403         403   4130     PSMC3  0.556253   1.515066     0.731098
# 404         404   9373   RACGAP1  0.150062   4.140888     0.503936
# 405         405   2511      PPA1  1.095815   1.004433     0.838776
# 406         406   5570      LSM7  0.886186   1.114549     0.822157
# 407         407   8324      LHX2  0.435701   1.800865     0.674101
#
#      per_exp_other  spec_score
# 0         0.393120       16.74
# 1         0.192518        8.61
# 2         0.141481        6.80
# 3         0.497381        6.69
# ...

# %%
sig_adj_spec_s_v2=adj_spec_s_v2.loc[(stats.zscore(adj_spec_s_v2.spec_score)>2) & (adj_spec_s_v2.exp_ratio>1) & (adj_spec_s_v2.per_exp_con>adj_spec_s_v2.per_exp_other),:]

# %%
spec_s_v3.loc[stats.zscore(spec_s_v3.spec_score)>2,:]
# Out:
#      Unnamed: 0  index       gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     84  HIST1H2AJ  0.083051  31.865586     0.720069
# 1             1     83   HIST1H3B  0.051320  26.178221     0.604567
# 2             2     82  HIST1H2AI  0.013582  23.221731     0.211972
# 3             3     70  HIST1H2AM  0.070652  23.081309     0.660415
# 4             4     78  HIST1H2AH  0.029836  22.003694     0.421038
# ..          ...    ...        ...       ...        ...          ...
# 337         337  10794       CGAS  0.013606   3.174087     0.090104
# 338         338   5938      POLD1  0.062039   3.162849     0.376125
# 339         339   9516       TTF2  0.077835   3.150666     0.428166
# 340         340   5038     HIRIP3  0.139032   3.150357     0.659654
# 341         341   6599      HMGN5  0.160111   3.149900     0.688097
#
#      per_exp_other  spec_score
# 0         0.035845       31.87
# 1         0.029175       26.18
# 2         0.009177       23.22
# ...

# %%
#results are convincing enougth this way.. (and retaining sox2)
sig_spec_s_v3=spec_s_v3.loc[stats.zscore(spec_s_v3.spec_score)>2,:]

# %%
spec_s_v2.loc[stats.zscore(spec_s_v2.spec_score)>2,:]
# Out:
#      Unnamed: 0  index        gene  mean_exp  exp_ratio  per_exp_con  \
# 0             0     62   HIST1H2AJ  0.030919  19.602972     0.236443
# 1             1     54   HIST1H2AM  0.032025  15.948846     0.229835
# 2             2   4089    HIST1H1A  0.041192  15.180505     0.287512
# 3             3     59    HIST1H1B  0.018586  14.360240     0.141108
# 4             4     60   HIST1H2AH  0.018228  12.786401     0.134305
# ..          ...    ...         ...       ...        ...          ...
# 342         342   4814       PRIM1  0.182700   2.617042     0.463168
# 343         343   4309  AL160262.1  0.022964   2.616777     0.064480
# 344         344   4425       ZNF90  0.058965   2.622669     0.174393
# 345         345     12     NEUROD4  0.049468   2.611835     0.123810
# 346         346    717       CLCN5  0.040449   2.609752     0.117590
#
#      per_exp_other  spec_score
# 0         0.013209       19.60
# 1         0.015026       15.95
# 2         0.020315       15.18
# ...

# %%
sig_spec_s_v2=spec_s_v2.loc[stats.zscore(spec_s_v2.spec_score)>2,:]

# %%
#intersections

# %%
fisher_test(hsg,sig_adj_spec_s_v3)
# Out:
# (['PRIM2',
#   'CDH12',
#   'SRP9',
#   'C1orf61',
#   'RBM39',
#   'NPAS3',
#   'ASPM',
#   'ZFP36L1',
#   'PRKDC'],
#  np.float64(0.43289478454880426))

# %%
fisher_test(hsg,sig_adj_spec_s_v2)
# Out:
# (['CDH12', 'SRP9', 'C1orf61', 'RBM39', 'NPAS3', 'ZFP36L1'],
#  np.float64(0.647186227709313))

# %%
fisher_test(hsg,sig_spec_s_v3)
# Out:
# (['FAM72C', 'FAM72D', 'SPAG5', 'RIBC2', 'ZNF492', 'KIF18A', 'ASPM', 'FAM72B'],
#  np.float64(0.3933251379039877))

# %%
fisher_test(hsg,sig_spec_s_v2)
# Out:
# (['FAM72C', 'FAM72D', 'SPAG5', 'CCDC74B', 'RIBC2', 'ZNF492', 'KIF18A', 'ASPM'],
#  np.float64(0.3967306146256801))
