# %% [markdown]
# # plot results and view in data

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# Out:
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /scratch200/reutj/conda-envs/jupyter-scanpy/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### speceficity results enrichments

# %%
hsg_gse_ct={'radial glia':0.3128,'IPC':0.1524,'Glioblast':0.7071,'Neuron':0.1091,'Nueroblast':0.2527,'NPCs':0.0196,'proliferating':0.0874,'differentiating':0.2644}
har_gse_ct={'radial glia':0.2864,'IPC':0.2208,'Glioblast':0.2285,'Neuron':0.0032,'Nueorblast':0.0227 ,'NPCs':0.2789,'proliferating':0.0439,'differentiating':0.1149}

# %%
plt.bar(hsg_gse_ct.keys(), [-math.log10(i) for i in list(hsg_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell type specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell type specificity lists')

# %%
plt.bar(har_gse_ct.keys(), [-math.log10(i) for i in list(har_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('GSEA results of HAR genes in cell type specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of HAR genes in cell type specificity lists')

# %%
#speceficity results cell cycle
hsg_gse_cy={'G1': 0.9077,'S':0.2542,'G2M':0.0017,'PostM':0.0196,'Non-cycling':0.1741}
har_gse_cy={'G1': 0.1261,'S':0.6944,'G2M':0.7253,'PostM':0.2789,'Non-cycling':0.0326}

# %%
plt.bar(hsg_gse_cy.keys(), [-math.log10(i) for i in list(hsg_gse_cy.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell cycle phase specificity lists')
#אםפשר לחקת את התאים הלא מתחלקים ולבדוק רק בתוך התאים של הרדיאל גליה ואיפיס
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell cycle phase specificity lists')

# %%
plt.bar(har_gse_cy.keys(), [-math.log10(i) for i in list(har_gse_cy.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('GSEA results of HAR genes in cell cycle phase specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of HAR genes in cell cycle phase specificity lists')

# %%
#new hsg
res=pd.read_csv("/scratch200/reutj/data/ges_results/hsg_all_gene_set/full_results.csv")

# %%
res
# Out:
#     Unnamed: 0                    condition num_genes_in_lead % genes_in_lead  \
# 0            0                   radialglia            36/206          15.03%
# 1            1                proliferating            24/210           7.96%
# 2            2              differentiating            58/203          23.35%
# 3            3                          IPC            26/206           7.85%
# 4            4                         NPCs            24/206           7.21%
# 5            5                           G1            46/203          23.52%
# 6            6                            S            25/210           6.58%
# 7            7                          G2M            21/213           7.00%
# 8            8                        PostM            24/206           7.21%
# 9            9                       Neuron            88/203          35.62%
# 10          10                    Glioblast            99/211          43.63%
# ...

# %%
hsg_gse_ct={'radial glia':0.394450,'IPC':0.330633,'Glioblast':0.690415,'Nueroblast':0.414909,'Neuron':0.330633,'NPCs':0.089600,'proliferating':0.281750,'differentiating':0.414909}
plt.bar(hsg_gse_ct.keys(), [-math.log10(i) for i in list(hsg_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell type specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell type specificity lists')

# %%
hsg_gse_cy={'G1': 0.868100,'S':0.394450,'G2M':0.023800,'PostM-proliferating':0.089600,'Non-cycling-proliferating':0.630700,'PostM-differentiating':0.414909}
plt.bar(hsg_gse_cy.keys(), [-math.log10(i) for i in list(hsg_gse_cy.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell cycle phase specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell cycle phase specificity lists')

# %%
#hsg dup
res_dup=pd.read_csv("/scratch200/reutj/data/ges_results/hsg_dup_gene_set/full_results.csv")
res_dup
# Out:
#     Unnamed: 0                    condition num_genes_in_lead % genes_in_lead  \
# 0            0                   radialglia            23/121          15.03%
# 1            1                proliferating            19/123          11.74%
# 2            2              differentiating            56/121          37.74%
# 3            3                          IPC            17/123           9.68%
# 4            4                         NPCs            13/121           7.21%
# 5            5                           G1            25/118          20.88%
# 6            6                            S            14/123           6.58%
# 7            7                          G2M            12/127           4.76%
# 8            8                        PostM            13/121           7.21%
# 9            9                       Neuron            75/120          51.79%
# 10          10                    Glioblast            60/123          44.06%
# ...

# %%
hsg_gse_ct={'radial glia':0.734373,'IPC':0.734373,'Glioblast':0.860672,'Nueroblast':0.821489,'Neuron':0.821489,'NPCs':	0.121333,'proliferating':0.521500,'differentiating':0.860672}
plt.bar(hsg_gse_ct.keys(), [-math.log10(i) for i in list(hsg_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell type specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell type specificity lists')

# %%
hsg_gse_cy={'G1': 0.860672,'S':0.797080,'G2M':0.019600,'PostM-proliferating':0.121333,'Non-cycling-proliferating':0.860672
,'PostM-differentiating':0.860672}
plt.bar(hsg_gse_cy.keys(), [-math.log10(i) for i in list(hsg_gse_cy.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell cycle phase specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell cycle phase specificity lists')

# %%
#hsg seq 
res_seq=pd.read_csv("/scratch200/reutj/data/ges_results/hsg_change_seq_gene_set/full_results.csv")
res_seq
# Out:
#     Unnamed: 0                    condition num_genes_in_lead % genes_in_lead  \
# 0            0                   radialglia             11/85           4.12%
# 1            1                proliferating             10/87           6.81%
# 2            2              differentiating             17/82           9.55%
# 3            3                          IPC             11/83           7.85%
# 4            4                         NPCs             10/85           4.71%
# 5            5                           G1             20/85          23.35%
# 6            6                            S             11/87           6.42%
# 7            7                          G2M              7/86           6.15%
# 8            8                        PostM             10/85           4.71%
# 9            9                       Neuron             22/83          12.00%
# 10          10                    Glioblast             30/88          26.46%
# ...

# %%
#this table! its clear there are some neurnal results but p-adj removes it almost completly... didnt redraw.
hsg_gse_ct={'radial glia':0.079524,'IPC':0.223860,'Glioblast':0.293688,'Nueroblast':0.042716,'Neuron':0.013906	,'NPCs':0.056506,'proliferating':0.104200,'differentiating':0.035507}
plt.bar(hsg_gse_ct.keys(), [-math.log10(i) for i in list(hsg_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell type specificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell type specificity lists')

# %%
hsg_gse_cy={'G1': 0.717461,'S':0.316279,'G2M':0.275153,'PostM':0.131847,'Non-cycling':0.105721}
plt.bar(hsg_gse_cy.keys(), [-math.log10(i) for i in list(hsg_gse_cy.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell cycle phase specificity lists')
#intersting elevation
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell cycle phase specificity lists')

# %%
#har again with padj
har_res=pd.read_csv("/scratch200/reutj/data/ges_results/custom_har_genes_list/full_results.csv")
har_res
# Out:
#     Unnamed: 0                    condition num_genes_in_lead % genes_in_lead  \
# 0            0                   radialglia           107/448          23.64%
# 1            1                proliferating            83/454          14.67%
# 2            2              differentiating           105/443          16.97%
# 3            3                          IPC           100/445          20.01%
# 4            4                         NPCs            72/450          13.08%
# 5            5                           G1           102/456          19.04%
# 6            6                            S            62/462          10.69%
# 7            7                          G2M           165/458          34.82%
# 8            8                        PostM            72/450          13.08%
# 9            9                       Neuron           109/444          15.79%
# 10          10                    Glioblast           107/452          21.34%
# ...

# %%
hsg_gse_ct={'radial glia':0.334133,'IPC':0.334133,'Glioblast':0.334133,'Nueroblast':0.105933,'Neuron':0.044800,'NPCs':0.334133,'proliferating':0.153650,'differentiating':0.252200}
plt.bar(hsg_gse_ct.keys(), [-math.log10(i) for i in list(hsg_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of HAR genes in cell type spepcificity lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of HAR genes in cell type spepcificity lists')

# %%
hsg_gse_cy={'G1':0.252200,'S':0.725300,'G2M':0.725300,'PostM-proliferating':0.334133,'Non-cycling-proliferating':0.105933,
'postM-differentiating':0.199080}
plt.bar(hsg_gse_cy.keys(), [-math.log10(i) for i in list(hsg_gse_cy.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.1), color = 'r', linestyle = '-') 
plt.title('GSEA results of HAR genes in cell cycle phase specificity lists')
#intersting elevation
# Out:
# Text(0.5, 1.0, 'GSEA results of HAR genes in cell cycle phase specificity lists')

# %%
#new har- 700
res_har_700=pd.read_csv("/scratch200/reutj/data/ges_results/har_700_genes/full_results.csv")
res_har_700
#no point of showing with all the padj behave the same..
#all non -significant
# Out:
#     Unnamed: 0                    condition num_genes_in_lead % genes_in_lead  \
# 0            0                   radialglia           188/521          34.94%
# 1            1                proliferating            82/526          14.21%
# 2            2              differentiating           131/508          27.35%
# 3            3                          IPC           284/520          53.72%
# 4            4                         NPCs           211/523          37.42%
# 5            5                           G1           230/526          42.89%
# 6            6                            S           172/531          30.13%
# 7            7                          G2M           192/527          32.79%
# 8            8                        PostM           211/523          37.42%
# 9            9                       Neuron           103/506          22.83%
# 10          10                    Glioblast           205/528          37.74%
# ...

# %%
#new har associated- 700
res_har_assoc=pd.read_csv("/scratch200/reutj/data/ges_results/har_associated/full_results.csv")
res_har_assoc
#here almost everythng is enriched.. how tom graph that? (check on a list with same size?)
#note very high nes in proliferating-non-cycling , neurons and differentiating cells
# Out:
#     Unnamed: 0                    condition num_genes_in_lead % genes_in_lead  \
# 0            0                   radialglia          229/1092          16.99%
# 1            1                proliferating          257/1108          15.52%
# 2            2              differentiating          272/1064          15.47%
# 3            3                          IPC          304/1093          24.36%
# 4            4                         NPCs          246/1095          18.49%
# 5            5                           G1          318/1101          22.42%
# 6            6                            S          407/1123          32.39%
# 7            7                          G2M          309/1110          25.56%
# 8            8                        PostM          246/1095          18.49%
# 9            9                       Neuron          305/1050          18.54%
# 10          10                    Glioblast          347/1084          22.09%
# ...

# %% [markdown]
# #### deseq2 results

# %%
#dge deseq2 results.. 
hsg_dse_ct={'radial glia':0.5626254516258531,'IPC':0.0749,'Glioblast':0.3437,'Neuroblast':0.6597,'Neuron':0.1664,'NPCs':0.1115111511151115,'proliferating':0.5336,'differentiating':0.0065}
har_dse_ct={'radial glia':0.8642456982793117,'IPC':0.002,'Glioblast':0.36,'Neuroblast':0.0231 ,'Neuron':0.0001,'NPCs':0.0015,'proliferating':0.0151,'differentiating':0.0009}

# %%
plt.bar(hsg_dse_ct.keys(), [-math.log10(i) for i in list(hsg_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('GSEA results of human specific genes in cell class dge lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of human specific genes in cell class dge lists')

# %%
plt.bar(har_dse_ct.keys(), [-math.log10(i) for i in list(har_gse_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('GSEA results of HAR genes in cell class dge lists')
# Out:
# Text(0.5, 1.0, 'GSEA results of HAR genes in cell class dge lists')

# %% [markdown]
# ### fisher results to sig lists

# %%
#dge fisher results
hsg_fisher_ct={'radial glia':0.49,'IPC':0.74,'Glioblast':0.45,'Neuron':0.16,'NPCs':0.17,'proliferating':0.23,'differentiating':0.27}
har_fisher_ct={'radial glia':0.747470841423922,'IPC':0.11852195581668815,'Glioblast':0.2561679171662372,'Neuroblast':0.3246258971918238 ,'Neuron':0.0029907019557552433,'NPCs':0.07312308932946764,'proliferating':0.3366892930691437,'differentiating':0.0426480875027815}

# %%
plt.bar(har_fisher_ct.keys(), [-math.log10(i) for i in list(har_fisher_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('fisher exact results of HAR genes in cell class dge lists')
# Out:
# Text(0.5, 1.0, 'fisher exact results of HAR genes in cell class dge lists')

# %%
plt.bar(hsg_fisher_ct.keys(), [-math.log10(i) for i in list(hsg_fisher_ct.values())])
plt.xticks(rotation=45)
plt.ylabel('-log10(padj)')
plt.axhline(y = -math.log10(0.05), color = 'r', linestyle = '-') 
plt.title('fisher exact results of human specific genes in cell class dge lists')
# Out:
# Text(0.5, 1.0, 'fisher exact results of human specific genes in cell class dge lists')
